# %%
import requests
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup as bs
import json
from datetime import date

# %%
df_scrap = pd.DataFrame(columns=['art_content','art_content_html','art_extract_datetime','art_lang','art_title','art_url','src_name','src_type','src_url','src_img','art_auth','art_tag']  )
df_scrap
# Out:
# Empty DataFrame
# Columns: [art_content, art_content_html, art_extract_datetime, art_lang, art_title, art_url, src_name, src_type, src_url, src_img, art_auth, art_tag]
# Index: []

# %%
url = "https://www.sap.com/france/products/erp-financial-management/grc.html"

# %%
def getSoup(url):
    
    response = requests.get(url)
    print("statut de la reponse ", response.status_code)
    print('\n')
    soup = bs(response.text, 'html.parser')
    print(soup)
    
    return soup

# %%
soup = getSoup(url)
# Out:
# statut de la reponse  200
#
#
# <!DOCTYPE html>
#
# <html class="content-fr_fr fr_fr bp touchPageRenderingFix" data-client-config="dcc_sap_com" data-language="fr_fr" data-page-path="/content/sapdx/languages/fr_fr/products/erp-financial-management/grc" data-publish-path="/france/products/erp-financial-management/grc.html" data-request-path="/content/sapdx/countries/fr_fr/products/erp-financial-management/grc.html" data-site-code="france" lang="fr" prefix="og: http://ogp.me/ns# fb: http://www.facebook.com/2008/fbml" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="GRC, gouvernance, risques, conformitÃ©, cybersÃ©curitÃ©" name="keywords"/>
# <title>CybersÃ©curitÃ© et gestion de la gouvernance, des risques et de la conformitÃ© | GRC</title>
# <meta content="ProtÃ©gez votre entreprise et ses rÃ©sultats, et adaptez-vous rapidement aux changements liÃ©s aux technologies, aux rÃ©glementations et Ã  l'Ã©conomie avec les logicielsÂ SAP pour la gestion de la cybersÃ©curitÃ©, et de la gouvernance, des risques et de la conformitÃ© (GRC)." name="description"/>
# <meta content="website" property="og:type"/>
# <meta content="https://www.sap.com/france/products/erp-financial-management/grc.html" property="og:url"/>
# <meta content="CybersÃ©curitÃ© et gestion de la gouvernance, des risques et de la conformitÃ© | GRC" property="og:title"/>
# <meta content="ProtÃ©gez votre entreprise et ses rÃ©sultats, et adaptez-vous rapidement aux changements liÃ©s aux technologies, aux rÃ©glementations et Ã  l'Ã©conomie avec les logicielsÂ SAP pour la gestion de la cybersÃ©curitÃ©, et de la gouvernance, des risques et de la conformitÃ© (GRC)." property="og:description"/>
# <meta content="SAP" property="og:site_name"/>
# <meta content="http://www.sap.com/dam/application/imagelibrary/photos/285000/285294.jpg/_jcr_content/renditions/285294_photo_3840_2160.jpg.adapt.640_-1.true.true.false.false.jpg" property="og:image"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="https://www.sap.com/france/products/erp-financial-management/grc.html" name="twitter:url"/>
# <meta content="CybersÃ©curitÃ© et gestion de la gouvernance, des risques et de la conformitÃ© | GRC" name="twitter:title"/>
# <meta content="ProtÃ©gez votre entreprise et ses rÃ©sultats, et adaptez-vous rapidement aux changements liÃ©s aux technologies, aux rÃ©glementations et Ã  l'Ã©conomie avec les logicielsÂ SAP pour la gestion de la cybersÃ©curitÃ©, et de la gouvernance, des risques et de la conformitÃ© (GRC)." name="twitter:description"/>
# <meta content="@SAP" name="twitter:site"/>
# <meta content="http://www.sap.com/dam/application/imagelibrary/photos/285000/285294.jpg/_jcr_content/renditions/285294_photo_3840_2160.jpg.adapt.640_-1.true.true.false.false.jpg" name="twitter:image"/>
# <link href="/etc.clientlibs/sapdx/clientlibs/clientlib-generic-legacy/resources/images/apple-touch-icons/touch-icon-60x60.png" rel="apple-touch-icon" sizes="60x60"/>
# <link href="/etc.clientlibs/sapdx/clientlibs/clientlib-generic-legacy/resources/images/apple-touch-icons/touch-icon-120x120.png" rel="apple-touch-icon" sizes="120x120"/>
# <link href="/etc.clientlibs/sapdx/clientlibs/clientlib-generic-legacy/resources/images/apple-touch-icons/touch-icon-180x180.png" rel="apple-touch-icon" sizes="180x180"/>
# <!--*/ Used for metadata customization of inherited pages */-->
# <meta content="0e8b67a5-7368-4677-ba96-0d3be3f2fb03,855921296787923236940428336119456,fr-FR,207430454709915121807807" name="sm_tech_ids"/>
# <meta content="French (France)" name="language"/>
# <meta content="France" name="web_site_identifier"/>
# <meta content="Page" name="type"/>
# <meta content="Web Pages" name="content_format"/>
# <meta content="ERP and Finance" name="portfolio_positioning"/>
# <script data-dtconfig="rid=RID_156827016|rpid=-1454887732|domain=sap.com|reportUrl=/rb_7a201085-1631-4793-b435-359a88a45974|app=ea7c4b59f27d43eb|featureHash=ICA2SVfqru|vcv=2|rdnt=1|uxrgce=1|bp=2|cuc=qt925f5j|dpvc=1|lastModification=1609461433418|dtVersion=10205201218101503|tp=500,50,0,1|uxdcw=1500|vs=2|agentUri=/ruxitagentjs_ICA2SVfqru_10205201218101503.js" src="/ruxitagentjs_ICA2SVfqru_10205201218101503.js" type="text/javascript"></script><script data-dtconfig="app=ea7c4b59f27d43eb|featureHash=ICA2SVfqru|vcv=2|rdnt=1|uxrgce=1|bp=2|cuc=qt925f5j|dpvc=1|lastModification=1609461433418|dtVersion=10205201218101503|tp=500,50,0,1|uxdcw=1500|vs=2|agentUri=/ruxitagentjs_ICA2SVfqru_10205201218101503.js|reportUrl=/rb_7a201085-1631-4793-b435-359a88a45974|rid=RID_-1389787772|rpid=-1954554969|domain=sap.com" src="/ruxitagentjs_ICA2SVfqru_10205201218101503.js" type="text/javascript"></script><link href="/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link crossorigin="" href="https://accounts.sap.com" rel="preconnect"/>
# <link href="https://accounts.sap.com" rel="dns-prefetch"/>
# <link href="https://trustarc.com" rel="dns-prefetch"/>
# <link href="https://trustarc.com" rel="preconnect"/>
# <link href="https://www.sap.com/france/products/erp-financial-management/grc.html" rel="canonical"/>
# <link href="/etc.clientlibs/sapdx/clientlibs/clientlib-global-usage/clientlib-global-usage-codebase.min.6d5e8185e6e2e58e9d975386d3d57670.css" rel="stylesheet" type="text/css"/>
# <link href="/etc.clientlibs/sapdx/clientlibs/clientlib-jquery-ui-customized.min.d41d8cd98f00b204e9800998ecf8427e.css" rel="stylesheet" type="text/css"/>
# <link href="/etc.clientlibs/sapdx/components/modular/nav/languageSelector/clientlib.min.870ff8713df8e06c1644ce80aef6b5b1.css" rel="stylesheet" type="text/css"/>
# <link href="/etc.clientlibs/sapdx/components/corporate/headerLangStandard/clientlib.min.a561ddffe7cd45ba42fb5c2437ae4bc9.css" rel="stylesheet" type="text/css"/>
# <link href="/etc.clientlibs/sapdx/components/modular/nav/headerStandard/clientlib.min.09a1e6dd9fd9ba10de0f08bb6a0a4310.css" rel="stylesheet" type="text/css"/>
# <link href="/etc.clientlibs/sapdx/components/modular/container/section/clientlib.min.abf1a300ae5a5f2aa0557bd359066ec4.css" rel="stylesheet" type="text/css"/>
# <link href="/etc.clientlibs/sapdx/components/modular/frame/clientlib.min.6cc8eecd611d307c5fb929e4a99272cb.css" rel="stylesheet" type="text/css"/>
# <link href="/etc.clientlibs/sapdx/components/modular/truste/truste/clientlib.min.313923f9aaa73ef72cc287414a41a77f.css" rel="stylesheet" type="text/css"/>
# <link href="/etc.clientlibs/sapdx/components/modular/topNavPromo/clientlib.min.3e564fb213c5d349fe482d14158fcbb7.css" rel="stylesheet" type="text/css"/>
# <link href="/etc.clientlibs/sapdx/components/modular/uid/authentication/clientlib.min.257318b1f8cd609e3e27d40fa8af0e75.css" rel="stylesheet" type="text/css"/>
# <link href="/etc.clientlibs/sapdx/components/modular/authentication/clientlib.min.86fece0cfacf904a2e29b2102c4f8ad5.css" rel="stylesheet" type="text/css"/>
# <link href="/etc.clientlibs/sapdx/components/modular/formLogin/clientlib.min.b8c2f1aa2d2348a0c2c2c7a265f3804a.css" rel="stylesheet" type="text/css"/>
# <link href="/etc.clientlibs/sapdx/components/modular/countrySelector/clientlib.min.42bbd18ff5547ae8e8b2339e6cef74fa.css" rel="stylesheet" type="text/css"/>
# <link href="/etc.clientlibs/sapdx/clientlibs/clientlib-global-usage.min.d41d8cd98f00b204e9800998ecf8427e.css" rel="stylesheet" type="text/css"/>
# <script src="/etc.clientlibs/clientlibs/granite/jquery.min.8e23e5ad8c1b5c588cca8d71df0aef0b.js" type="text/javascript"></script>
# <script src="/etc.clientlibs/clientlibs/granite/utils.min.fd64744866d6499535dd464d6da82678.js" type="text/javascript"></script>
# <script src="/etc.clientlibs/clientlibs/granite/jquery/granite.min.d5e9f23f76c833119924c46f2a433ab6.js" type="text/javascript"></script>
# <script src="/etc.clientlibs/foundation/clientlibs/jquery.min.dd9b395c741ce2784096e26619e14910.js" type="text/javascript"></script>
# <script src="/etc.clientlibs/foundation/clientlibs/shared.min.6cd003256d877aa91c7c5632fd28d19d.js" type="text/javascript"></script>
# <script src="/etc.clientlibs/cq/personalization/clientlib/underscore.min.bdd50875c07e56f60d1b7407fedba430.js" type="text/javascript"></script>
# <script src="/etc.clientlibs/cq/personalization/clientlib/personalization/kernel.min.30396f954d7308d29a525a9b9573b0ac.js" type="text/javascript"></script>
# <script src="/etc.clientlibs/clientlibs/granite/lodash/modern.min.3a0ad4c7614495b1cae264dfcb9b9813.js" type="text/javascript"></script>
# <script src="/etc.clientlibs/cq/personalization/clientlib/personalization/integrations/commons.min.2b48968f693eba80428c01cfb96e50d3.js" type="text/javascript"></script>
# <script src="/etc.clientlibs/cq/testandtarget/clientlibs/testandtarget/atjs-integration.min.57a208c2d6654f348c2e68a2da2d1045.js" type="text/javascript"></script>
# <script src="/etc.clientlibs/cq/testandtarget/clientlibs/testandtarget/util.min.2b3d8311dfdb32a0a3d54d1bedb084e6.js" type="text/javascript"></script>
# <script src="/etc.clientlibs/sapdx/clientlibs/clientlib-handlebars.min.8b33830677f1fe3d2b3cbc36bcfff0fb.js" type="text/javascript"></script>
# <script src="/etc.clientlibs/sapdx/clientlibs/clientlib-global-usage/clientlib-global-usage-codebase.min.684952af2447c9b9865e7cd571c03f26.js" type="text/javascript"></script>
# <script src="/etc.clientlibs/sapdx/clientlibs/clientlib-jquery-ui-customized.min.c71b45d2b74a17de10ba9f43680acdda.js" type="text/javascript"></script>
# <script src="/etc.clientlibs/sapdx/components/modular/nav/languageSelector/clientlib.min.123880e0b79d66d49d9375fd5bf8c877.js" type="text/javascript"></script>
# <script src="/etc.clientlibs/sapdx/components/corporate/headerLangStandard/clientlib.min.256ec03cb09721e11e9b60093c0a1776.js" type="text/javascript"></script>
# <script src="/etc.clientlibs/sapdx/components/modular/nav/headerStandard/clientlib.min.0ef6b67931abc8239eafda7a9946351c.js" type="text/javascript"></script>
# <script src="/etc.clientlibs/sapdx/components/modular/container/section/clientlib.min.5af82ba11c56a67457a3bf3f2f5582f4.js" type="text/javascript"></script>
# <script src="/etc.clientlibs/sapdx/components/modular/frame/clientlib.min.9dee1eb059a4fd222a7bd6caf5cff7e7.js" type="text/javascript"></script>
# <script src="/etc.clientlibs/sapdx/clientlibs/analytics/clientlib-finder-analytics.min.3ceb4065456af6a5ce6a10eeabd9dec9.js" type="text/javascript"></script>
# <script src="/etc.clientlibs/sapdx/clientlibs/analytics/dfp.min.js.lib.min.1b53d9904b3f84b23d1166b5754a30e6.js" type="text/javascript"></script>
# <script src="/etc.clientlibs/sapdx/clientlibs/analytics/clientlib-analytics.min.ae895818c4deccc303d7b476c55bf311.js" type="text/javascript"></script>
# <script src="/etc.clientlibs/sapdx/clientlibs/analytics/clientlib-onload-analytics.min.4ea1ba459fbe5fa0f3ac4f7a9c81d21a.js" type="text/javascript"></script>
# <script src="/etc.clientlibs/sapdx/clientlibs/analytics/clientlib-init-analytics.min.abf4c34200daa13fb61f39139197b055.js" type="text/javascript"></script>
# <script src="/etc.clientlibs/sapdx/components/modular/truste/truste/clientlib.min.5c7b42f4befb63f76790e389c12a6310.js" type="text/javascript"></script>
# <script src="/etc.clientlibs/sapdx/components/modular/uid/authentication/clientlib.min.f636db7e0e5851ce564e4de09126d691.js" type="text/javascript"></script>
# <script src="/etc.clientlibs/sapdx/components/modular/authentication/clientlib.min.cf06da147c5f9ea5436101614733bd4e.js" type="text/javascript"></script>
# <script src="/etc.clientlibs/sapdx/components/modular/formLogin/clientlib.min.fce0d36de97e2aa9fb6066424e411e94.js" type="text/javascript"></script>
# <script src="/etc.clientlibs/sapdx/components/modular/countrySelector/clientlib.min.19752628d4153e267138cc9411b162f3.js" type="text/javascript"></script>
# <script src="/etc.clientlibs/sapdx/clientlibs/clientlib-gating-autoloading.min.568594e6c20719ff3c4ee05175308dcf.js" type="text/javascript"></script>
# <script src="/etc.clientlibs/sapdx/clientlibs/clientlib-global-usage.min.d41d8cd98f00b204e9800998ecf8427e.js" type="text/javascript"></script>
# <script type="text/javascript">
#         (function(){
#             window.SAP = window.SAP || {};
#             SAP.DTM = SAP.DTM || {};
#             SAP.DTM.pageComponents = ["sapdx/components/modular/heroes/heroSpaceProductCategory","sapdx/components/page/contentpages/productPageGrid3","sapdx/components/modular/universalLayout","sapdx/components/modular/nav/headerStandard","nt:unstructured","sapdx/components/page/contentpages/standardPageGrid3","sapdx/components/modular/nav/navigationExtended2019/item","sapdx/components/modular/heroUniversal","sapdx/components/modular/nav/footer","sapdx/components/modular/heroes/heroSpaceProductCategory/event","sapdx/components/modular/heroes/heroSpaceProductCategory/promo","sapdx/components/modular/container/section","foundation/components/iparsys/par","foundation/components/reference","foundation/components/parsys","sapdx/components/modular/countrySelector","foundation/components/iparsys","sapdx/components/modular/universalLayout/item","cq:BlueprintSyncConfig","sapdx/components/modular/nav/navigationExtended2019","sapdx/components/page/contentpages/homePageStandard"];
#             SAP.DTM.runMode = "prod";
#         })();
#     </script>
# <script type="text/javascript">
#         window.SAP = window.SAP || {};
#         SAP.DTM = SAP.DTM || {};
#         SAP.DTM.LivePerson = SAP.DTM.LivePerson || {};
#         var url = window.location.href;
#         SAP.DTM.LivePerson.lpButtonId = "lpChatButtonDiv1";
#         SAP.DTM.LivePerson.countryWithDefault = "fr";
#         SAP.DTM.LivePerson.languageWithDefault = "fr";
#         SAP.DTM.LivePerson.arrLPvars = [
#             { scope:'page', name:'Unit', value: "sales" },
#             { scope:'page', name:'Section', value: "home" },
#             { scope:'page', name:'Site', value:"sap" },
#             { scope:'page', name:'Collection', value:"general" },
#             { scope:'page', name:'Country', value:"fr" },
#             { scope:'page', name:'Language', value:"fr" },
#             { scope:'page', name:'WBSCode', value:"CRM-FR19-TEL-FRICHAT" },
#             { scope:'page', name:'Url', value: url },
#             { scope:'session', name:'lpReferrer', value: url },
#             { scope:'page', name:'VideoIsPlaying', value: "false" }
#         ];
#     </script>
# <script src="//assets.adobedtm.com/ccc66c06b30b/7f1afd17dc3b/launch-7ee8b84a36a9.min.js"></script>
# <link href="/etc/sapdx/binary/clientlib-pdfjs.min.d41d8cd98f00b204e9800998ecf8427e.css" rel="stylesheet" type="text/css"/>
# <link href="/etc/sapdx/binary/clientlibs-pdfjs-extensions.min.d0e64aa04183419090cf093099dc05e4.css" rel="stylesheet" type="text/css"/>
# <script src="/etc/sapdx/binary/clientlib-pdfjs.min.d69d3bd08f52a79589ec4cc3d5a77d03.js" type="text/javascript"></script>
# <script src="/etc/sapdx/binary/clientlibs-pdfjs-extensions.min.fa1d62136788aab499ab01df12199ccd.js" type="text/javascript"></script>
# <link href="/etc.clientlibs/sapdx/clientlibs/clientlib-product-grid2-codebase-headlibs.min.f22747fbd5bf7dfbae71e7909b76795e.css" rel="stylesheet" type="text/css"/>
# <script src="/etc.clientlibs/sapdx/clientlibs/clientlib-product-grid2-codebase-headlibs.min.ee9a82655dc33f9d447df117ff951a6a.js" type="text/javascript"></script>
# <link href="/etc/sapdx/binary/clientlib-videojs.min.4ba5fa50adc86142ea06780ffb71b57e.css" rel="stylesheet" type="text/css"/>
# <link href="/etc.clientlibs/sapdx/clientlibs/clientlib-product-grid2.min.02da2ce79e6159b429c2007ef708ed0b.css" rel="stylesheet" type="text/css"/>
# <link href="/etc.clientlibs/sapdx/ui/react/resources/static/commonStyles~static.5dd0edeeb32bf3e0cb6e.css" rel="stylesheet">
# <script src="/etc.clientlibs/sapdx/ui/react/resources/static/runtime.4410517c8893d1f57b7b.js" type="text/javascript"></script>
# <script src="/etc.clientlibs/sapdx/ui/react/resources/static/commonStyles~static.cd129841f7f4a74398f0.js" type="text/javascript"></script>
# <script src="/etc.clientlibs/sapdx/ui/react/resources/static/static.72063b7a6a0abd344cd5.js" type="text/javascript"></script>
# </link></head>
# <body class="is-publish-true productPageGrid3" data-banner-enabled="true" data-banner-expdate="2020-07-29" data-banner-key="Header.NotificationBanner.PrivacyUpdate.Text" data-dynamic-components="sapdx/components/modular/finders/finderContainerStandard,sapdx/components/modular/finderContainer" data-enable-qualtrics-service-layer="true" data-is-pdf-lightbox-enabled="true" data-is-pdf-rating-allowed="true" data-is-video-lightbox-enabled="true" data-is-video-rating-allowed="true" data-qualtrics-survey-language="FR">
# <div class="notificationBannerWrapper" data-component="NotificationBanner" data-type="static" style="display: none"></div>
# <noscript>
# <div class="nojs">JavaScript doit Ãªtre activÃ© pour un affichage optimal de la page</div>
# </noscript>
# <div id="page">
# <div class="hidden" data-ids-cookie-loggedout-value="xxxxxx" data-ids-cookie-name="ONEDX_IDS_PROD" data-ids-sp-name="sapdx" id="idsConfig"></div>
# <div class="pageAnalytics-block hidden">
# <div class="pageAnalytics" data-country-code="fr" data-ids-hostname="https://accounts.sap.com"></div>
# </div>
# <strong class="accessibility"><a accesskey="S" href="#main" tabindex="0">AccÃ¨s rapide au contenu</a></strong>
# <header id="header">
# <div class="section"><div class="new"></div>
# </div><div class="iparys_inherited"><div class="parHeader iparsys parsys"><div class="section header headerLangStandard headerStandard container-extended"><!-- SDI include (path: /content/sapdx/countries/fr_fr/_jcr_content/parHeader/headerstandard.cache.html, resourceType: sapdx/components/modular/nav/headerStandard) -->
# <div class="hidden headerKeys" data-header.search.autosuggest.viewallresults.label="Afficher tous les rÃ©sultats">
# </div>
# <!--Header Component-->
# <div class="header-lang-standard header-standard font-is-not-loaded site-skin- large-content header-holder-standard">
# <div class="logo-wrapper">
# <a class="logo" data-engagement-tracking-analytics="header:Logo" href="/france/index.html" title="SAP">
# <img alt="SAP" class="image svg-image" data-src="/dam/application/shared/logos/sap-logo-svg.svg.adapt.svg/1493030643828.svg" src="/dam/application/shared/logos/sap-logo-svg.svg.adapt.svg/1493030643828.svg"/>
# </a>
# </div>
# <nav class="menu-wrapper">
# <ul class="menu list-unstyled">
# <li class="menu__item">
# <a aria-haspopup="true" class="menu__link has-dropdown" data-engagement-tracking-analytics="nav_L1:Produits" data-index="0" href="/france/products.html" target="_self">
# <span class="link__title">Produits<span class="icon-arrow-next"></span></span>
# </a>
# </li>
# <li class="menu__item">
# <a aria-haspopup="true" class="menu__link has-dropdown" data-engagement-tracking-analytics="nav_L1:Industries" data-index="1" href="/france/industries.html" target="_self">
# <span class="link__title">Industries<span class="icon-arrow-next"></span></span>
# </a>
# </li>
# <li class="menu__item">
# <a aria-haspopup="true" class="menu__link has-dropdown" data-engagement-tracking-analytics="nav_L1:Services et support" data-index="2" href="/france/support.html" target="_self">
# <span class="link__title">Services et support<span class="icon-arrow-next"></span></span>
# </a>
# </li>
# <li class="menu__item">
# <a aria-haspopup="true" class="menu__link has-dropdown" data-engagement-tracking-analytics="nav_L1:Formation" data-index="3" href="/france/training-certification.html" target="_self">
# <span class="link__title">Formation<span class="icon-arrow-next"></span></span>
# </a>
# </li>
# <li class="menu__item">
# <a aria-haspopup="true" class="menu__link has-dropdown" data-engagement-tracking-analytics="nav_L1:CommunautÃ©" data-index="4" href="/france/community.html" target="_self">
# <span class="link__title">CommunautÃ©<span class="icon-arrow-next"></span></span>
# </a>
# </li>
# <li class="menu__item">
# <a aria-haspopup="true" class="menu__link has-dropdown" data-engagement-tracking-analytics="nav_L1:Partenaire" data-index="5" href="/france/partner.html" target="_self">
# <span class="link__title">Partenaire<span class="icon-arrow-next"></span></span>
# </a>
# </li>
# <li class="menu__item">
# <a aria-haspopup="true" class="menu__link has-dropdown" data-engagement-tracking-analytics="nav_L1: Ã propos de" data-index="6" href="/france/about.html" target="_self">
# <span class="link__title"> Ã propos de<span class="icon-arrow-next"></span></span>
# </a>
# </li>
# <li class="menu__item">
# <a aria-haspopup="true" class="menu__link has-dropdown" data-engagement-tracking-analytics="nav_L1:COVID-19" data-index="7" href="/france/covid-19.html" target="_self">
# <span class="link__title">COVID-19<span class="icon-arrow-next"></span></span>
# </a>
# </li>
# </ul>
# <div class="dropdown menu__dropdown">
# <div class="dropdown__content hidden" data-index="0">
# <div class="dropdown__section dropdown__section--three-columns">
# <ul class="dropdown__nav-area list-unstyled nav-area--three-columns with-deep-link">
# <li class="dropdown__nav-block mobile-link nav-block--back">
# <button class="button dropdown__button button-back" tabindex="0" type="button">
# <span class="icon-arrow-prev button__icon"></span>
# <span class="button__title">Produits</span>
# </button>
# </li>
# <li class="dropdown__nav-block mobile-link nav-block--back">
# <a class="nav-block__title dropdown__link" data-engagement-tracking-analytics="nav_L2:Vue d'ensemble" href="/france/products.html" target="_self">
# Vue d'ensemble
# </a>
# </li>
# <li class="dropdown__nav-block">
# <p class="nav-block__title" tabindex="0">
# <a class="dropdown__link" data-engagement-tracking-analytics="nav_L2:ERP et finance" href="/france/products/erp-financial-management.html" target="_self">
# ERP et finance
# <span class="icon-arrow-next"></span>
# </a>
# </p>
# <ul class="nav-block__list list-unstyled">
# <li class="nav-block__item mobile-link nav-block__item--back">
# <button class="button button dropdown__button button-back" tabindex="0" type="button">
# <span class="icon-arrow-prev button__icon"></span>
# <span class="button__title">ERP et finance</span>
# </button>
# </li>
# <li class="nav-block__item mobile-link">
# <a class="nav-block__link dropdown__link" data-engagement-tracking-analytics="nav_L2:PrÃ©sentation" href="/france/products/erp-financial-management.html" target="_self">
# Vue d'ensemble
# </a>
# </li>
# <li class="nav-block__item">
# <a class="nav-block__link dropdown__link" data-engagement-tracking-analytics="nav_L3:SAP S/4HANA" href="/france/products/s4hana-erp.html" target="_self">
# SAP S/4HANA
# </a>
# </li>
# <li class="nav-block__item">
# <a class="nav-block__link dropdown__link" data-engagement-tracking-analytics="nav_L3:ERP pour PME et ETI" href="/france/products/erp-financial-management/small-business-erp.html" target="_self">
# ERP pour PME et ETI
# </a>
# </li>
# <li class="nav-block__item">
# <a class="nav-block__link dropdown__link" data-engagement-tracking-analytics="nav_L3:ERP pour la fonction Finance" href="/france/products/erp-financial-management/financial-planning-analysis-fpa.html" target="_self">
# ERP pour la fonction Finance
# </a>
# </li>
# <li class="nav-block__item">
# <a class="nav-block__link dropdown__link" data-engagement-tracking-analytics="nav_L3:ComptabilitÃ©, clÃ´ture financiÃ¨re et gestion des taxes" href="/france/products/erp-financial-management/accounting-financial-close.html" target="_self">
# ComptabilitÃ©, clÃ´ture financiÃ¨re et gestion des taxes
# </a>
# </li>
# <li class="nav-block__item">
# <a class="nav-block__link dropdown__link" data-engagement-tracking-analytics="nav_L3:SystÃ¨me de gestion de la trÃ©sorerie" href="/france/products/erp-financial-management/treasury-management.html" target="_self">
# SystÃ¨me de gestion de la trÃ©sorerie
# </a>
# </li>
# <li class="nav-block__item">
# <a class="nav-block__link dropdown__link" data-engagement-tracking-analytics="nav_L3:ComptabilitÃ© clients et fournisseurs" href="/france/products/erp-financial-management/accounts-receivable-billing.html" target="_self">
# ComptabilitÃ© clients et fournisseurs
# </a>
# </li>
# <li class="nav-block__item">
# <a class="nav-block__link dropdown__link" data-engagement-tracking-analytics="nav_L3:Gouvernance, risque, conformitÃ© (GRC) et cybersÃ©curitÃ©" href="/france/products/erp-financial-management/grc.html" target="_self">
# Gouvernance, risque, conformitÃ© (GRC) et cybersÃ©curitÃ©
# </a>
# </li>
# </ul>
# </li>
# <li class="dropdown__nav-block">
# <p class="nav-block__title" tabindex="0">
# <a class="dropdown__link" data-engagement-tracking-analytics="nav_L2:Gestion de la relation client et expÃ©rience client" href="/france/products/crm.html" target="_self">
# Gestion de la relation client et expÃ©rience client
# <span class="icon-arrow-next"></span>
# </a>
# </p>
# <ul class="nav-block__list list-unstyled">
# <li class="nav-block__item mobile-link nav-block__item--back">
# <button class="button button dropdown__button button-back" tabindex="0" type="button">
# <span class="icon-arrow-prev button__icon"></span>
# <span class="button__title">Gestion de la relation client et expÃ©rience client</span>
# </button>
# </li>
# <li class="nav-block__item mobile-link">
# <a class="nav-block__link dropdown__link" data-engagement-tracking-analytics="nav_L2:PrÃ©sentation" href="/france/products/crm.html" target="_self">
# Vue d'ensemble
# </a>
# </li>
# <li class="nav-block__item">
# <a class="nav-block__link dropdown__link" data-engagement-tracking-analytics="nav_L3:DonnÃ©es clients" href="/france/products/crm/customer-data-management.html" target="_self">
# DonnÃ©es clients
# </a>
# </li>
# <li class="nav-block__item">
# <a class="nav-block__link dropdown__link" data-engagement-tracking-analytics="nav_L3:Marketing" href="/france/products/crm/marketing.html" target="_self">
# Marketing
# </a>
# </li>
# <li class="nav-block__item">
# <a class="nav-block__link dropdown__link" data-engagement-tracking-analytics="nav_L3:Commerce" href="/france/products/crm/e-commerce-platforms.html" target="_self">
# Commerce
# </a>
# </li>
# <li class="nav-block__item">
# <a class="nav-block__link dropdown__link" data-engagement-tracking-analytics="nav_L3:Ventes" href="/france/products/crm/sales.html" target="_self">
# Ventes
# </a>
# </li>
# <li class="nav-block__item">
# <a class="nav-block__link dropdown__link" data-engagement-tracking-analytics="nav_L3:Service" href="/france/products/crm/customer-service.html" target="_self">
# Service
# </a>
# </li>
# </ul>
# </li>
# <li class="dropdown__nav-block">
# <p class="nav-block__title" tabindex="0">
# <a class="dropdown__link" data-engagement-tracking-analytics="nav_L2:RÃ©seau et gestion des dÃ©penses" href="/france/products/e-procurement.html" target="_self">
# RÃ©seau et gestion des dÃ©penses
# <span class="icon-arrow-next"></span>
# </a>
# </p>
# <ul class="nav-block__list list-unstyled">
# <li class="nav-block__item mobile-link nav-block__item--back">
# <button class="button button dropdown__button button-back" tabindex="0" type="button">
# <span class="icon-arrow-prev button__icon"></span>
# <span class="button__title">RÃ©seau et gestion des dÃ©penses</span>
# </button>
# </li>
# <li class="nav-block__item mobile-link">
# <a class="nav-block__link dropdown__link" data-engagement-tracking-analytics="nav_L2:PrÃ©sentation" href="/france/products/e-procurement.html" target="_self">
# Vue d'ensemble
# </a>
# </li>
# <li class="nav-block__item">
# <a class="nav-block__link dropdown__link" data-engagement-tracking-analytics="nav_L3:Gestion des fournisseurs" href="/france/products/e-procurement/supplier-management.html" target="_self">
# Gestion des fournisseurs
# </a>
# </li>
# <li class="nav-block__item">
# <a class="nav-block__link dropdown__link" data-engagement-tracking-analytics="nav_L3:Strategic Sourcing" href="/france/products/e-procurement/strategic-sourcing.html" target="_self">
# Strategic Sourcing
# </a>
# </li>
# <li class="nav-block__item">
# <a class="nav-block__link dropdown__link" data-engagement-tracking-analytics="nav_L3:Achats" href="/france/products/e-procurement/procurement.html" target="_self">
# Achats
# </a>
# </li>
# <li class="nav-block__item">
# <a class="nav-block__link dropdown__link" data-engagement-tracking-analytics="nav_L3:Achat de services et force de travail temporaire" href="/france/products/e-procurement/contingent-workforce.html" target="_self">
# Achat de services et force de travail temporaire
# </a>
# </li>
# <li class="nav-block__item">
# <a class="nav-block__link dropdown__link" data-engagement-tracking-analytics="nav_L3:Vente et traitement" href="/france/products/e-procurement/selling-fulfillment.html" target="_self">
# Vente et traitement
# </a>
# </li>
# <li class="nav-block__item">
# <a class="nav-block__link dropdown__link" data-engagement-tracking-analytics="nav_L3:DÃ©placements et notes de frais" href="/france/products/e-procurement/travel-expense-management.html" target="_self">
# DÃ©placements et notes de frais
# </a>
# </li>
# </ul>
# </li>
# <li class="dropdown__nav-block">
# <p class="nav-block__title" tabindex="0">
# <a class="dropdown__link" data-engagement-tracking-analytics="nav_L2:Gestion de la chaÃ®ne logistique" href="/france/products/supply-chain-management.html" target="_self">
# Gestion de la chaÃ®ne logistique
# <span class="icon-arrow-next"></span>
# </a>
# </p>
# <ul class="nav-block__list list-unstyled">
# <li class="nav-block__item mobile-link nav-block__item--back">
# <button class="button button dropdown__button button-back" tabindex="0" type="button">
# <span class="icon-arrow-prev button__icon"></span>
# <span class="button__title">Gestion de la chaÃ®ne logistique</span>
# </button>
# </li>
# <li class="nav-block__item mobile-link">
# <a class="nav-block__link dropdown__link" data-engagement-tracking-analytics="nav_L2:PrÃ©sentation" href="/france/products/supply-chain-management.html" target="_self">
# Vue d'ensemble
# </a>
# </li>
# <li class="nav-block__item">
# <a class="nav-block__link dropdown__link" data-engagement-tracking-analytics="nav_L3:Planification de la supply chain" href="/france/products/supply-chain-management/supply-chain-planning.html" target="_self">
# Planification de la supply chain
# </a>
# </li>
# <li class="nav-block__item">
# <a class="nav-block__link dropdown__link" data-engagement-tracking-analytics="nav_L3:Logistique de la supply chain" href="/france/products/supply-chain-management/supply-chain-logistics.html" target="_self">
# Logistique de la supply chain
# </a>
# </li>
# <li class="nav-block__item">
# <a class="nav-block__link dropdown__link" data-engagement-tracking-analytics="nav_L3:Production" href="/france/products/supply-chain-management/manufacturing.html" target="_self">
# Production
# </a>
# </li>
# <li class="nav-block__item">
# <a class="nav-block__link dropdown__link" data-engagement-tracking-analytics="nav_L3:Gestion du cycle de vie des produits" href="/france/products/supply-chain-management/plm-r-d-engineering.html" target="_self">
# Gestion du cycle de vie des produits
# </a>
# </li>
# <li class="nav-block__item">
# <a class="nav-block__link dropdown__link" data-engagement-tracking-analytics="nav_L3:Gestion des immobilisations d'entreprise" href="/france/products/supply-chain-management/asset-management-eam.html" target="_self">
# Gestion des immobilisations d'entreprise
# </a>
# </li>
# </ul>
# </li>
# <li class="dropdown__nav-block">
# <p class="nav-block__title" tabindex="0">
# <a class="dropdown__link" data-engagement-tracking-analytics="nav_L2:RH et implication du personnel" href="/france/products/human-resources-hcm.html" target="_self">
# RH et implication du personnel
# <span class="icon-arrow-next"></span>
# </a>
# </p>
# <ul class="nav-block__list list-unstyled">
# <li class="nav-block__item mobile-link nav-block__item--back">
# <button class="button button dropdown__button button-back" tabindex="0" type="button">
# <span class="icon-arrow-prev button__icon"></span>
# <span class="button__title">RH et implication du personnel</span>
# </button>
# </li>
# <li class="nav-block__item mobile-link">
# <a class="nav-block__link dropdown__link" data-engagement-tracking-analytics="nav_L2:PrÃ©sentation" href="/france/products/human-resources-hcm.html" target="_self">
# Vue d'ensemble
# </a>
# </li>
# <li class="nav-block__item">
# <a class="nav-block__link dropdown__link" data-engagement-tracking-analytics="nav_L3:Gestion de l'expÃ©rience collaborateur" href="/france/products/human-resources-hcm/employee-experience-management.html" target="_self">
# Gestion de l'expÃ©rience collaborateur
# </a>
# </li>
# <li class="nav-block__item">
# <a class="nav-block__link dropdown__link" data-engagement-tracking-analytics="nav_L3:Gestion des RH et de la paie" href="/france/products/human-resources-hcm/core-hr-payroll.html" target="_self">
# Gestion des RH et de la paie
# </a>
# </li>
# <li class="nav-block__item">
# <a class="nav-block__link dropdown__link" data-engagement-tracking-analytics="nav_L3:Gestion des talents" href="/france/products/human-resources-hcm/talent-management.html" target="_self">
# Gestion des talents
# </a>
# </li>
# <li class="nav-block__item">
# <a class="nav-block__link dropdown__link" data-engagement-tracking-analytics="nav_L3:Outils d'analyse RH et gestion du personnel" href="/france/products/human-resources-hcm/workforce-planning-hr-analytics.html" target="_self">
# Outils d'analyse RH et gestion du personnel
# </a>
# </li>
# </ul>
# </li>
# <li class="dropdown__nav-block">
# <p class="nav-block__title" tabindex="0">
# <a class="dropdown__link" data-engagement-tracking-analytics="nav_L2:Business Technology Platform" href="/france/products/business-technology-platform.html" target="_self">
# Business Technology Platform
# <span class="icon-arrow-next"></span>
# </a>
# </p>
# <ul class="nav-block__list list-unstyled">
# <li class="nav-block__item mobile-link nav-block__item--back">
# <button class="button button dropdown__button button-back" tabindex="0" type="button">
# <span class="icon-arrow-prev button__icon"></span>
# <span class="button__title">Business Technology Platform</span>
# </button>
# </li>
# <li class="nav-block__item mobile-link">
# <a class="nav-block__link dropdown__link" data-engagement-tracking-analytics="nav_L2:" href="/france/products/business-technology-platform.html" target="_self">
# Vue d'ensemble
# </a>
# </li>
# <li class="nav-block__item">
# <a class="nav-block__link dropdown__link" data-engagement-tracking-analytics="nav_L3:Gestion des donnÃ©es et bases de donnÃ©es" href="/france/products/database-data-management.html" target="_self">
# Gestion des donnÃ©es et bases de donnÃ©es
# </a>
# </li>
# <li class="nav-block__item">
# <a class="nav-block__link dropdown__link" data-engagement-tracking-analytics="nav_L3:DÃ©veloppement et intÃ©gration d'applications" href="/france/products/application-development-integration.html" target="_self">
# DÃ©veloppement et intÃ©gration d'applications
# </a>
# </li>
# <li class="nav-block__item">
# <a class="nav-block__link dropdown__link" data-engagement-tracking-analytics="nav_L3:Analytics (outils d'analyse)" href="/france/products/analytics.html" target="_self">
# Analytics (outils d'analyse)
# </a>
# </li>
# <li class="nav-block__item">
# <a class="nav-block__link dropdown__link" data-engagement-tracking-analytics="nav_L3:Technologies intelligentes" href="/france/products/intelligent-technologies.html" target="_self">
# Technologies intelligentes
# </a>
# </li>
# </ul>
# </li>
# <li class="dropdown__side-panel-opener">
# <button class="button side-panel-opener" tabindex="0" type="button">Zoom sur...
# <span class="icon-arrow-next"></span>
# </button>
# </li>
# <li class="dropdown__nav-block mobile-link nav-block--back">
# <p class="nav-block__title" tabindex="0">
# <a class="dropdown__link" data-engagement-tracking-analytics="nav_L2:Explorez tous les produits deÂ A Ã Â Z" href="/france/products-a-z.html" target="_self">
# Explorez tous les produits deÂ A Ã Â Z
# </a>
# </p>
# </li>
# </ul>
# <div class="dropdown__nav-block-deep-link">
# <p class="nav-block__title" tabindex="0">
# <a class="dropdown__link" data-engagement-tracking-analytics="nav_L2:Explorez tous les produits deÂ A Ã Â Z" href="/france/products-a-z.html" target="_self">
# Explorez tous les produits deÂ A Ã Â Z
# <span class="icon-arrow-next"></span>
# </a>
# </p>
# </div>
# </div>
# <ul class="side-panel list-unstyled side-panel--three-columns">
# <li class="side-panel__item--back">
# <button class="button button-back" tabindex="0" type="button">
# <span class="icon-arrow-prev"></span>
# <span class="button__title">Zoom sur...</span>
# </button>
# </li>
# <li class="side-panel__item">
# <a class="side-panel__link" data-engagement-tracking-analytics="nav_sidebar:L'entreprise intelligente" href="/france/products/intelligent-enterprise.html">
# <div class="side-panel__icon">
# <img alt="" class="lazy svg-image" data-src="/dam/application/imagelibrary/pictograms/281000/281100-pictogram-neg-orange.svg.adapt.svg/1491343788997.svg" src="..."/>
# </div>
# <p class="side-panel__title">L'entreprise intelligente</p>
# </a>
# </li>
# <li class="side-panel__item">
# <a class="side-panel__link" data-engagement-tracking-analytics="nav_sidebar:Gestion de l'expÃ©rience" href="/france/products/experience-management-xm.html">
# <div class="side-panel__icon">
# <img alt="" class="lazy svg-image" data-src="/dam/application/imagelibrary/pictograms/283000/283060-pictogram-neg-orange.svg.adapt.svg/1513371421811.svg" src="..."/>
# </div>
# <p class="side-panel__title">Gestion de l'expÃ©rience</p>
# </a>
# </li>
# <li class="side-panel__item">
# <a class="side-panel__link" data-engagement-tracking-analytics="nav_sidebar:IndustrieÂ 4.0" href="/france/products/supply-chain-management/industry-4-0.html" target="_self">
# <div class="side-panel__icon">
# <img alt="" class="lazy svg-image" data-src="/dam/application/imagelibrary/pictograms/281000/281433-pictogram-neg-orange.svg.adapt.svg/1491344304636.svg" src="..."/>
# </div>
# <p class="side-panel__title">IndustrieÂ 4.0</p>
# </a>
# </li>
# <li class="side-panel__item">
# <a class="side-panel__link" data-engagement-tracking-analytics="nav_sidebar:PME/ETI" href="/france/products/sme-business-software.html">
# <div class="side-panel__icon">
# <img alt="" class="lazy svg-image" data-src="/dam/application/imagelibrary/pictograms/281000/281531-pictogram-neg-orange.svg.adapt.svg/1491344507312.svg" src="..."/>
# </div>
# <p class="side-panel__title">PME/ETI</p>
# </a>
# </li>
# <li class="side-panel__item">
# <a class="side-panel__link" data-engagement-tracking-analytics="nav_sidebar:Tendances technologiques" href="/france/trends.html" target="_self">
# <div class="side-panel__icon">
# <img alt="" class="lazy svg-image" data-src="/dam/application/imagelibrary/pictograms/284000/284166-pictogram-neg-orange.svg.adapt.svg/1537563824535.svg" src="..."/>
# </div>
# <p class="side-panel__title">Tendances technologiques</p>
# </a>
# </li>
# <li class="side-panel__item side-panel__item--after-more side-panel__title--more">
# <a class="side-panel__link" data-engagement-tracking-analytics="nav_sidebar:Plus..." href="/france/trends.html" target="_self">
# <p class="side-panel__title">Plus...</p>
# </a>
# </li>
# </ul>
# </div>
# <div class="dropdown__content hidden" data-index="1">
# <div class="dropdown__section dropdown__section--three-columns">
# <ul class="dropdown__nav-area list-unstyled nav-area--three-columns">
# <li class="dropdown__nav-block mobile-link nav-block--back">
# <button class="button dropdown__button button-back" tabindex="0" type="button">
# <span class="icon-arrow-prev button__icon"></span>
# <span class="button__title">Industries</span>
# </button>
# </li>
# <li class="dropdown__nav-block mobile-link nav-block--back">
# <a class="nav-block__title dropdown__link" data-engagement-tracking-analytics="nav_L2:Vue d'ensemble" href="/france/industries.html" target="_self">
# Vue d'ensemble
# </a>
# </li>
# <li class="dropdown__nav-block">
# <p class="nav-block__title" tabindex="0">
# Ãnergie et ressources naturelles
# <span class="icon-arrow-next"></span>
# </p>
# <ul class="nav-block__list list-unstyled">
# <li class="nav-block__item mobile-link nav-block__item--back">
# <button class="button button dropdown__button button-back" tabindex="0" type="button">
# <span class="icon-arrow-prev button__icon"></span>
# <span class="button__title">Ãnergie et ressources naturelles</span>
# </button>
# </li>
# <li class="nav-block__item">
# <a class="nav-block__link dropdown__link" data-engagement-tracking-analytics="nav_L3:Produits de construction" href="/france/industries/building-products.html" target="_self">
# Produits de construction
# </a>
# </li>
# <li class="nav-block__item">
# <a class="nav-block__link dropdown__link" data-engagement-tracking-analytics="nav_L3:Industrie chimique" href="/france/industries/chemicals.html" target="_self">
# Industrie chimique
# </a>
# </li>
# <li class="nav-block__item">
# <a class="nav-block__link dropdown__link" data-engagement-tracking-analytics="nav_L3:Industries de transformation" href="/france/industries/mill-products.html" target="_self">
# Industries de transformation
# </a>
# </li>
# <li class="nav-block__item">
# <a class="nav-block__link dropdown__link" data-engagement-tracking-analytics="nav_L3:Exploitation miniÃ¨re " href="/france/industries/mining.html" target="_self">
# Exploitation miniÃ¨re
# </a>
# </li>
# <li class="nav-block__item">
# <a class="nav-block__link dropdown__link" data-engagement-tracking-analytics="nav_L3:Industrie des hydrocarbures" href="/france/industries/oil-gas.html" target="_self">
# Industrie des hydrocarbures
# </a>
# </li>
# <li class="nav-block__item">
# <a class="nav-block__link dropdown__link" data-engagement-tracking-analytics="nav_L3:Eau et Ã©nergie" href="/france/industries/energy-utilities.html" target="_self">
# Eau et Ã©nergie
# </a>
# </li>
# </ul>
# </li>
# <li class="dropdown__nav-block">
# <p class="nav-block__title" tabindex="0">
# Banque &amp; assurance
# <span class="icon-arrow-next"></span>
# </p>
# <ul class="nav-block__list list-unstyled">
# <li class="nav-block__item mobile-link nav-block__item--back">
# <button class="button button dropdown__button button-back" tabindex="0" type="button">
# <span class="icon-arrow-prev button__icon"></span>
# <span class="button__title">Banque &amp; assurance</span>
# </button>
# </li>
# <li class="nav-block__item">
# <a class="nav-block__link dropdown__link" data-engagement-tracking-analytics="nav_L3:Banque" href="/france/industries/banking.html" target="_self">
# Banque
# </a>
# </li>
# <li class="nav-block__item">
# <a class="nav-block__link dropdown__link" data-engagement-tracking-analytics="nav_L3:Assurance " href="/france/industries/insurance.html" target="_self">
# Assurance
# </a>
# </li>
# </ul>
# </li>
# <li class="dropdown__nav-block">
# <p class="nav-block__title" tabindex="0">
# Secteur des biens de consommation
# <span class="icon-arrow-next"></span>
# </p>
# <ul class="nav-block__list list-unstyled">
# <li class="nav-block__item mobile-link nav-block__item--back">
# <button class="button button dropdown__button button-back" tabindex="0" type="button">
# <span class="icon-arrow-prev button__icon"></span>
# <span class="button__title">Secteur des biens de consommation</span>
# </button>
# </li>
# <li class="nav-block__item">
# <a class="nav-block__link dropdown__link" data-engagement-tracking-analytics="nav_L3:SociÃ©tÃ©s agro-alimentaires" href="/france/industries/agribusiness.html" target="_self">
# SociÃ©tÃ©s agro-alimentaires
# </a>
# </li>
# <li class="nav-block__item">
# <a class="nav-block__link dropdown__link" data-engagement-tracking-analytics="nav_L3:Biens de consommation" href="/france/industries/consumer-goods-cpg.html" target="_self">
# Biens de consommation
# </a>
# </li>
# <li class="nav-block__item">
# <a class="nav-block__link dropdown__link" data-engagement-tracking-analytics="nav_L3:Mode" href="/france/industries/fashion-apparel.html" target="_self">
# Mode
# </a>
# </li>
# <li class="nav-block__item">
# <a class="nav-block__link dropdown__link" data-engagement-tracking-analytics="nav_L3:Sciences de la vie" href="/france/industries/life-sciences.html" target="_self">
# Sciences de la vie
# </a>
# </li>
# <li class="nav-block__item">
# <a class="nav-block__link dropdown__link" data-engagement-tracking-analytics="nav_L3:Retail" href="/france/industries/retail.html" target="_self">
# Retail
# </a>
# </li>
# <li class="nav-block__item">
# <a class="nav-block__link dropdown__link" data-engagement-tracking-analytics="nav_L3:NÃ©goce" href="/france/industries/wholesale-distribution.html" target="_self">
# NÃ©goce
# </a>
# </li>
# </ul>
# </li>
# <li class="dropdown__nav-block">
# <p class="nav-block__title" tabindex="0">
# Industries manufacturiÃ¨res
# <span class="icon-arrow-next"></span>
# </p>
# <ul class="nav-block__list list-unstyled">
# <li class="nav-block__item mobile-link nav-block__item--back">
# <button class="button button dropdown__button button-back" tabindex="0" type="button">
# <span class="icon-arrow-prev button__icon"></span>
# <span class="button__title">Industries manufacturiÃ¨res</span>
# </button>
# </li>
# <li class="nav-block__item">
# <a class="nav-block__link dropdown__link" data-engagement-tracking-analytics="nav_L3:AÃ©ronautique et dÃ©fense" href="/france/industries/aerospace-defense.html" target="_self">
# AÃ©ronautique et dÃ©fense
# </a>
# </li>
# <li class="nav-block__item">
# <a class="nav-block__link dropdown__link" data-engagement-tracking-analytics="nav_L3:Automobile" href="/france/industries/automotive.html" target="_self">
# Automobile
# </a>
# </li>
# <li class="nav-block__item">
# <a class="nav-block__link dropdown__link" data-engagement-tracking-analytics="nav_L3:High-tech" href="/france/industries/high-tech.html" target="_self">
# High-tech
# </a>
# </li>
# <li class="nav-block__item">
# <a class="nav-block__link dropdown__link" data-engagement-tracking-analytics="nav_L3:Equipements industriels" href="/france/industries/industrial-manufacturing.html" target="_self">
# Equipements industriels
# </a>
# </li>
# </ul>
# </li>
# <li class="dropdown__nav-block">
# <p class="nav-block__title" tabindex="0">
# Secteurs du tertiaire
# <span class="icon-arrow-next"></span>
# </p>
# <ul class="nav-block__list list-unstyled">
# <li class="nav-block__item mobile-link nav-block__item--back">
# <button class="button button dropdown__button button-back" tabindex="0" type="button">
# <span class="icon-arrow-prev button__icon"></span>
# <span class="button__title">Secteurs du tertiaire</span>
# </button>
# </li>
# <li class="nav-block__item">
# <a class="nav-block__link dropdown__link" data-engagement-tracking-analytics="nav_L3:Services logistiques et transport" href="/france/industries/cargo-transportation-logistics.html" target="_self">
# Services logistiques et transport
# </a>
# </li>
# <li class="nav-block__item">
# <a class="nav-block__link dropdown__link" data-engagement-tracking-analytics="nav_L3:BÃ¢timent et travaux publics" href="/france/industries/engineering-construction-management.html" target="_self">
# BÃ¢timent et travaux publics
# </a>
# </li>
# <li class="nav-block__item">
# <a class="nav-block__link dropdown__link" data-engagement-tracking-analytics="nav_L3:MÃ©dias" href="/france/industries/media.html" target="_self">
# MÃ©dias
# </a>
# </li>
# <li class="nav-block__item">
# <a class="nav-block__link dropdown__link" data-engagement-tracking-analytics="nav_L3:Transport de passagers et loisirs" href="/france/industries/passenger-travel-leisure.html" target="_self">
# Transport de passagers et loisirs
# </a>
# </li>
# <li class="nav-block__item">
# <a class="nav-block__link dropdown__link" data-engagement-tracking-analytics="nav_L3:Services professionnels" href="/france/industries/professional-services.html" target="_self">
# Services professionnels
# </a>
# </li>
# <li class="nav-block__item">
# <a class="nav-block__link dropdown__link" data-engagement-tracking-analytics="nav_L3:Sports et loisirs" href="/france/industries/sports-entertainment.html" target="_self">
# Sports et loisirs
# </a>
# </li>
# <li class="nav-block__item">
# <a class="nav-block__link dropdown__link" data-engagement-tracking-analytics="nav_L3:TÃ©lÃ©communications" href="/france/industries/telecommunications.html" target="_self">
# TÃ©lÃ©communications
# </a>
# </li>
# </ul>
# </li>
# <li class="dropdown__nav-block">
# <p class="nav-block__title" tabindex="0">
# Services publics
# <span class="icon-arrow-next"></span>
# </p>
# <ul class="nav-block__list list-unstyled">
# <li class="nav-block__item mobile-link nav-block__item--back">
# <button class="button button dropdown__button button-back" tabindex="0" type="button">
# <span class="icon-arrow-prev button__icon"></span>
# <span class="button__title">Services publics</span>
# </button>
# </li>
# <li class="nav-block__item">
# <a class="nav-block__link dropdown__link" data-engagement-tracking-analytics="nav_L3:DÃ©fense et sÃ©curitÃ©" href="/france/industries/defense-security.html" target="_self">
# DÃ©fense et sÃ©curitÃ©
# </a>
# </li>
# <li class="nav-block__item">
# ...
#                 <div class="footer-container grid-container">
#                     <div class="row">
#                         <div class="col-xs-7 col-sm-12 col-md-12 col-lg-12">
#                             <div class="info-container">
#                                 <div class="he footer-headine">{{assetFooterTitle}}</div>
#                                 <div class="text footer-paragraph">{{assetFooterDescription}}</div>
#                             </div>
#                         </div>
#                         <div class="btn-wrapper col-xs-5 col-sm-5 col-md-5 col-lg-5">
#                             {{#if assetFooterLinkName}}
#                                 <a href="{{assetFooterLinkPath}}" target="{{assetFooterLinkTarget}}"
#                                    title="{{assetFooterLinkTooltip}}" class="button2017 version1 lightbox-footer-link">
#                                     <span class="buttonText">{{assetFooterLinkName}}</span>
#                                     <span class="hoverboxes"><span class="hoverbox"></span><span
#                                             class="hoverbox"></span><span class="hoverbox"></span></span>
#                                 </a>
#                             {{/if}}
#                         </div>
#                     </div>
#                 </div>
#                 {{/if}}
#             </div>
#         </div>
#     </div>
# </script>
# <script class="feedbackLightbox" type="text/x-handlebars-template">
#     <div class="lightboxPopup lightboxFeedback" id="openPopup">
#         <div class="wrapper">
#             <div class="header">
#                 <div class="title he">{{assetTitle}}</div>
#                 <div class="toolbtn exit icon-close mfp-close"></div>
#             </div>
#             <div class="popupContent">
#                 {{{popupContent}}}
#             </div>
#         </div>
#     </div>
# </script>
# <script class="videoElementLightbox" type="text/x-handlebars-template">
#     <div class="videoWrapper lightBoxVideoWrapper mfp-hide" data-light-box-type="video" data-asset-title="{{title}}" data-asset-description="{{description}}">
#         <div class="topDiv"></div>
#         <video class="video-js vjs-default-skin vjs-big-play-centered vjs-fluid"
#                controls="true"
#                preload="none"
#                data-publishingdate="{{publishingDate}}"
#                data-expirationdate="{{expirationDate}}"
#                data-title="{{videoTitle}}"
#                poster="{{poster}}"
#                data-akamaiUrl="{{akamaiUrl}}"
#                data-akamaiMobileUrl="{{akamaiMobileUrl}}"
#                data-analyticsAssetId="{{analyticsAssetId}}"
#                data-sap-digital-id="{{sap_digital_id}}"
#                data-crm-code="{{crmCode}}"
#                data-is-stream="{{streamVideo}}"
#                data-is-youtube="{{isYoutubeURI}}"
#                data-is-lightbox="true"
#                data-dam-link="{{damLink}}"
#                data-asset-id="{{id}}"
#                data-video-setup="{{videoSetup}}">
#             <source src="{{source.src}}" type="{{source.type}}"/>
#         </video>
#     </div>
# </script>
# <script class="integrationReportLightbox" type="text/x-handlebars-template">
#     <div class="lightboxPopup" id="openPopup">
#         <section>
#             <div class="loadingBar">
#                 <div class="bar bar-first"></div>
#                 <div class="bar bar-second"></div>
#                 <div class="bar bar-third"></div>
#             </div>
#         </section>
#         <div class="lightboxContainer">
#             <div class="toolbtn exit icon-close mfp-close"></div>
#             <div class="aside-lightbox">
#                 <div class="toolbtn exit icon-close mfp-close"></div>
#                 <div class="popupHeader">
#                     <div class="header-container grid-container">
#                         <div class="row">
#                             <div class="col-xs-11 col-sm-10 col-md-10 col-lg-10">
#                                 <div class="sectionTitle he">{{assetTitle}}</div>
#                                 <div class="descriptionText text">{{assetDescription}}</div>
#                             </div>
#                         </div>
#                     </div>
#                     <div class="toolbar-container">
#                         <nav class="toolbar">
#                             <ul class="toolbar-list">
#                                 <li><a id="download-link" class="toolbtn download icon-download exclude-ligthbox-handler"></a></li>
#                                 <li><a class="toolbtn mail icon-email exclude-ligthbox-handler" data-share-tracking-analytics="SHARE" data-share-channel="mailto"></a></li>
#                                 <li class="share-wrap"><a class="toolbtn share icon-share"></a>
#                                     <ul class="share-dropdown">
#                                         {{#each socialItems}}
#                                         <li>
#                                             <a class="{{shareClass}}" title="{{title}}" data-share-channel="{{share-channel}}" data-share-tracking-analytics="SHARE" target="_blank"
#                                                data-share-url="{{resourceLink}}"><span class="{{class}}"></span>{{title}}</a>
#                                         </li>
#                                         {{/each }}
#                                     </ul>
#                                 </li>
#                             </ul>
#                         </nav>
#                     </div>
#                      <div class="search-toc-container">
#                         <div class="content-btn_mobile">
#                             <span class="icon-menu"></span>
#                             <span class="content-label">Sommaire</span>
#                         </div>
#                         <div class="search-form">
#                             <form class="search__form" action="#">
#                                 <div class="search__holder">
#                                     <div class="search__field">
#                                         <input class="search__input" type="text" name="searchInput"
#                                                placeholder="Rechercher" autocomplete="off">
#                                         <span class="search__icon icon-search">
#                                             <input type="submit" class="search__btn">
#                                         </span>
#                                         <span class="clear-search-btn"><span class="icon-close"></span></span>
#                                     </div>
#                                 </div>
#                             </form>
#                             <div class="matches__holder">
#                                 <div class="search-results-control">
#                                     <span class="overall__matches"></span>
#                                     <span class="find-arrow find__prev icon-arrowleft"></span>
#                                     <span class="find-arrow find__next icon-arrowright"></span>
#                                 </div>
#                                 <div class="entries"><span class="num__count"></span></div>
#                             </div>
#                         </div>
#                      </div>
#                 </div>
#                 <div class="outlinePanel jcf-scrollable" data-jcf='{"handleResize": false}'>
#                     <h2 class="hd outline-headline">Sommaire</h2>
#                     <ul class="outline-tree"></ul>
#                 </div>
#                 <div class="popupFooter">
#                     <div class="fullscreen-control">Plein Ã©cran<a href="#" class="fullscreen-link"><span
#                                 class="icon-fullscreen"></span></a></div>
#                     <div class="zoom-control"><span class="zoom-control__label">Zoom</span><a href="#" class="zoomOut"><span class="icon-zoomOut"></span></a><a href="#" class="zoomIn"><span class="icon-zoomIn"></span></a></div>
#                 </div>
#             </div>
#             <div class="popupContent jcf-scrollable">
#                 {{{popupContent}}}
#             </div>
#         </div>
#     </div>
# </script>
# <script class="compatibilityLightbox" type="text/x-handlebars-template">
#     <div class="lightboxPopup lightboxCompatibility" id="openPopup">
#         <div class="wrapper">
#             <div class="header">
#                 <div class="title he">{{compatibilityTitle}}</div>
#                 <div class="toolbtn exit icon-close mfp-close"></div>
#             </div>
#             <div class="popupContent">
#                 <div class="compatibility-wrapper">
#                     <div class="compatibility-content">
#                         <div class="compatibility-headline">
#                             {{compatibilityHeadline}}
#                         </div>
#                         <div class="compatibility-body">
#                             {{compatibilityContent}}
#                         </div>
#                         <div class="compatibility-button-wrapper">
#                             <a class="compatibility-button button2017 version1">
#                                 <span class="buttonText">{{compatibilityConfirmButton}}</span>
#                                 <span class="hoverboxes">
#                                     <span class="hoverbox"></span>
#                                     <span class="hoverbox"></span>
#                                     <span class="hoverbox"></span>
#                                 </span>
#                             </a>
#                         </div>
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
# </script>
# <script class="messageLightbox" type="text/x-handlebars-template">
#     <div class="popup-header">
#         <p class="title">{{headerMessage}}</p>
#         <button class="close-button" type="button">Ã</button>
#     </div>
#     <div class="popup-container">
#         {{> content}}
#         <div class="loading-bar-overlay">
#             <div class="loadingBar">
#                 <div class="bar bar-first"></div>
#                 <div class="bar bar-second"></div>
#                 <div class="bar bar-third"></div>
#             </div>
#         </div>
#     </div>
# </script>
# <script class="errorMessageContent" type="text/x-handlebars-template">
#     <div class="content-container content-partial content-fail-partial grid-container">
#         <div class="row">
#             <div class="col-lg-offset-1 col-lg-10 col-md-offset-1 col-md-10 col-sm-offset-1 col-sm-10 col-xs-12">
#                 <div class="standardText">
#                     <h1 class="header-title hd">{{failTitle}}</h1>
#                     <div class="content-block">
#                         <div class="body-text text">
#                             <p>{{errorMessage}}</p>
#                         </div>
#                         <div class="links-list">
#                             <ul class="links list-unstyled">
#                                 <li class="type-link">
#                                     <a class="button2017 version1 error-close-button" type="button" href="#">
#                                         <span class="buttonText">{{buttonTitle}}</span>
#                                         <span class="hoverboxes">
#                                             <span class="hoverbox"></span>
#                                             <span class="hoverbox"></span>
#                                             <span class="hoverbox"></span>
#                                         </span>
#                                     </a>
#                                 </li>
#                             </ul>
#                         </div>
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
# </script>
# <script class="html-content-lightbox" type="text/x-handlebars-template">
#     <div class="popupHeader">
#         {{#if isHeaderConfigured}}
#         <div class="header-container grid-container">
#             <div class="row">
#                 <div class="col-xs-11 col-sm-10 col-md-10 col-lg-10">
#                     <div class="sectionTitle he">{{assetTitle}}</div>
#                     <div class="descriptionText text">{{assetDescription}}</div>
#                 </div>
#             </div>
#         </div>
#         {{/if}}
#         <div class="toolbar-container">
#             {{#if isHeaderConfigured}}
#             {{#if isEnabledShareLink}}
#             <nav class="toolbar">
#                 <ul class="toolbar-list">
#                     <li><a class="toolbtn mail icon-email exclude-ligthbox-handler" data-share-tracking-analytics="SHARE" data-share-channel="mailto"></a></li>
#                     <li class="share-wrap"><a class="toolbtn share icon-share"></a>
#                         <ul class="share-dropdown">
#                             {{#each socialItems}}
#                             <li>
#                                 <a class="{{shareClass}}" title="{{title}}" data-share-channel="{{share-channel}}" data-share-tracking-analytics="SHARE" target="_blank"
#                                    data-share-url="{{resourceLink}}"><span class="{{class}}"></span>{{title}}</a>
#                             </li>
#                             {{/each }}
#                         </ul>
#                     </li>
#                 </ul>
#             </nav>
#             {{/if}}
#             {{/if}}
#             <div class="toolbtn exit icon-close mfp-close"></div>
#         </div>
#     </div>
#     <div class="popup-container">
#         <iframe
#             class="html-content-lightbox-frame"
#             src={{src}}
#             width='1100px' height='700px'>
#         </iframe>
#     </div>
#     <div class="popupFooter">
#         {{#if isFooterConfigured}}
#         <div class="footer-container grid-container">
#             <div class="row">
#                 <div class="col-xs-7 col-sm-12 col-md-12 col-lg-12">
#                     <div class="info-container">
#                         <div class="he footer-headine">{{assetFooterTitle}}</div>
#                         <div class="text footer-paragraph">{{assetFooterDescription}}</div>
#                     </div>
#                 </div>
#                 <div class="btn-wrapper col-xs-5 col-sm-5 col-md-5 col-lg-5">
#                     <a href="{{assetFooterLinkPath}}" target="{{assetFooterLinkTarget}}"
#                        title="{{assetFooterLinkTooltip}}" class="button2017 version1 lightbox-footer-link">
#                         <span class="buttonText">{{assetFooterLinkName}}</span>
#                         <span class="hoverboxes"><span class="hoverbox"></span><span
#                                 class="hoverbox"></span><span class="hoverbox"></span></span>
#                     </a>
#                 </div>
#             </div>
#         </div>
#         {{/if}}
#     </div>
# </script>
# <script defer="" src="/etc.clientlibs/sapdx/clientlibs/clientlib-ip-detection.min.925a92f8be4a5664c213186fab88093d.js" type="text/javascript"></script>
# <script defer="" src="/etc.clientlibs/sapdx/clientlibs/clientlib-product-grid2.min.c11065537c472d58a331741f33a591bb.js" type="text/javascript"></script>
# <script src="/etc.clientlibs/sapdx/ui/react/resources/static/react~static.791311bb90ad1bcd6691.js" type="text/javascript"></script>
# <script src="/etc.clientlibs/sapdx/ui/react/resources/static/vendors~static.8741f8e38bc7cfc91ec3.js" type="text/javascript"></script>
# <script>
#     try{
#         if (!!window._satellite) {
#             _satellite.pageBottom();
#         }
#     } catch(e) {
#         console.error("Error while calling _satellite.pageBottom(), Error thrown : " +  e);
#     }
# </script>
# <div class="call-popup" style="display:none">
# <div class="musthead">
# <h3 class="hd callme-title">Service de rappel</h3>
# <span class="popup-close ignore-draggable-intouch" role="button" title="Fermer"></span>
# <span class="popup-minimize ignore-draggable-intouch" role="button" title="RÃ©duire"></span>
# <span class="popup-maximize ignore-draggable-intouch" role="button" title="Agrandir"></span>
# </div>
# </div>
# </body>
# </html>

# %%
def getContent(soup):
    
    """ 
        Extracting the content of the article, whether in html or not
    """
    art_content_html = soup.find_all('div', class_="parContent")
    art_content = " ".join([x.text for x in art_content_html])
    #art_content = art_content.replace("\n", "").replace("\xa0", "")

    return art_content, art_content_html

# %%
getContent(soup)
# Out:
# ("\n\n\n\n\n\nIntÃ©grez les processus GRC pour obtenir une visibilitÃ© en temps rÃ©el\n\n\nAutomatisez et gÃ©rez les risques, les contrÃ´les, les identitÃ©s, les cyber-menaces et les Ã©changes internationaux dans toute l'entreprise.\n\n\n\n\n\n\n\n\n\n\n\n\n\nRÃ©agissez aux risques\n\n\n\n\nGestion des risques d'entreprise\nContrÃ´les et conformitÃ© centralisÃ©s\nPlanification et performance des audits\nDÃ©tection et correction des exceptions\n\n\nDÃ©couvrir nos produits pour la gestion des risq...\n\n\n\n\n\nGÃ©rez les Ã©changes internationaux\n\n\n\n\nGestion des importations et exportations\nContrÃ´le des tiers faisant l'objet de restrictions ou d'interdictions\nGestion des droits et des frais de douane\nProcÃ©dures douaniÃ¨res spÃ©ciales\n\n\nDÃ©couvrir nos produits pour la gestion commerciale\n\n\n\n\n\nSÃ©curisez vos donnÃ©es\n\n\n\n\nFonctionnalitÃ©s puissantes et flexibles de gestion de la sÃ©curitÃ©Â\xa0\n\nSurveillance de la sÃ©curitÃ© et dÃ©tection des menaces\nIdentification des faiblesses de votre environnement applicatif\nGestion de la confidentialitÃ© et de la protection des donnÃ©es\n\n\n\nDÃ©couvrir nos produits pour la cybersÃ©curitÃ© et...\n\n\n\n\n\nAdministrez les accÃ¨s\n\n\n\n\n Analyse des accÃ¨s et visibilitÃ© permanentes\nPolitiques d'accÃ¨s configurables et prÃ©dÃ©finiesÂ\xa0\nGestion complÃ¨te des identitÃ©s\nConnexion unique et rationalisÃ©eÂ\xa0\n\n\nDÃ©couvrir nos produits pour la gouvernance des ...\n\n\n\n\n\n\nSur cette page\n\n\n\n\n\n\nRÃ©fÃ©rences clients\n\n\n\n\nRisques et conformitÃ©\n\n\n\n\nGestion du commerce international\n\n\n\n\nCybersÃ©curitÃ©\n\n\n\n\nGouvernance des accÃ¨s\n\n\n\n\nPourquoi choisir SAPÂ\xa0?\n\n\n\n\nActualitÃ©s et tendances\n\n\n\n\nServices et support\n\n\n\n\n\n\n\n\nDÃ©velopper tout\n\n\nRÃ©duire tout\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nÃ\x8ates-vous prÃªt Ã\xa0 transformer le risque d'entrepriseÂ\xa0?\n\n\nUnifiez les activitÃ©s de contrÃ´le et de gestion des risques de votre entreprise sur une plateforme technologique commune et tirez parti de la surveillance continue pour prendre des dÃ©cisions en toute flexibilitÃ©.\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nIntÃ©grer les activitÃ©s GRC Ã\xa0 toutes vos opÃ©rations et tous vos projets digitaux.\nAppliquer la gestion du risque Ã\xa0 plusieurs domaines pour une Ã©valuation agrÃ©gÃ©e.\nAutomatiser la surveillance et le contrÃ´le des risques grÃ¢ce Ã\xa0 l'intelligence artificielle.\nPrendre de meilleures dÃ©cisions plus rapidement grÃ¢ce Ã\xa0 des outils d'analyse intÃ©grÃ©s et contextuels.\n\n\n\n\n\n\nRegarder le tÃ©moignage client\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nTransformez votre entreprise\n\n\nTÃ©moignages clientsÂ\xa0SAP\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nRisques de conformitÃ© rÃ©duits grÃ¢ce Ã\xa0 une prise en charge Ã©volutive\n\nDÃ©couvrez comment Flint Group surveille en permanence ses processus opÃ©rationnels et transactionnels afin de corriger rapidement toute incohÃ©rence ou toute erreur.\n\n\n\n\n\n\nLire le tÃ©moignage client\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n2,6Â\xa0millions de dollars d'Ã©conomies sur les droits de douane dans les zones de commerce international \n\nDÃ©couvrez commentÂ\xa0Kodak a rationalisÃ© et automatisÃ© la gestion et le suivi des marchandises Ã\xa0 l'intÃ©rieur et Ã\xa0 l'extÃ©rieur des zones de commerce international des Ã\x89tats-Unis.\n\n\n\n\n\n\nLire le tÃ©moignage client\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nUnifiez les activitÃ©s GRC dans toute l'entreprise intelligente\n\nDÃ©couvrez comment Delivery Hero rÃ©pond Ã\xa0 la demande des clients tout en se conformant aux diverses rÃ¨gles de gouvernance dans plus de 40Â\xa0pays.\n\n\n\n\n\n\nLire le tÃ©moignage client\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nLire plus de tÃ©moignages clients\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nRisques et conformitÃ©\n ...
#  [<div class="parContent"><div class="section dx-row2 dx-f76443995a3d827598813e7679ff522508b2b39c">
#   <section class="cx-section-component ds-p-t-xxl">
#   <div class="container-extended">
#   <div class="row">
#   <div class="col-xs-12 col-sm-10 col-sm-offset-1 col-md-10 col-md-offset-1 col-lg-10 col-lg-offset-1 col-xlg-8 col-xlg-offset-2">
#   <div class="section-headline">
#   <h2 class="ds-heading ds-heading--xl">IntÃ©grez les processus GRC pour obtenir une visibilitÃ© en temps rÃ©el</h2>
#   </div>
#   <div class="section-subTitle">
#   <p>Automatisez et gÃ©rez les risques, les contrÃ´les, les identitÃ©s, les cyber-menaces et les Ã©changes internationaux dans toute l'entreprise.<br/>
#   </p>
#   </div>
#   </div>
#   </div>
#   <div class="row">
#   <div class="col-xs-12 col-sm-12 col-md-12 col-lg-12 col-xlg-12">
#   <div class="section-content"><div class="navigationExtended2019 dx-row2-1 section dx-6167047080c0b6cab0fe859f998a4e7eabc8e33f">
#   <span class="lazy-loader-wrapper" data-loader="lazyScriptCssLoader" data-resource-type="sapdx/components/modular/nav/navigationExtended2019">
#   <span class="lazy-css" data-src="/etc.clientlibs/sapdx/components/modular/nav/navigationExtended2019/clientlib.min.18daxb14810.css"></span><span class="lazy-script" data-src="/etc.clientlibs/sapdx/components/modular/nav/navigationExtended2019/clientlib.min.18daxb14810.js"></span>
#   </span>
#   <div class="extended-navigation row" style="display: none">
#   <div class="navigation-item col-xs-12">
#   <div class="navigation-item__heading">
#   <h3 class="navigation-item__headline ds-heading--m">RÃ©agissez aux risques</h3>
#   <span class="icon-dropdown navigation-item__accordion-icon"></span>
#   </div>
#   <div class="navigation-item__body ds-body">
#   <ul>
#   <li>Gestion des risques d'entreprise</li>
#   <li>ContrÃ´les et conformitÃ© centralisÃ©s</li>
#   <li>Planification et performance des audits</li>
#   <li>DÃ©tection et correction des exceptions</li>
#   </ul>
#   <a class="ds-button ds-button--secondary" href="#enterprise-risk-compliance" target="_self" title="DÃ©couvrir nos produits pour la gestion des risques et de la conformitÃ© d'entreprise">
#   DÃ©couvrir nos produits pour la gestion des risq...
#   </a>
#   </div>
#   </div>
#   <div class="navigation-item col-xs-12">
#   <div class="navigation-item__heading">
#   <h3 class="navigation-item__headline ds-heading--m">GÃ©rez les Ã©changes internationaux</h3>
#   <span class="icon-dropdown navigation-item__accordion-icon"></span>
#   </div>
#   <div class="navigation-item__body ds-body">
#   <ul>
#   <li>Gestion des importations et exportations</li>
#   <li>ContrÃ´le des tiers faisant l'objet de restrictions ou d'interdictions</li>
#   <li>Gestion des droits et des frais de douane</li>
#   <li>ProcÃ©dures douaniÃ¨res spÃ©ciales</li>
#   </ul>
#   <a class="ds-button ds-button--secondary" href="#international-trade-management" target="_self">
#   DÃ©couvrir nos produits pour la gestion commerciale
#   </a>
#   </div>
#   </div>
#   <div class="navigation-item col-xs-12">
#   <div class="navigation-item__heading">
#   <h3 class="navigation-item__headline ds-heading--m">SÃ©curisez vos donnÃ©es</h3>
#   <span class="icon-dropdown navigation-item__accordion-icon"></span>
#   </div>
#   <div class="navigation-item__body ds-body">
#   <ul>
#   <li>FonctionnalitÃ©s puissantes et flexibles de gestion de la sÃ©curitÃ©Â <br>
#   </br></li>
#   <li>Surveillance de la sÃ©curitÃ© et dÃ©tection des menaces</li>
#   <li>Identification des faiblesses de votre environnement applicatif</li>
#   <li>Gestion de la confidentialitÃ© et de la protection des donnÃ©es<br/>
#   </li>
#   </ul>
#   <a class="ds-button ds-button--secondary" href="#cybersecurity" target="_self" title="DÃ©couvrir nos produits pour la cybersÃ©curitÃ© et la protection">
#   DÃ©couvrir nos produits pour la cybersÃ©curitÃ© et...
#   </a>
#   </div>
#   </div>
#   <div class="navigation-item col-xs-12">
#   <div class="navigation-item__heading">
#   <h3 class="navigation-item__headline ds-heading--m">Administrez les accÃ¨s</h3>
#   <span class="icon-dropdown navigation-item__accordion-icon"></span>
#   </div>
#   <div class="navigation-item__body ds-body">
#   <ul>
#   <li> Analyse des accÃ¨s et visibilitÃ© permanentes</li>
#   <li>Politiques d'accÃ¨s configurables et prÃ©dÃ©finiesÂ </li>
#   <li>Gestion complÃ¨te des identitÃ©s</li>
#   <li>Connexion unique et rationalisÃ©eÂ </li>
#   </ul>
#   <a class="ds-button ds-button--secondary" href="#access-governance" target="_self">
#   DÃ©couvrir nos produits pour la gouvernance des ...
#   </a>
#   </div>
#   </div>
#   <div class="navigation-item _table-of-contents col-xlg-4 col-lg-4 col-xs-12">
#   <div>
#   <div class="navigation-item__heading">
#   <h3 class="navigation-item__headline ds-heading--m">Sur cette page</h3>
#   <span class="icon-dropdown navigation-item__accordion-icon"></span>
#   </div>
#   <div class="navigation-item__body ds-body">
#   <ul>
#   <li>
#   <a class="ds-link" href="#customer-references">
#   <span>RÃ©fÃ©rences clients</span>
#   </a>
#   </li>
#   <li>
#   <a class="ds-link" href="#enterprise-risk-compliance">
#   <span>Risques et conformitÃ©</span>
#   </a>
#   </li>
#   <li>
#   <a class="ds-link" href="#international-trade-management">
#   <span>Gestion du commerce international</span>
#   </a>
#   </li>
#   <li>
#   <a class="ds-link" href="#cybersecurity">
#   <span>CybersÃ©curitÃ©</span>
#   </a>
#   </li>
#   <li>
#   <a class="ds-link" href="#access-governance">
#   <span>Gouvernance des accÃ¨s</span>
#   </a>
#   </li>
#   <li>
#   <a class="ds-link" href="#why-sap">
#   <span>Pourquoi choisir SAPÂ ?</span>
#   </a>
#   </li>
#   <li>
#   <a class="ds-link" href="#news-trends">
#   <span>ActualitÃ©s et tendances</span>
#   </a>
#   </li>
#   <li>
#   <a class="ds-link" href="#services">
#   <span>Services et support</span>
#   </a>
#   </li>
#   </ul>
#   </div>
#   </div>
#   </div>
#   <div class="button-container col-xs-12">
#   <a class="accordion-button _expand ds-link withArrow" data-action="expand" href="#">
#   <span>DÃ©velopper tout</span>
#   </a>
#   <a class="accordion-button _collapse ds-link withArrow hidden" data-action="collapse" href="#">
#   <span>RÃ©duire tout</span>
#   </a>
#   </div>
#   </div>
#   </div>
#   </div>
#   </div>
#   </div>
#   </div>
#   <div class="section-divider-container ds-p-t-m">
#   <div class="section-divider ds-p-t-xxl"></div>
#   </div>
#   </section>
#   </div>
#   <div class="section dx-row3 dx-6e929dc4d851ef93900a6522f08520c05e4e5f70">
#   <section class="cx-section-component ds-p-t-xxl">
#   <div class="container-extended">
#   <div class="row">
#   <div class="col-xs-12 col-sm-10 col-sm-offset-1 col-md-10 col-md-offset-1 col-lg-10 col-lg-offset-1 col-xlg-8 col-xlg-offset-2">
#   <div class="section-headline">
#   <h2 class="ds-heading ds-heading--xl">Ãtes-vous prÃªt Ã  transformer le risque d'entrepriseÂ ?</h2>
#   </div>
#   <div class="section-subTitle">
#   <p>Unifiez les activitÃ©s de contrÃ´le et de gestion des risques de votre entreprise sur une plateforme technologique commune et tirez parti de la surveillance continue pour prendre des dÃ©cisions en toute flexibilitÃ©.</p>
#   </div>
#   </div>
#   </div>
#   <div class="row">
#   <div class="col-xs-12 col-sm-12 col-md-12 col-lg-12 col-xlg-12">
#   <div class="section-content"><div class="universalLayout dx-80cc97f8a6d567a3d1120becd653944889773d4b section dx-row3-1">
#   <link href="/etc.clientlibs/sapdx/components/modular/universalLayout/clientlib.min.8130cbfdf1d747366190817e7315bc42.css" rel="stylesheet" type="text/css"/>
#   <span class="lazy-loader-wrapper" data-loader="lazyScriptCssLoader" data-resource-type="sapdx/components/modular/universalLayout">
#   <span class="lazy-script" data-src="/etc.clientlibs/sapdx/components/modular/universalLayout/clientlib.min.18daxb14810.js"></span>
#   </span>
#   <span class="lazy-loader-wrapper" data-loader="lazyScriptCssLoader" data-resource-type="sapdx/components/modular/universalLayout">
#   <span class="lazy-script" data-src="/etc.clientlibs/sapdx/components/modular/universalLayout/clientlib-animation.min.18daxb14810.js"></span>
#   </span>
#   <section class="universalLayoutComponent one-box horizontal textright">
#   <div class="container-extended flex" dir="ltr">
#   <div class="row" data-row-index="0">
#   <div class="col-xs-12 col-sm-12 col-md-12 col-lg-12 col-xlg-12 universal-item horizontal" data-row-index="0">
#   <div class="row">
#   <div class="col-xs-12 col-sm-6 col-md-6 col-lg-6 col-xlg-6">
#   <div class="visual-content video" data-animation-item="">
#   <div class="lightbox-image__container">
#   <div class="lightbox-image">
#   <div class="lightbox-image__cover-container twoBoxesFullWidth">
#   <div class="slide img-container shadowed">
#   <div class="visual-content video" data-is-lightbox-footer-configured="false">
#   <script defer="" src="/etc/sapdx/binary/clientlib-videojs.min.2e0ecb56166ee1581455b430081c9728.js" type="text/javascript"></script>
#   <script defer="" src="/etc.clientlibs/sapdx/components/modular/video/lightBoxVideo/clientlib.min.827fe05195ba515bef20edacf8bcb752.js" type="text/javascript"></script>
#   <script defer="" src="/etc.clientlibs/sapdx/components/modular/video/embeddedVideo/clientlib.min.b7282b8d09764fb6ef457810f06ebbb9.js" type="text/javascript"></script>
#   <script defer="" src="/etc.clientlibs/sapdx/components/modular/video/clientlib.min.378b1b5d03fa8e26225b14e75c919c6a.js" type="text/javascript"></script>
#   <div class="lightBox lightBoxControlWrapper" data-asset-id="2af167c0-9d7d-0010-87a3-c30de2ffd8ff" data-light-box-type="video">
#   <div>
#   <picture class="adaptiveImagesContainer lazy" data-alt="" data-loader="pictureFillLoader">
#   <source data-height="406" data-srcset="https://content.cdn.sap.com/is/image/sap/286442:3840x2160?wid=722&amp;hei=406&amp;fit=stretch,1" data-width="722" media="(max-width: 767px) and (-webkit-min-device-pixel-ratio: 2)"/>
#   <source data-height="772" data-srcset="https://content.cdn.sap.com/is/image/sap/286442:3840x2160?wid=1370&amp;hei=770&amp;fit=stretch,1" data-width="1370" media="(-webkit-min-device-pixel-ratio: 2) and (min-resolution: 192dpi)"/>
#   <source data-height="203" data-srcset="https://content.cdn.sap.com/is/image/sap/286442:3840x2160?wid=361&amp;hei=203&amp;fit=stretch,1" data-width="361" media="(max-width: 767px)"/>
#   <source data-height="161" data-srcset="https://content.cdn.sap.com/is/image/sap/286442:3840x2160?wid=286&amp;hei=160&amp;fit=stretch,1" data-width="286" media="(min-width: 768px) and (max-width: 979px)"/>
#   <source data-height="322" data-srcset="https://content.cdn.sap.com/is/image/sap/286442:3840x2160?wid=572&amp;hei=321&amp;fit=stretch,1" data-width="572" media="(min-width: 768px) and (max-width: 979px) and (-webkit-min-device-pixel-ratio: 2)"/>
#   <source data-height="319" data-srcset="https://content.cdn.sap.com/is/image/sap/286442:3840x2160?wid=568&amp;hei=319&amp;fit=stretch,1" data-width="568" media="(min-width: 980px) and (max-width: 1299px)"/>
#   <source data-height="638" data-srcset="https://content.cdn.sap.com/is/image/sap/286442:3840x2160?wid=1136&amp;hei=638&amp;fit=stretch,1" data-width="1136" media="(min-width: 980px) and (max-width: 1299px) and (-webkit-min-device-pixel-ratio: 2)"/>
#   <source data-height="319" data-srcset="https://content.cdn.sap.com/is/image/sap/286442:3840x2160?wid=568&amp;hei=319&amp;fit=stretch,1" data-width="568" media="(min-width: 1300px) and (max-width: 1600px)"/>
#   <source data-height="638" data-srcset="https://content.cdn.sap.com/is/image/sap/286442:3840x2160?wid=1136&amp;hei=638&amp;fit=stretch,1" data-width="1136" media="(min-width: 1300px) and (max-width: 1600px) and (-webkit-min-device-pixel-ratio: 2)"/>
#   <img data-height="386" data-srcset="https://content.cdn.sap.com/is/image/sap/286442:3840x2160?wid=685&amp;hei=385&amp;fit=stretch,1" data-width="685"/>
#   </picture>
#   <div>
#   <div class="videoIcon icon-play"></div>
#   </div>
#   </div>
#   </div>
#   <div class="videoWrapper lightBoxVideoWrapper mfp-hide" data-asset-description="Aligning governance, risk, and compliance (GRC) resources to strategic priorities while remaining agile can be challenging. OYAK Mining Metallurgy Group has transformed its audit and GRC processes along a âthree lines of defenseâ model for greater automation, assurance, and visibility." data-asset-title="Transform Audit Processes Digitally">
#   <div class="topDiv"></div>
#   <video class="video-js vjs-default-skin vjs-big-play-centered vjs-fluid" controls="" data-akamaiurl="https://sapeventsvod-vh.akamaihd.net/i/sapphirenow/2020/noam-english/vod/odsn2020038_,200,600,1200,.mp4.csmil/master.m3u8" data-analyticsassetid="2af167c0-9d7d-0010-87a3-c30de2ffd8ff|mp4|Transform Audit Processes Digitally" data-asset-id="2af167c0-9d7d-0010-87a3-c30de2ffd8ff" data-dam-link="/france/assetdetail/2020/06/2af167c0-9d7d-0010-87a3-c30de2ffd8ff.html" data-expirationdate="2022-06-17T00:00:00Z" data-is-lightbox="true" data-is-stream="false" data-is-youtube="false" data-publishingdate="2020-06-17T00:00:00Z" data-sap-digital-id="No Digital Library ID" data-title="Transform Audit Processes Digitally" data-video-setup='{"plugins":{"share":{"pinterest":false,"delicious":false,"reddit":false,"embed":false,"more":false,"vk":false,"share_url":"/france/assetdetail/2020/06/2af167c0-9d7d-0010-87a3-c30de2ffd8ff.html"},"whiteBigPlayButton":{}}}' preload="none">
#   <source src="https://sapeventsvod-vh.akamaihd.net/i/sapphirenow/2020/noam-english/vod/odsn2020038_,200,600,1200,.mp4.csmil/master.m3u8" type="application/x-mpegURL">
#   </source></video>
#   <div class="vjs-poster video-poster"><picture class="adaptiveImagesContainer lazy" data-alt="" data-loader="pictureFillLoader">
#   </picture></div>
#   <div class="hiddenMessage">
#   <picture class="adaptiveImagesContainer lazy" data-alt="" data-loader="pictureFillLoader">
#   </picture></div>
#   </div>
#   </div>
#   </div>
#   </div>
#   </div>
#   </div>
#   </div>
#   </div>
#   <div class="col-xs-12 col-sm-6 col-md-6 col-lg-6 col-xlg-6">
#   <div class="text-content" data-animation-item="">
#   <div class="ds-body text-content-list">
#   <ul>
#   <li>IntÃ©grer les activitÃ©s GRC Ã  toutes vos opÃ©rations et tous vos projets digitaux.</li>
#   <li>Appliquer la gestion du risque Ã  plusieurs domaines pour une Ã©valuation agrÃ©gÃ©e.</li>
#   <li>Automatiser la surveillance et le contrÃ´le des risques grÃ¢ce Ã  l'intelligence artificielle.</li>
#   <li>Prendre de meilleures dÃ©cisions plus rapidement grÃ¢ce Ã  des outils d'analyse intÃ©grÃ©s et contextuels.</li>
#   </ul>
#   </div>
#   <div class="links-list">
#   <ul class="links list-unstyled">
#   <li class="type-link">
#   <a class="ds-link withArrow" data-analytics-assetid="2af167c0-9d7d-0010-87a3-c30de2ffd8ff|mp4|Transform Audit Processes Digitally" data-asset-id="2af167c0-9d7d-0010-87a3-c30de2ffd8ff" data-engagement-tracking-analytics="Regarder le tÃ©moignage client" data-is-lightbox-footer-configured="false" data-is-lightbox-header-configured="false" href="/france/assetdetail/2020/06/2af167c0-9d7d-0010-87a3-c30de2ffd8ff.html" target="_self">
#   <span>Regarder le tÃ©moignage client</span>
#   </a>
#   </li>
#   </ul>
#   </div>
#   </div>
#   </div>
#   </div>
#   </div>
#   </div>
#   </div>
#   </section>
#   </div>
#   </div>
#   </div>
#   </div>
#   </div>
#   <div class="section-divider-container ds-p-t-m">
#   <div class="section-divider ds-p-t-xxl"></div>
#   </div>
#   </section>
#   </div>
#   <div class="section dx-row4 dx-3a72fe16c3dbcca443d2e06c4ec6c02322ec8254">
#   <section class="cx-section-component ds-p-t-xxl" data-anchor-url-selector="customer-references" id="customer-references">
#   <div class="container-extended">
#   <div class="row">
#   <div class="col-xs-12 col-sm-10 col-sm-offset-1 col-md-10 col-md-offset-1 col-lg-10 col-lg-offset-1 col-xlg-8 col-xlg-offset-2">
#   <div class="section-headline">
#   <h2 class="ds-heading ds-heading--xl">Transformez votre entreprise</h2>
#   </div>
#   <div class="section-subTitle">
#   <p>TÃ©moignages clientsÂ SAP</p>
#   </div>
#   </div>
#   </div>
#   <div class="row">
#   <div class="col-xs-12 col-sm-12 col-md-12 col-lg-12 col-xlg-12">
#   <div class="section-content"><div class="universalLayout dx-15ca6973709cbaac1ff2ab9ec357a7391114db8e section dx-row4-1">
#   <span class="lazy-loader-wrapper" data-loader="lazyScriptCssLoader" data-resource-type="sapdx/components/modular/universalLayout">
#   </span>
#   <span class="lazy-loader-wrapper" data-loader="lazyScriptCssLoader" data-resource-type="sapdx/components/modular/universalLayout">
#   </span>
#   <section class="universalLayoutComponent three-boxes vertical">
#   <div class="container-extended flex" dir="ltr">
#   <div class="row" data-row-index="0">
#   <div class="col-xs-12 col-sm-12 col-md-4 col-lg-4 col-xlg-4 universal-item vertical" data-row-index="0">
#   <div class="universal-item-content-vertical">
#   <div class="visual-content" data-animation-item="">
#   <div class="lightbox-image__container">
#   <div class="lightbox-image">
#   <div class="lightbox-image__cover-container logo">
#   <div class="lightbox-image__cover-wrapper center lightbox-disabled">
#   <img alt="Logo de FlintGroup, client SAP utilisant les solutions GRC" class="icon lazy lazyplaceholder" data-src="/content/dam/application/shared/logos/customer/a-g/flint-group-customer-logo.png" src="..." title="Logo de FlintGroup, client SAP utilisant les solutions GRC">
#   </img></div>
#   </div>
#   </div>
#   </div>
#   </div>
#   <div class="text-content" data-animation-item="">
#   <h3 class="ds-heading ds-heading--s">Risques de conformitÃ© rÃ©duits grÃ¢ce Ã  une prise en charge Ã©volutive</h3>
#   <div class="ds-body text-content-list">
#   <p>DÃ©couvrez comment Flint Group surveille en permanence ses processus opÃ©rationnels et transactionnels afin de corriger rapidement toute incohÃ©rence ou toute erreur.<br/>
#   </p>
#   </div>
#   <div class="links-list">
#   <ul class="links list-unstyled">
#   <li class="type-link">
#   <a class="ds-link withArrow" data-analytics-assetid="482c895e-497d-0010-87a3-c30de2ffd8ff|pdf|Flint Group: How Can Continuous Control Monitoring Help Ensure Consistent and Compliant Processes and Data?" data-asset-id="482c895e-497d-0010-87a3-c30de2ffd8ff" data-engagement-tracking-analytics="Lire le tÃ©moignage client" data-is-lightbox-footer-configured="false" data-is-lightbox-header-configured="false" data-light-box-type="lightbox" href="/france/documents/2019/04/482c895e-497d-0010-87a3-c30de2ffd8ff.html" target="_self">
#   <span>Lire le tÃ©moignage client</span>
#   </a>
#   </li>
#   </ul>
#   </div>
#   </div>
#   </div>
#   </div>
#   <div class="col-xs-12 col-sm-12 col-md-4 col-lg-4 col-xlg-4 universal-item vertical" data-row-index="0">
#   <div class="universal-item-content-vertical">
#   <div class="visual-content" data-animation-item="">
#   <div class="lightbox-image__container">
#   <div class="lightbox-image">
#   <div class="lightbox-image__cover-container logo">
#   <div class="lightbox-image__cover-wrapper center lightbox-disabled">
#   <img alt="Logo de Kodak, client SAP utilisant les solutions GRC" class="icon lazy lazyplaceholder" data-src="/content/dam/application/shared/logos/customer/h-q/kodak-customer-logo.svg" src="..." title="Logo de Kodak, client SAP utilisant les solutions GRC">
#   </img></div>
#   </div>
#   </div>
#   </div>
#   </div>
#   <div class="text-content" data-animation-item="">
#   <h3 class="ds-heading ds-heading--s">2,6Â millions de dollars d'Ã©conomies sur les droits de douane dans les zones de commerce international </h3>
#   <div class="ds-body text-content-list">
#   <p>DÃ©couvrez commentÂ Kodak a rationalisÃ© et automatisÃ© la gestion et le suivi des marchandises Ã  l'intÃ©rieur et Ã  l'extÃ©rieur des zones de commerce international des Ãtats-Unis.<br/>
#   </p>
#   </div>
#   <div class="links-list">
#   <ul class="links list-unstyled">
#   <li class="type-link">
#   <a class="ds-link withArrow" data-analytics-assetid="36d90907-4e7d-0010-87a3-c30de2ffd8ff|pdf|Kodak: How Can Automation and System Integration Streamline U.S. Foreign-Trade Zone Operation?" data-asset-id="36d90907-4e7d-0010-87a3-c30de2ffd8ff" data-engagement-tracking-analytics="Lire le tÃ©moignage client" data-is-lightbox-footer-configured="false" data-is-lightbox-header-configured="false" href="/france/documents/2019/05/36d90907-4e7d-0010-87a3-c30de2ffd8ff.html" target="_self">
#   <span>Lire le tÃ©moignage client</span>
#   </a>
#   </li>
#   </ul>
#   </div>
#   </div>
#   </div>
#   </div>
#   <div class="col-xs-12 col-sm-12 col-md-4 col-lg-4 col-xlg-4 universal-item vertical" data-row-index="0">
#   <div class="universal-item-content-vertical">
#   <div class="visual-content" data-animation-item="">
#   <div class="lightbox-image__container">
#   <div class="lightbox-image">
#   <div class="lightbox-image__cover-container logo">
#   <div class="lightbox-image__cover-wrapper center lightbox-disabled">
#   <img alt="Logo de DeliveryÂ Hero, client SAP" class="icon lazy lazyplaceholder" data-src="/content/dam/application/shared/logos/customer/a-g/delivery-hero-customer-logo.svg" src="..." title="Logo de DeliveryÂ Hero, client SAP">
#   </img></div>
#   </div>
#   </div>
#   </div>
#   </div>
#   <div class="text-content" data-animation-item="">
#   <h3 class="ds-heading ds-heading--s">Unifiez les activitÃ©s GRC dans toute l'entreprise intelligente</h3>
#   <div class="ds-body text-content-list">
#   <p>DÃ©couvrez comment Delivery Hero rÃ©pond Ã  la demande des clients tout en se conformant aux diverses rÃ¨gles de gouvernance dans plus de 40Â pays.<br/>
#   </p>
#   </div>
#   <div class="links-list">
#   <ul class="links list-unstyled">
#   <li class="type-link">
#   <a class="ds-link withArrow" data-analytics-assetid="f2ae8dcf-6f7d-0010-87a3-c30de2ffd8ff|pdf|Delivery Hero SE: How Does Better Audit Management Help Improve the Customer Experience and Provide Assurance Around the World?/BTS" data-asset-id="f2ae8dcf-6f7d-0010-87a3-c30de2ffd8ff" data-engagement-tracking-analytics="Lire le tÃ©moignage client" data-is-lightbox-footer-configured="false" data-is-lightbox-header-configured="false" href="/france/documents/2019/11/f2ae8dcf-6f7d-0010-87a3-c30de2ffd8ff.html" target="_self">
#   <span>Lire le tÃ©moignage client</span>
#   </a>
#   </li>
#   </ul>
#   </div>
#   </div>
#   </div>
#   </div>
#   </div>
#   </div>
#   </section>
#   </div>
#   </div>
#   </div>
#   </div>
#   <div class="row ds-p-t-xl">
#   <div class="col-xs-12 col-sm-12 col-md-12 col-lg-12 col-xlg-12">
#   <div class="section-cta">
#   <div class="links-list">
#   <ul class="links list-unstyled">
#   <li class="type-link">
#   <a class="ds-link withArrow" data-engagement-tracking-analytics="Lire plus de tÃ©moignages clients" href="/france/about/customer-stories.html" target="_self">
#   <span>Lire plus de tÃ©moignages clients</span>
#   </a>
#   </li>
#   </ul>
#   </div>
#   </div>
#   </div>
#   </div>
#   </div>
#   <div class="section-divider-container ds-p-t-m">
#   <div class="section-divider ds-p-t-xxl"></div>
#   </div>
#   </section>
#   </div>
#   <div class="section dx-row5 dx-da037113cb23203f16acd28f0b4e00462e4afd2d">
#   <section class="cx-section-component ds-p-t-xxl" data-anchor-url-selector="enterprise-risk-compliance" id="enterprise-risk-compliance">
#   <div class="container-extended">
#   <div class="row">
#   <div class="col-xs-12 col-sm-10 col-sm-offset-1 col-md-10 col-md-offset-1 col-lg-10 col-lg-offset-1 col-xlg-8 col-xlg-offset-2">
#   <div class="section-icon">
#   <img alt="Image d'un marteau, reprÃ©sentant la conformitÃ© rÃ©glementaire" class="icon" src="/dam/application/imagelibrary/pictograms/281000/281952-pictogram-purple.svg">
#   </img></div>
#   <div class="section-headline">
#   <h2 class="ds-heading ds-heading--xl">Risques et conformitÃ©</h2>
#   </div>
#   <div class="section-subTitle">
#   <p>Adoptez trois lignes de dÃ©fenseÂ : gestion des opÃ©rations, gestion des risques et de la conformitÃ©, et audits internes.<br/>
#   </p>
#   </div>
#   </div>
#   </div>
#   <div class="row">
#   <div class="col-xs-12 col-sm-12 col-md-12 col-lg-12 col-xlg-12">
#   <div class="section-content"><div class="universalLayout dx-row6 section dx-e326da054840d0fb52c4315b8bcd4d4a7656a7c6">
#   <span class="lazy-loader-wrapper" data-loader="lazyScriptCssLoader" data-resource-type="sapdx/components/modular/universalLayout">
#   </span>
#   <span class="lazy-loader-wrapper" data-loader="lazyScriptCssLoader" data-resource-type="sapdx/components/modular/universalLayout">
#   </span>
#   <section class="universalLayoutComponent two-boxes vertical">
#   <div class="container-extended flex" dir="ltr">
#   <div class="row" data-row-index="0">
#   <div class="col-xs-12 col-sm-6 col-md-6 col-lg-6 col-xlg-6 universal-item vertical" data-row-index="0">
#   <div class="universal-item-content-vertical">
#   <div class="visual-content" data-animation-item="">
#   <div class="lightbox-image__container">
#   <div class="lightbox-image">
#   <div class="lightbox-image__cover-container productFiftyFifty product-content">
#   <div class="img-container lightbox-image__cover-wrapper center productFiftyFifty lightbox-disabled">
#   <picture class="adaptiveImagesContainer lightbox" data-alt="SAP Risk Management affiché sur un écran" data-loader="pictureFillLoader">
#   <source data-height="320" data-width="494" media="(max-width: 767px) and (-webkit-min-device-pixel-ratio: 2)" srcset="/dam/application/shared/photos/products-j-r/sap-risk-management-device-nwrskasmt.png/_jcr_content/renditions/original.adapt.-1_320.false.false.false.false.png/1596125985666.png"/>
#   <source data-height="684" data-width="1056" media="(-webkit-min-device-pixel-ratio: 2) and (min-resolution: 192dpi)" srcset="/dam/application/shared/photos/products-j-r/sap-risk-management-device-nwrskasmt.png/_jcr_content/renditions/original.adapt.-1_684.false.false.false.false.png/1596125985666.png"/>
#   <source data-height="160" data-width="247" media="(max-width: 767px)" srcset="/dam/application/shared/photos/products-j-r/sap-risk-management-device-nwrskasmt.png/_jcr_content/renditions/original.adapt.-1_160.false.false.false.false.png/1596125985666.png"/>
#   <source data-height="342" data-width="528" media="(min-width: 1601px) and (max-width: 1920px)" srcset="/dam/application/shared/photos/products-j-r/sap-risk-management-device-nwrskasmt.png/_jcr_content/renditions/original.adapt.-1_342.false.false.false.false.png/1596125985666.png"/>
#   <source data-height="215" data-width="332" media="(min-width: 768px) and (max-width: 979px)" srcset="/dam/application/shared/photos/products-j-r/sap-risk-management-device-nwrskasmt.png/_jcr_content/renditions/original.adapt.-1_215.false.false.false.false.png/1596125985666.png"/>
#   <source data-height="430" data-width="664" media="(min-width: 768px) and (max-width: 979px) and (-webkit-min-device-pixel-ratio: 2)" srcset="/dam/application/shared/photos/products-j-r/sap-risk-management-device-nwrskasmt.png/_jcr_content/renditions/original.adapt.-1_430.false.false.false.false.png/1596125985666.png"/>
#   <source data-height="282" data-width="435" media="(min-width: 980px) and (max-width: 1299px)" srcset="/dam/application/shared/photos/products-j-r/sap-risk-management-device-nwrskasmt.png/_jcr_content/renditions/original.adapt.-1_282.false.false.false.false.png/1596125985666.png"/>
#   <source data-height="564" data-width="871" media="(min-width: 980px) and (max-width: 1299px) and (-webkit-min-device-pixel-ratio: 2)" srcset="/dam/application/shared/photos/products-j-r/sap-risk-management-device-nwrskasmt.png/_jcr_content/renditions/original.adapt.-1_564.false.false.false.false.png/1596125985666.png"/>
#   <source data-height="342" data-width="528" media="(min-width: 1300px) and (max-width: 1600px)" srcset="/dam/application/shared/photos/products-j-r/sap-risk-management-device-nwrskasmt.png/_jcr_content/renditions/original.adapt.-1_342.false.false.false.false.png/1596125985666.png"/>
#   <source data-height="684" data-width="1056" media="(min-width: 1300px) and (max-width: 1600px) and (-webkit-min-device-pixel-ratio: 2)" srcset="/dam/application/shared/photos/products-j-r/sap-risk-management-device-nwrskasmt.png/_jcr_content/renditions/original.adapt.-1_684.false.false.false.false.png/1596125985666.png"/>
#   <img data-height="342" data-width="528" srcset="/dam/application/shared/photos/products-j-r/sap-risk-management-device-nwrskasmt.png/_jcr_content/renditions/original.adapt.-1_342.false.false.false.false.png/1596125985666.png"/>
#   </picture>
#   </div>
#   </div>
#   </div>
#   </div>
#   </div>
#   <div class="text-content" data-animation-item="">
#   <h3 class="ds-heading ds-heading--s">GÃ©rez les risques financiers, opÃ©rationnels et liÃ©s aux fournisseurs</h3>
#   <div class="ds-body text-content-list">
#   <p>Analysez en dÃ©tail l'impact des facteurs de risque sur la valeur et la rÃ©putation de votre entreprise et prenez des dÃ©cisions plus avisÃ©es, tenant compte des risques, grÃ¢ce Ã  notre logiciel de gestion des risques d'entreprise (ERM).<br>
#   </br></p>
#   </div>
#   <div class="links-list">
#   <ul class="links list-unstyled">
#   <li class="type-button">
#   <a class="ds-button ds-button--primary" data-engagement-tracking-analytics="SAPÂ Risk Management" data-is-lightbox-footer-configured="false" data-is-lightbox-header-configured="false" href="/france/products/risk-management.html" target="_self">
#   SAPÂ Risk Management
#   </a>
#   </li>
#   </ul>
#   </div>
#   </div>
#   </div>
#   </div>
#   <div class="col-xs-12 col-sm-6 col-md-6 col-lg-6 col-xlg-6 universal-item vertical" data-row-index="0">
#   <div class="universal-item-content-vertical">
#   <div class="visual-content" data-animation-item="">
#   <div class="lightbox-image__container">
#   <div class="lightbox-image">
#   <div class="lightbox-image__cover-container productFiftyFifty product-content">
#   <div class="img-container lightbox-image__cover-wrapper center productFiftyFifty lightbox-disabled">
#   <picture class="adaptiveImagesContainer lightbox" data-alt="Capture d'écran de SAP Process Control" data-loader="pictureFillLoader">
#   <source data-height="320" data-width="653" media="(max-width: 767px) and (-webkit-min-device-pixel-ratio: 2)" srcset="/dam/application/shared/photos/products-j-r/sap-process-control-device-mtrcntrlstat.png/_jcr_content/renditions/original.adapt.-1_320.false.false.false.false.png/1596126480618.png"/>
#   <source data-height="684" data-width="1397" media="(-webkit-min-device-pixel-ratio: 2) and (min-resolution: 192dpi)" srcset="/dam/application/shared/photos/products-j-r/sap-process-control-device-mtrcntrlstat.png/_jcr_content/renditions/original.adapt.-1_684.false.false.false.false.png/1596126480618.png"/>
#   <source data-height="160" data-width="326" media="(max-width: 767px)" srcset="/dam/application/shared/photos/products-j-r/sap-process-control-device-mtrcntrlstat.png/_jcr_content/renditions/original.adapt.-1_160.false.false.false.false.png/1596126480618.png"/>
#   <source data-height="342" data-width="698" media="(min-width: 1601px) and (max-width: 1920px)" srcset="/dam/application/shared/photos/products-j-r/sap-process-control-device-mtrcntrlstat.png/_jcr_content/renditions/original.adapt.-1_342.false.false.false.false.png/1596126480618.png"/>
#   <source data-height="215" data-width="439" media="(min-width: 768px) and (max-width: 979px)" srcset="/dam/application/shared/photos/products-j-r/sap-process-control-device-mtrcntrlstat.png/_jcr_content/renditions/original.adapt.-1_215.false.false.false.false.png/1596126480618.png"/>
#   <source data-height="430" data-width="878" media="(min-width: 768px) and (max-width: 979px) and (-webkit-min-device-pixel-ratio: 2)" srcset="/dam/application/shared/photos/products-j-r/sap-process-control-device-mtrcntrlstat.png/_jcr_content/renditions/original.adapt.-1_430.false.false.false.false.png/1596126480618.png"/>
#   <source data-height="282" data-width="576" media="(min-width: 980px) and (max-width: 1299px)" srcset="/dam/application/shared/photos/products-j-r/sap-process-control-device-mtrcntrlstat.png/_jcr_content/renditions/original.adapt.-1_282.false.false.false.false.png/1596126480618.png"/>
#   <source data-height="564" data-width="1152" media="(min-width: 980px) and (max-width: 1299px) and (-webkit-min-device-pixel-ratio: 2)" srcset="/dam/application/shared/photos/products-j-r/sap-process-control-device-mtrcntrlstat.png/_jcr_content/renditions/original.adapt.-1_564.false.false.false.false.png/1596126480618.png"/>
#   <source data-height="342" data-width="698" media="(min-width: 1300px) and (max-width: 1600px)" srcset="/dam/application/shared/photos/products-j-r/sap-process-control-device-mtrcntrlstat.png/_jcr_content/renditions/original.adapt.-1_342.false.false.false.false.png/1596126480618.png"/>
#   <source data-height="684" data-width="1397" media="(min-width: 1300px) and (max-width: 1600px) and (-webkit-min-device-pixel-ratio: 2)" srcset="/dam/application/shared/photos/products-j-r/sap-process-control-device-mtrcntrlstat.png/_jcr_content/renditions/original.adapt.-1_684.false.false.false.false.png/1596126480618.png"/>
#   <img data-height="342" data-width="698" srcset="/dam/application/shared/photos/products-j-r/sap-process-control-device-mtrcntrlstat.png/_jcr_content/renditions/original.adapt.-1_342.false.false.false.false.png/1596126480618.png"/>
#   </picture>
#   </div>
#   </div>
#   </div>
#   </div>
#   </div>
#   <div class="text-content" data-animation-item="">
#   <h3 class="ds-heading ds-heading--s">ContrÃ´lez les processus clÃ©s et gÃ©rez la conformitÃ©</h3>
#   <div class="ds-body text-content-list">
#   <p>Documentez, Ã©valuez, testez et corrigez les risques et contrÃ´les liÃ©s aux processus critiques en rationalisant les efforts de conformitÃ© de l'entreprise et en utilisant les processus de contrÃ´le interne basÃ©s sur les meilleures pratiques.<br/>
#   </p>
#   </div>
#   <div class="links-list">
#   <ul class="links list-unstyled">
#   <li class="type-button">
#   <a class="ds-button ds-button--primary" data-engagement-tracking-analytics="SAPÂ Process Control" data-is-lightbox-footer-configured="false" data-is-lightbox-header-configured="false" href="/france/products/internal-control.html" target="_self">
#   SAPÂ Process Control
#   </a>
#   </li>
#   </ul>
#   </div>
#   </div>
#   </div>
#   </div>
#   </div>
#   </div>
#   </section>
#   </div>
#   <div class="universalLayout dx-87a299a45648942b5dc7ea82ee54853dea16b1a9 dx-row7 section">
#   <span class="lazy-loader-wrapper" data-loader="lazyScriptCssLoader" data-resource-type="sapdx/components/modular/universalLayout">
#   </span>
#   <span class="lazy-loader-wrapper" data-loader="lazyScriptCssLoader" data-resource-type="sapdx/components/modular/universalLayout">
#   </span>
#   <section class="universalLayoutComponent two-boxes vertical">
#   <div class="container-extended flex" dir="ltr">
#   <div class="row" data-row-index="0">
#   <div class="col-xs-12 col-sm-6 col-md-6 col-lg-6 col-xlg-6 universal-item vertical" data-row-index="0">
#   <div class="universal-item-content-vertical">
#   <div class="visual-content" data-animation-item="">
#   <div class="lightbox-image__container">
#   <div class="lightbox-image">
#   <div class="lightbox-image__cover-container productFiftyFifty product-content">
#   <div class="img-container lightbox-image__cover-wrapper center productFiftyFifty lightbox-disabled">
#   <picture class="adaptiveImagesContainer lightbox" data-alt="Capture d'écran de la fonctionnalité de suivi d'audit de SAP Audit Management" data-loader="pictureFillLoader">
#   <source data-height="320" data-width="494" media="(max-width: 767px) and (-webkit-min-device-pixel-ratio: 2)" srcset="/dam/application/shared/photos/products-a-b/sap-audit-management-device-mgaudtplns.png/_jcr_content/renditions/original.adapt.-1_320.false.false.false.false.png/1593031672045.png"/>
#   <source data-height="684" data-width="1056" media="(-webkit-min-device-pixel-ratio: 2) and (min-resolution: 192dpi)" srcset="/dam/application/shared/photos/products-a-b/sap-audit-management-device-mgaudtplns.png/_jcr_content/renditions/original.adapt.-1_684.false.false.false.false.png/1593031672045.png"/>
#   <source data-height="160" data-width="247" media="(max-width: 767px)" srcset="/dam/application/shared/photos/products-a-b/sap-audit-management-device-mgaudtplns.png/_jcr_content/renditions/original.adapt.-1_160.false.false.false.false.png/1593031672045.png"/>
#   <source data-height="342" data-width="528" media="(min-width: 1601px) and (max-width: 1920px)" srcset="/dam/application/shared/photos/products-a-b/sap-audit-management-device-mgaudtplns.png/_jcr_content/renditions/original.adapt.-1_342.false.false.false.false.png/1593031672045.png"/>
#   <source data-height="215" data-width="332" media="(min-width: 768px) and (max-width: 979px)" srcset="/dam/application/shared/photos/products-a-b/sap-audit-management-device-mgaudtplns.png/_jcr_content/renditions/original.adapt.-1_215.false.false.false.false.png/1593031672045.png"/>
#   <source data-height="430" data-width="664" media="(min-width: 768px) and (max-width: 979px) and (-webkit-min-device-pixel-ratio: 2)" srcset="/dam/application/shared/photos/products-a-b/sap-audit-management-device-mgaudtplns.png/_jcr_content/renditions/original.adapt.-1_430.false.false.false.false.png/1593031672045.png"/>
#   <source data-height="282" data-width="435" media="(min-width: 980px) and (max-width: 1299px)" srcset="/dam/application/shared/photos/products-a-b/sap-audit-management-device-mgaudtplns.png/_jcr_content/renditions/original.adapt.-1_282.false.false.false.false.png/1593031672045.png"/>
#   <source data-height="564" data-width="871" media="(min-width: 980px) and (max-width: 1299px) and (-webkit-min-device-pixel-ratio: 2)" srcset="/dam/application/shared/photos/products-a-b/sap-audit-management-device-mgaudtplns.png/_jcr_content/renditions/original.adapt.-1_564.false.false.false.false.png/1593031672045.png"/>
#   <source data-height="342" data-width="528" media="(min-width: 1300px) and (max-width: 1600px)" srcset="/dam/application/shared/photos/products-a-b/sap-audit-management-device-mgaudtplns.png/_jcr_content/renditions/original.adapt.-1_342.false.false.false.false.png/1593031672045.png"/>
#   <source data-height="684" data-width="1056" media="(min-width: 1300px) and (max-width: 1600px) and (-webkit-min-device-pixel-ratio: 2)" srcset="/dam/application/shared/photos/products-a-b/sap-audit-management-device-mgaudtplns.png/_jcr_content/renditions/original.adapt.-1_684.false.false.false.false.png/1593031672045.png"/>
#   <img data-height="342" data-width="528" srcset="/dam/application/shared/photos/products-a-b/sap-audit-management-device-mgaudtplns.png/_jcr_content/renditions/original.adapt.-1_342.false.false.false.false.png/1593031672045.png"/>
#   </picture>
#   </div>
#   </div>
#   </div>
#   </div>
#   </div>
#   <div class="text-content" data-animation-item="">
#   <h3 class="ds-heading ds-heading--s">Renforcez la qualitÃ© des audits et offrez des informations fiables grÃ¢ce au processus GRC</h3>
#   <div class="ds-body text-content-list">
#   <p>Rationalisez vos activitÃ©s d'audit interne et renforcez leur qualitÃ© en facilitant la documentation des preuves, l'organisation des tÃ¢ches administratives et la crÃ©ation de rapports, sur site et Ã  distance.<br/>
#   </p>
#   </div>
#   <div class="links-list">
#   <ul class="links list-unstyled">
#   <li class="type-button">
#   <a class="ds-button ds-button--primary" data-engagement-tracking-analytics="SAPÂ Audit Management" data-is-lightbox-footer-configured="false" data-is-lightbox-header-configured="false" href="/france/products/audit-management.html" target="_self">
#   SAPÂ Audit Management
#   </a>
#   </li>
#   </ul>
#   </div>
#   </div>
#   </div>
#   </div>
#   <div class="col-xs-12 col-sm-6 col-md-6 col-lg-6 col-xlg-6 universal-item vertical" data-row-index="0">
#   <div class="universal-item-content-vertical">
#   <div class="visual-content" data-animation-item="">
#   <div class="lightbox-image__container">
#   <div class="lightbox-image">
#   <div class="lightbox-image__cover-container productFiftyFifty product-content">
#   <div class="img-container lightbox-image__cover-wrapper center productFiftyFifty lightbox-disabled">
#   <picture class="adaptiveImagesContainer lightbox" data-alt="Capture d'écran d'une carte montrant des alertes de détection de fraudes générées par SAP Business Integrity Screening" data-loader="pictureFillLoader">
#   <source data-height="320" data-width="653" media="(max-width: 767px) and (-webkit-min-device-pixel-ratio: 2)" srcset="/dam/application/shared/photos/products-a-b/sap-business-integrity-screening-device-bnkdtalptp.png/_jcr_content/renditions/original.adapt.-1_320.false.false.false.false.png/1596056004633.png"/>
#   <source data-height="684" data-width="1397" media="(-webkit-min-device-pixel-ratio: 2) and (min-resolution: 192dpi)" srcset="/dam/application/shared/photos/products-a-b/sap-business-integrity-screening-device-bnkdtalptp.png/_jcr_content/renditions/original.adapt.-1_684.false.false.false.false.png/1596056004633.png"/>
#   <source data-height="160" data-width="326" media="(max-width: 767px)" srcset="/dam/application/shared/photos/products-a-b/sap-business-integrity-screening-device-bnkdtalptp.png/_jcr_content/renditions/original.adapt.-1_160.false.false.false.false.png/1596056004633.png"/>
#   <source data-height="342" data-width="698" media="(min-width: 1601px) and (max-width: 1920px)" srcset="/dam/application/shared/photos/products-a-b/sap-business-integrity-screening-device-bnkdtalptp.png/_jcr_content/renditions/original.adapt.-1_342.false.false.false.false.png/1596056004633.png"/>
#   <source data-height="215" data-width="439" media="(min-width: 768px) and (max-width: 979px)" srcset="/dam/application/shared/photos/products-a-b/sap-business-integrity-screening-device-bnkdtalptp.png/_jcr_content/renditions/original.adapt.-1_215.false.false.false.false.png/1596056004633.png"/>
#   <source data-height="430" data-width="878" media="(min-width: 768px) and (max-width: 979px) and (-webkit-min-device-pixel-ratio: 2)" srcset="/dam/application/shared/photos/products-a-b/sap-business-integrity-screening-device-bnkdtalptp.png/_jcr_content/renditions/original.adapt.-1_430.false.false.false.false.png/1596056004633.png"/>
#   <source data-height="282" data-width="576" media="(min-width: 980px) and (max-width: 1299px)" srcset="/dam/application/shared/photos/products-a-b/sap-business-integrity-screening-device-bnkdtalptp.png/_jcr_content/renditions/original.adapt.-1_282.false.false.false.false.png/1596056004633.png"/>
#   <source data-height="564" data-width="1152" media="(min-width: 980px) and (max-width: 1299px) and (-webkit-min-device-pixel-ratio: 2)" srcset="/dam/application/shared/photos/products-a-b/sap-business-integrity-screening-device-bnkdtalptp.png/_jcr_content/renditions/original.adapt.-1_564.false.false.false.false.png/1596056004633.png"/>
#   <source data-height="342" data-width="698" media="(min-width: 1300px) and (max-width: 1600px)" srcset="/dam/application/shared/photos/products-a-b/sap-business-integrity-screening-device-bnkdtalptp.png/_jcr_content/renditions/original.adapt.-1_342.false.false.false.false.png/1596056004633.png"/>
#   <source data-height="684" data-width="1397" media="(min-width: 1300px) and (max-width: 1600px) and (-webkit-min-device-pixel-ratio: 2)" srcset="/dam/application/shared/photos/products-a-b/sap-business-integrity-screening-device-bnkdtalptp.png/_jcr_content/renditions/original.adapt.-1_684.false.false.false.false.png/1596056004633.png"/>
#   <img data-height="342" data-width="698" srcset="/dam/application/shared/photos/products-a-b/sap-business-integrity-screening-device-bnkdtalptp.png/_jcr_content/renditions/original.adapt.-1_342.false.false.false.false.png/1596056004633.png"/>
#   </picture>
#   </div>
#   </div>
#   </div>
#   </div>
#   </div>
#   <div class="text-content" data-animation-item="">
#   <h3 class="ds-heading ds-heading--s">CybersÃ©curitÃ©Â : DÃ©tectez les fraudes et menez des investigations plus rapides sur les modÃ¨les suspects</h3>
#   <div class="ds-body text-content-list">
#   <p>Analysez d'immenses volumes de donnÃ©es transactionnelles en temps rÃ©el grÃ¢ce Ã  des analyses prÃ©dictives et des ensembles de rÃ¨gles extensibles qui dÃ©tectent les anomalies, la fraude ou le non-respect des politiques.<br/>
#   </p>
#   </div>
#   <div class="links-list">
#   <ul class="links list-unstyled">
#   <li class="type-button">
#   <a class="ds-button ds-button--primary" data-engagement-tracking-analytics="SAPÂ Business Integrity Screening" data-is-lightbox-footer-configured="false" data-is-lightbox-header-configured="false" href="/france/products/fraud-management.html" target="_self">
#   SAPÂ Business Integrity Screening
# ...
#   <img data-height="248" data-srcset="/dam/application/imagelibrary/photos/285000/285361.jpg/_jcr_content/renditions/285361_photo_3840_2160.jpg.adapt.440_248.false.false.false.false.jpg/1576759374092.jpg" data-width="440"/>
#   </picture>
#   </div>
#   </div>
#   </div>
#   </div>
#   </div>
#   <div class="text-content" data-animation-item="">
#   <h3 class="ds-heading ds-heading--s">Tendances GRC pour SAPÂ S/4HANA et les applications cloud</h3>
#   <div class="ds-body text-content-list">
#   <p>DÃ©couvrez nos stratÃ©gies GRC et les actions que les entreprises mettent en Åuvre ou envisagent de mettre en Åuvre avec SAPÂ S/4HANA ou toute autre application dans le cloud.<br/>
#   </p>
#   </div>
#   <div class="links-list">
#   <ul class="links list-unstyled">
#   <li class="type-link">
#   <a class="ds-link withArrow" data-engagement-tracking-analytics="Lire le rapport" data-is-lightbox-footer-configured="false" data-is-lightbox-header-configured="false" href="https://www.sapinsideronline.com/research-reports/grc-for-sap-s-4hana-and-cloud-applications-research-report/" rel="noopener noreferrer" target="_blank">
#   <span>Lire le rapport</span>
#   </a>
#   </li>
#   </ul>
#   </div>
#   </div>
#   </div>
#   </div>
#   </div>
#   </div>
#   </section>
#   </div>
#   </div>
#   </div>
#   </div>
#   </div>
#   <div class="section-divider-container ds-p-t-m">
#   <div class="section-divider ds-p-t-xxl"></div>
#   </div>
#   </section>
#   </div>
#   <div class="section dx-row12 dx-d140e4a8efe97ae20a26dd82bb84625abb22b897">
#   <section class="cx-section-component ds-p-t-xxl" data-anchor-url-selector="news-trends" id="news-trends">
#   <div class="container-extended">
#   <div class="row">
#   <div class="col-xs-12 col-sm-10 col-sm-offset-1 col-md-10 col-md-offset-1 col-lg-10 col-lg-offset-1 col-xlg-8 col-xlg-offset-2">
#   <div class="section-headline">
#   <h2 class="ds-heading ds-heading--xl">Des experts partagent les derniÃ¨res actualitÃ©s et tendances</h2>
#   </div>
#   </div>
#   </div>
#   <div class="row">
#   <div class="col-xs-12 col-sm-12 col-md-12 col-lg-12 col-xlg-12">
#   <div class="section-content"><div class="universalLayout dx-5fa753bd0d10436462be678645a2c095fb624f5a section dx-row12-1">
#   <span class="lazy-loader-wrapper" data-loader="lazyScriptCssLoader" data-resource-type="sapdx/components/modular/universalLayout">
#   </span>
#   <span class="lazy-loader-wrapper" data-loader="lazyScriptCssLoader" data-resource-type="sapdx/components/modular/universalLayout">
#   </span>
#   <section class="universalLayoutComponent three-boxes vertical">
#   <div class="container-extended flex" dir="ltr">
#   <div class="row" data-row-index="0">
#   <div class="col-xs-12 col-sm-12 col-md-4 col-lg-4 col-xlg-4 universal-item vertical" data-row-index="0">
#   <div class="universal-item-content-vertical">
#   <div class="visual-content expert-container" data-animation-item="">
#   <div class="lightbox-image__container">
#   <div class="lightbox-image">
#   <div class="lightbox-image__cover-container expert_person">
#   <div class="img-container lightbox-image__cover-wrapper center expert_person expert-image lightbox-disabled">
#   <span class="lightbox"><img alt="Thomas Frenehard" class="userProfile lazy" data-src="https://avatars.services.sap.com/images/thomas.frenehard.png"/></span>
#   </div>
#   </div>
#   </div>
#   </div>
#   <div class="expert-content">
#   <div class="expert-name">ThomasÂ Frenehard</div>
#   <div class="expert-title">Directeur, <br/>gestion des solutions GRC, <br/>SAP</div>
#   </div>
#   </div>
#   <div class="text-content" data-animation-item="">
#   <h3 class="ds-heading ds-heading--s">Unifiez la gestion des contrÃ´les et des risques grÃ¢ce Ã  l'automatisation</h3>
#   <div class="ds-body text-content-list">
#   <p>Allez au-delÃ  du reporting inter-services en harmonisant la gestion des risques afin d'amÃ©liorer la visibilitÃ©, la planification, la flexibilitÃ©, l'uniformitÃ©, la standardisation et la conformitÃ©.<br>
#   </br></p>
#   </div>
#   <div class="links-list">
#   <ul class="links list-unstyled">
#   <li class="type-link">
#   <a class="ds-link withArrow" data-engagement-tracking-analytics="Lire le blog" data-is-lightbox-footer-configured="false" data-is-lightbox-header-configured="false" href="https://blogs.sap.com/2020/05/26/grc-tuesdays-bringing-control-and-risk-management-together-through-automation/" target="_blank">
#   <span>Lire le blog</span>
#   </a>
#   </li>
#   </ul>
#   </div>
#   </div>
#   </div>
#   </div>
#   <div class="col-xs-12 col-sm-12 col-md-4 col-lg-4 col-xlg-4 universal-item vertical" data-row-index="0">
#   <div class="universal-item-content-vertical">
#   <div class="visual-content expert-container" data-animation-item="">
#   <div class="lightbox-image__container">
#   <div class="lightbox-image">
#   <div class="lightbox-image__cover-container expert_person">
#   <div class="img-container lightbox-image__cover-wrapper center expert_person expert-image lightbox-disabled">
#   <span class="lightbox"><img alt="Photo de Bruce Romney" class="userProfile lazy" data-src="https://avatars.services.sap.com/images/bruce.romney.png"/></span>
#   </div>
#   </div>
#   </div>
#   </div>
#   <div class="expert-content">
#   <div class="expert-name">BruceÂ Romney</div>
#   <div class="expert-title">Directeur principal,<br/>SAP Marketing pour les solutions GRC</div>
#   </div>
#   </div>
#   <div class="text-content" data-animation-item="">
#   <h3 class="ds-heading ds-heading--s">Assurez la stabilitÃ© du commerce international pendant les pÃ©riodes de changement rapide</h3>
#   <div class="ds-body text-content-list">
#   <p>Soulignez l'importance d'une entreprise digitale en gÃ©rant de bout en bout les opÃ©rations commerciales, de faÃ§on Ã  garantir la continuitÃ© des activitÃ©s et Ã  limiter les risques et interruptions inattendus.<br>
#   </br></p>
#   </div>
#   <div class="links-list">
#   <ul class="links list-unstyled">
#   <li class="type-link">
#   <a class="ds-link withArrow" data-engagement-tracking-analytics="Lire le blog" data-is-lightbox-footer-configured="false" data-is-lightbox-header-configured="false" href="https://blogs.sap.com/2020/04/14/global-trade-stability-amid-rapid-and-turbulent-change/" target="_blank">
#   <span>Lire le blog</span>
#   </a>
#   </li>
#   </ul>
#   </div>
#   </div>
#   </div>
#   </div>
#   <div class="col-xs-12 col-sm-12 col-md-4 col-lg-4 col-xlg-4 universal-item vertical" data-row-index="0">
#   <div class="universal-item-content-vertical">
#   <div class="visual-content expert-container" data-animation-item="">
#   <div class="lightbox-image__container">
#   <div class="lightbox-image">
#   <div class="lightbox-image__cover-container expert_person">
#   <div class="img-container lightbox-image__cover-wrapper center expert_person expert-image lightbox-disabled">
#   <span class="lightbox"><img alt="harsha vardhana a" class="userProfile lazy" data-src="https://avatars.services.sap.com/images/harsha_vardhana_achar.png"/></span>
#   </div>
#   </div>
#   </div>
#   </div>
#   <div class="expert-content">
#   <div class="expert-name">Harsha VardhanaÂ A</div>
#   <div class="expert-title">Architecte technique de solutions<br/>SAP</div>
#   </div>
#   </div>
#   <div class="text-content" data-animation-item="">
#   <h3 class="ds-heading ds-heading--s">Planifiez votre projet de mise Ã  niveau GRC maintenant</h3>
#   <div class="ds-body text-content-list">
#   <p>Explorez les exigences techniques et de planification, les Ã©tapes et les considÃ©rations Ã  prendre en compte pour garantir une mise Ã  niveau rÃ©ussie des solutions SAPÂ GRC.<br>
#   </br></p>
#   </div>
#   <div class="links-list">
#   <ul class="links list-unstyled">
#   <li class="type-link">
#   <a class="ds-link withArrow" data-engagement-tracking-analytics="Lire le blog" data-is-lightbox-footer-configured="false" data-is-lightbox-header-configured="false" href="https://blogs.sap.com/2020/04/14/grc-10.1-to-12-upgrade-plan-your-grc-upgrade-project-now/" target="_blank">
#   <span>Lire le blog</span>
#   </a>
#   </li>
#   </ul>
#   </div>
#   </div>
#   </div>
#   </div>
#   </div>
#   </div>
#   </section>
#   </div>
#   </div>
#   </div>
#   </div>
#   </div>
#   <div class="section-divider-container ds-p-t-m">
#   <div class="section-divider ds-p-t-xxl"></div>
#   </div>
#   </section>
#   </div>
#   <div class="section dx-row13 dx-e6d9f7b6acbe6249437e1ed3a8c372d6a4c10f55">
#   <section class="cx-section-component ds-p-t-xxl" data-anchor-url-selector="services" id="services">
#   <div class="container-extended">
#   <div class="row">
#   <div class="col-xs-12 col-sm-10 col-sm-offset-1 col-md-10 col-md-offset-1 col-lg-10 col-lg-offset-1 col-xlg-8 col-xlg-offset-2">
#   <div class="section-headline">
#   <h2 class="ds-heading ds-heading--xl">SAP offre toute une gamme de services et un support incomparable pour rÃ©pondre aux besoins de votre entreprise</h2>
#   </div>
#   </div>
#   </div>
#   <div class="row">
#   <div class="col-xs-12 col-sm-12 col-md-12 col-lg-12 col-xlg-12">
#   <div class="section-content"><div class="universalLayout section dx-row13-1 dx-22cea7bff5153bd6dc3579f2e14696a81d7ba553">
#   <span class="lazy-loader-wrapper" data-loader="lazyScriptCssLoader" data-resource-type="sapdx/components/modular/universalLayout">
#   </span>
#   <span class="lazy-loader-wrapper" data-loader="lazyScriptCssLoader" data-resource-type="sapdx/components/modular/universalLayout">
#   </span>
#   <section class="universalLayoutComponent four-boxes vertical">
#   <div class="container-extended flex" dir="ltr">
#   <div class="row" data-row-index="0">
#   <div class="col-xs-12 col-sm-6 col-md-6 col-lg-6 col-xlg-3 universal-item vertical" data-row-index="0">
#   <div class="universal-item-content-vertical">
#   <div class="visual-content" data-animation-item="">
#   <div class="lightbox-image__container">
#   <div class="lightbox-image">
#   <div class="lightbox-image__cover-container iconFourBox">
#   <div class="lightbox-image__cover-wrapper center lightbox-disabled">
#   <img alt="Image de la lettre I (pour Informations) dans un cercle" class="icon lazy lazyplaceholder" data-src="/content/dam/application/imagelibrary/pictograms/282000/282532-pictogram-purple.svg" src="..." title="Image de la lettre I (pour Informations) dans un cercle">
#   </img></div>
#   </div>
#   </div>
#   </div>
#   </div>
#   <div class="text-content" data-animation-item="">
#   <h3 class="ds-heading ds-heading--s">SAPÂ Help Portal</h3>
#   <div class="ds-body text-content-list">
#   <p>DÃ©couvrez de nombreuses ressources sur l'intÃ©gration, la mise en Åuvre et l'extensibilitÃ© des produits, parcourez les Learning Journeys et accÃ©dez aux ressources de support.<br>
#   </br></p>
#   </div>
#   <div class="links-list">
#   <ul class="links list-unstyled">
#   <li class="type-link">
#   <a class="ds-link withArrow" data-engagement-tracking-analytics="Consulter SAPÂ Help Portal" data-is-lightbox-footer-configured="false" data-is-lightbox-header-configured="false" href="https://help.sap.com/viewer/index" target="_blank">
#   <span>Consulter SAPÂ Help Portal</span>
#   </a>
#   </li>
#   </ul>
#   </div>
#   </div>
#   </div>
#   </div>
#   <div class="col-xs-12 col-sm-6 col-md-6 col-lg-6 col-xlg-3 universal-item vertical" data-row-index="0">
#   <div class="universal-item-content-vertical">
#   <div class="visual-content" data-animation-item="">
#   <div class="lightbox-image__container">
#   <div class="lightbox-image">
#   <div class="lightbox-image__cover-container iconFourBox">
#   <div class="lightbox-image__cover-wrapper center lightbox-disabled">
#   <img alt="Image d'un membre du support montrant un graphique" class="icon lazy lazyplaceholder" data-src="/content/dam/application/imagelibrary/pictograms/282000/282747-pictogram-purple.svg" src="..." title="Image d'un membre du support montrant un graphique">
#   </img></div>
#   </div>
#   </div>
#   </div>
#   </div>
#   <div class="text-content" data-animation-item="">
#   <h3 class="ds-heading ds-heading--s">Services aux entreprises SAP</h3>
#   <div class="ds-body text-content-list">
#   <p>BÃ©nÃ©ficiez des conseils, des meilleures pratiques et du savoir-faire d'experts du secteur, de consultants et d'ingÃ©nieurs support afin d'accÃ©lÃ©rer votre prise en main des solutions SAP et votre retour sur investissement.<br/></p>
#   </div>
#   <div class="links-list">
#   <ul class="links list-unstyled">
#   <li class="type-link">
#   <a class="ds-link withArrow" data-engagement-tracking-analytics="DÃ©couvrir nos services et notre support" data-is-lightbox-footer-configured="false" data-is-lightbox-header-configured="false" href="/france/services.html" target="_self">
#   <span>DÃ©couvrir nos services et notre support</span>
#   </a>
#   </li>
#   </ul>
#   </div>
#   </div>
#   </div>
#   </div>
#   <div class="col-xs-12 col-sm-6 col-md-6 col-lg-6 col-xlg-3 universal-item vertical" data-row-index="0">
#   <div class="universal-item-content-vertical">
#   <div class="visual-content" data-animation-item="">
#   <div class="lightbox-image__container">
#   <div class="lightbox-image">
#   <div class="lightbox-image__cover-container iconFourBox">
#   <div class="lightbox-image__cover-wrapper center lightbox-disabled">
#   <img alt="Image d'une pile de livres" class="icon lazy lazyplaceholder" data-src="/content/dam/application/imagelibrary/pictograms/281000/281602-pictogram-purple.svg" src="..." title="Image d'une pile de livres">
#   </img></div>
#   </div>
#   </div>
#   </div>
#   </div>
#   <div class="text-content" data-animation-item="">
#   <h3 class="ds-heading ds-heading--s">Certification et formation SAP</h3>
#   <div class="ds-body text-content-list">
#   <p>Atteignez vos objectifs stratÃ©giques par l'acquisition de connaissances et d'expÃ©riences pertinentes grÃ¢ce Ã  des formations disponibles dans certains bureaux SAP, dans votre rÃ©gion ou en ligne.<br/>
#   </p>
#   </div>
#   <div class="links-list">
#   <ul class="links list-unstyled">
#   <li class="type-link">
#   <a class="ds-link withArrow" data-engagement-tracking-analytics="En savoir plus sur la formation et la certification" data-is-lightbox-footer-configured="false" data-is-lightbox-header-configured="false" href="/france/training-certification.html" target="_self">
#   <span>En savoir plus sur la formation et la certification</span>
#   </a>
#   </li>
#   </ul>
#   </div>
#   </div>
#   </div>
#   </div>
#   <div class="col-xs-12 col-sm-6 col-md-6 col-lg-6 col-xlg-3 universal-item vertical" data-row-index="0">
#   <div class="universal-item-content-vertical">
#   <div class="visual-content" data-animation-item="">
#   <div class="lightbox-image__container">
#   <div class="lightbox-image">
#   <div class="lightbox-image__cover-container iconFourBox">
#   <div class="lightbox-image__cover-wrapper center lightbox-disabled">
#   <img alt="Image de deux personnes discutant Ã  l'intÃ©rieur d'une roue de gouvernail" class="icon lazy lazyplaceholder" data-src="/content/dam/application/imagelibrary/pictograms/283000/283637-pictogram-purple.svg" src="..." title="Image de deux personnes discutant Ã  l'intÃ©rieur d'une roue de gouvernail">
#   </img></div>
#   </div>
#   </div>
#   </div>
#   </div>
#   <div class="text-content" data-animation-item="">
#   <h3 class="ds-heading ds-heading--s">Centre de dÃ©veloppementÂ SAP</h3>
#   <div class="ds-body text-content-list">
#   <p>Pour tirer le meilleur parti de vos solutions SAP, suivez les guides pas Ã  pas, reportez-vous Ã  la documentation et aux vidÃ©os pratiques et abonnez-vous Ã  notre lettre d'information mensuelle.<br/>
#   </p>
#   </div>
#   <div class="links-list">
#   <ul class="links list-unstyled">
#   <li class="type-link">
#   <a class="ds-link withArrow" data-engagement-tracking-analytics="Visiter le Centre de dÃ©veloppementÂ SAP" data-is-lightbox-footer-configured="false" data-is-lightbox-header-configured="false" href="https://developers.sap.com/" target="_blank">
#   <span>Visiter le Centre de dÃ©veloppementÂ SAP</span>
#   </a>
#   </li>
#   </ul>
#   </div>
#   </div>
#   </div>
#   </div>
#   </div>
#   </div>
#   </section>
#   </div>
#   </div>
#   </div>
#   </div>
#   </div>
#   <div class="section-divider-container ds-p-t-m">
#   <div class="section-divider ds-p-t-xxl"></div>
#   </div>
#   </section>
#   </div>
#   </div>])

# %%
def getDate(soup):
    
    """ 
        Extracting the date of publishing / updating of the article
    """
    # Getting date of a video published on the article because it's the only date i found that can fit
    art_extract_datetime = soup.find('video', class_='video-js vjs-default-skin vjs-big-play-centered vjs-fluid').get('data-publishingdate')

    
    return art_extract_datetime

# %%
def getLang(soup):
    
    """ 
        Extracting the language the article is written in
    """
    
    art_lang = soup.find('meta', attrs={'name':"language"}).get('content')

    return art_lang

# %%
def getTitle(soup):
    
    """ 
        Extracting the title of the article
    """
    
    art_title = soup.find('meta', property = "og:title").get('content')
    
    return art_title

# %%
def getUrl(soup):
    
    """ 
        Extracting the url of the article
    """
    
    art_url = soup.find('meta', property = "og:url").get('content')
    
    return art_url

# %%
def getSourceName(soup):
    
    """ 
        Extracting article's source name
    """
    
    src_name = soup.find('meta', property = "og:site_name").get('content')
    
    return src_name

# %%
def getSourceType(soup):
    
    """ 
        Extracting article's source type
    """
    
    src_type = "xpath_source"
    
    return src_type

# %%
def getSourceUrl(soup):
    
    """ 
        Article's source url
    """
    
    src_url = soup.find('meta', property = "og:site_name").get('content') + ".com"
   
    return src_url

# %%
def getImg(soup):
    
    """ 
        Extracting article's image
    """
    
    src_img = soup.find('meta', property = "og:image").get('content')
    
    return src_img

# %%
def getArtAuth(soup):
    
    """ 
        Extracting article's author
    """
    
    #art_auth = soup.find('meta', attrs={'name':"twitter:data1"}).get('content')
    art_auth = "no_data"
    
    return art_auth

# %%
def getTag(soup):
    
    """ 
        Extracting article's tags if they exist
    """
    
    art_tag = soup.find('meta', attrs={'name':"keywords"}).get('content')
    
    return art_tag

# %%
getTag(soup)
# Out:
# 'GRC, gouvernance, risques, conformitÃ©, cybersÃ©curitÃ©'

# %%
def scrapPage(soup):
    
    """ 
        Function combining the previous ones and stocking the list of results in a dataframe line
    """
    
    art_content, art_content_html = getContent(soup)
    
    art_extract_datetime = getDate(soup)
    
    art_lang = getLang(soup)
    
    art_title = getTitle(soup)
    
    art_url = getUrl(soup)
    
    src_name = getSourceName(soup)
    
    src_type = "xpath_source"
    
    src_url = getSourceUrl(soup)
    
    src_img = getImg(soup) 
    
    art_auth = getArtAuth(soup)
    
    art_tag = getTag(soup)
    
    return art_content, art_content_html, art_extract_datetime, art_lang, art_title, art_url, src_name, src_type, src_url, src_img, art_auth, art_tag

# %%
df_scrap.loc[1]=scrapPage(soup)

# %%
df_scrap
# Out:
#                                          art_content  \
# 1  \n\n\n\n\n\nIntÃ©grez les processus GRC pour o...
#
#                                     art_content_html  art_extract_datetime  \
# 1  [[[\n, <section class="cx-section-component ds...  2020-06-17T00:00:00Z
#
#           art_lang                                          art_title  \
# 1  French (France)  CybersÃ©curitÃ© et gestion de la gouvernance, ...
#
#                                              art_url src_name      src_type  \
# 1  https://www.sap.com/france/products/erp-financ...      SAP  xpath_source
#
#    src_url                                            src_img art_auth  \
# 1  SAP.com  http://www.sap.com/dam/application/imagelibrar...  no_data
#
#                                              art_tag
# 1  GRC, gouvernance, risques, conformitÃ©, cybers...
