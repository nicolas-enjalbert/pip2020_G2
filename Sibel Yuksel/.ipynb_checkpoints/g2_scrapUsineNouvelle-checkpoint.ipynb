# %%
"""Created on Monday Jan 6 11:03:00 
2019 Group 2
@authors: Sibel Yuksel"""
# Out:
# 'Created on Monday Jan 6 11:03:00 \n2019 Group 2\n@authors: Sibel Yuksel'

# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup
from textblob import TextBlob
import datetime

# %%
url1 = 'https://www.usinenouvelle.com/article/industrie-du-futur-castres-mazamet-mise-sur-la-cybersecurite.N903244'
url2 = "https://www.usinenouvelle.com/article/la-5g-enjeu-industriel-cle-pour-la-donnee-intelligente.N1026544"
url3 = 'https://www.usinenouvelle.com/article/quand-siemens-preche-l-entreprise-numerisee-a-ses-clients.N547678'
url4 = 'https://www.usinenouvelle.com/editorial/le-sud-alsace-un-territoire-d-industrie-dans-les-starting-blocks.N818615'


def scraping_linternaute(url : 'str') -> list:
    """Documentation
    function which from a url creates a BeautifulSoup object, then extract different informations about the article and the 
    source. Then researches informations about the article and the website. It finally returns all this data as a list
  
    Parameters:
        url(str): The url that we will scrap 
        
    Out:
        list: it contains some propreties of the article and the sources 

    """
    response = requests.get(url)
    html_soup = BeautifulSoup(response.text, 'html.parser')
    
    src_type = 'xpath_source'
    src_url = 'https://www.usinenouvelle.com/'
    src_name = "L'Usine Nouvelle"
    
    # find the article URL (art_url) 
    if html_soup.find("meta", {"property": "og:url"}) is not None:
        art_url = html_soup.find("meta", {"property": "og:url"})['content']
    else:
        art_url = url
        
    # find the article Title (art_title)  
    art_title = html_soup.title.get_text().replace('\xa0','')
    
    
    # find the article Author (art_auth)  
    if html_soup.find("meta",{"itemprop":"name"}) is not None:
        art_auth = html_soup.find("meta",{"itemprop":"name"})['content']
        if art_auth==[]: art_auth = 'no-data' 
    else:
        art_auth = 'no-data'
        
        
    # find the date of publication of the article (art_published_datetime) (format: datetime)  
    if html_soup.find("meta", {"name": "lastmod"}) is not None:
        art_published = html_soup.find("meta", {"name": "lastmod"})['content'][:10]      # take the date and remove the hour
        art_published_datetime = datetime.datetime.strptime(art_published,'%Y-%m-%d').date()  # put at the format datetime      
    elif html_soup.find("time") is not None:
        art_published = html_soup.find("time")["datetime"][:10]    
        art_published_datetime = datetime.datetime.strptime(art_published,'%Y-%m-%d').date() 
    # if there is no date, we replace None with the date of today
    else:
        art_published_datetime = datetime.datetime.today().date()     # 

        
    #src_img  
    if html_soup.find("meta", {"property": "og:image"}) is not None:
        art_img = html_soup.find("meta", {"property": "og:image"})["content"]
         
    else:
        art_img = 'no-data'
        
        
    #art_tag  
    art_tag = []
    if html_soup.find_all("meta",{'itemprop':"keywords"}) is not None:
        html_tag = html_soup.find_all("meta",{'itemprop':"keywords"})
        for i in html_tag:
            tag_i = i['content']
            art_tag.append(tag_i)
    else:
        art_tag = 'no-data'
        
    #art_content_html  and  art_content
    art_content_html_intro = html_soup.find("h2", {"class" : "chapo"}).get_text()
    art_content_html_corps = html_soup.find("div", {"class": "contenuArt"})    #prend une sous balise en trop 
    art_content_html = [art_content_html_intro,art_content_html_corps]
    art_content = art_content_html_intro + art_content_html_corps.get_text().replace("\'"," ' ")      # REPLACE NE MARCHE PAS

    #art_lang   
    a = TextBlob(art_content)
    art_lang = a.detect_language()
    
    return [art_content,art_content_html,art_published_datetime,art_lang,art_title,art_url,src_name,src_type,src_url,art_img,art_auth,art_tag] 


scraping_linternaute(url1)
# Out:
# ["\nPubli-rédactionnel\n                                                     \r\n\tL’ADN industriel est inscrit depuis des générations dans le patrimoine du territoire de Castres-Mazamet. Cette « terre du Sud-Ouest où il fait bon vivre » attire à elle de nombreux industriels. L’un des domaines d’excellence de Castres-Mazamet concerne le numérique et la cybersécurité. \r\n\n                \n\n\n\n\n\n\n\nTwitter\n\n\n\n\n\nFacebook\n\n\n\n\n\nLinkedin\n\n\n\n\n\nFlipboard\n\n\n\n\n\nEmail\n\n\n\n\n\r\n\tAprès avoir aménagé en 1998 le réseau de fibre optique de l’agglomération, la SEM Intermédiasud, créée à l’initiative de la collectivité, donne naissance à IMS Networks, spécialisé dans le déploiement, l’infogérance et la sécurité d’infrastructures et réseaux critiques.\n\r\n\t\xa0\n\nDéfendre les systèmes industriels\n\r\n\t\xa0\n\r\n\tLe prestataire de services managés de cybersécurité a mis en place des activités de SOC (Security Operation Center) certifiées ISO 27001. IMS Networks propose ainsi un service qui cartographie et détecte les attaques visant les systèmes industriels. Dès lors, son équipe d’experts24/7 supervise les intrusions en temps réel et assure l’intégrité de la disponibilité de l’outil de production.\n\r\n\t\xa0\n\nUne Technopole comme accélérateur de réussite\n\r\n\t\xa0\n\r\n\tPlus largement, l’agglomération sud tarnaise a également su mettre en place un environnement favorable au développement de projets innovants. Ses structures d’accélération à taille humaine, incubateur et pépinière d’entreprises, pilotées par Castres-Mazamet Technopole, séduisent de plus en plus de start-up en recherche d’un accompagnement sur-mesure.\n\r\n\t\xa0\n\nwww.castres-mazamet.fr\n\r\n\t\xa0\n\n\n\n\n\n                            [PUBLI-DOSSIER] Nouvelle Aquitaine Terre d ' innovation industrielle\n                            10 / 11\n\n\n\n",
#  ['\nPubli-rédactionnel\n                                                     \r\n\tL’ADN industriel est inscrit depuis des générations dans le patrimoine du territoire de Castres-Mazamet. Cette « terre du Sud-Ouest où il fait bon vivre » attire à elle de nombreux industriels. L’un des domaines d’excellence de Castres-Mazamet concerne le numérique et la cybersécurité. \r\n\n                \n\n',
#   <div class="contenuArt" itemprop="articleBody">
#   <script>
#       window.App = window['App'] || {};
#       App.Seo = App['Seo'] || {};
#       App.Seo.titrePage = 'Industrie du futur : Castres-Mazamet mise sur la cybersécurité';
#   </script>
#   <ul class="socialBar">
#   <li class="btn-twitter jqtwitter" data-title="Industrie du futur : Castres-Mazamet mise sur la cybersécurité" data-url="https://www.usinenouvelle.com/article/industrie-du-futur-castres-mazamet-mise-sur-la-cybersecurite.N903244">
#   <a href="#">
#   <span class="pictoTwitter"></span>
#   <span class="txtSocialBar">Twitter</span>
#   </a>
#   </li>
#   <li class="btn-facebook jqfacebook" data-title="Industrie du futur : Castres-Mazamet mise sur la cybersécurité" data-url="https://www.usinenouvelle.com/article/industrie-du-futur-castres-mazamet-mise-sur-la-cybersecurite.N903244">
#   <a href="#">
#   <span class="pictoFacebook"></span>
#   <span class="txtSocialBar">Facebook</span>
#   </a>
#   </li>
#   <li class="btn-linkedin jqlinked-in" data-summary="L&amp;rsquo;ADN industriel est inscrit depuis des g&amp;eacute;n&amp;eacute;rations dans le patrimoine du territoire de Castres-Mazamet. Cette &amp;laquo; terre du Sud-Ouest o&amp;ugrave; il fait bon vivre &amp;raquo; attire[&amp;hellip;]" data-title="Industrie du futur : Castres-Mazamet mise sur la cybersécurité" data-url="https://www.usinenouvelle.com/article/industrie-du-futur-castres-mazamet-mise-sur-la-cybersecurite.N903244">
#   <a href="#">
#   <span class="pictoLinkedin"></span>
#   <span class="txtSocialBar">Linkedin</span>
#   </a>
#   </li>
#   <li class="btn-flipboard jqflipboard" data-title="Industrie du futur : Castres-Mazamet mise sur la cybersécurité" data-url="https://www.usinenouvelle.com/article/industrie-du-futur-castres-mazamet-mise-sur-la-cybersecurite.N903244">
#   <a href="#">
#   <span class="pictoFlipboard"></span>
#   <span class="txtSocialBar">Flipboard</span>
#   </a>
#   </li>
#   <li class="btn-email jqEmail" data-title="Industrie du futur : Castres-Mazamet mise sur la cybersécurité" data-url="https://www.usinenouvelle.com/article/industrie-du-futur-castres-mazamet-mise-sur-la-cybersecurite.N903244">
#   <a href="#">
#   <span class="pictoEmail"></span>
#   <span class="txtSocialBar">Email</span>
#   </a>
#   </li>
#   </ul>
#   <p>
#   <div>
#   	Après avoir aménagé en 1998 le réseau de fibre optique de l’agglomération, la SEM Intermédiasud, créée à l’initiative de la collectivité, donne naissance à IMS Networks, spécialisé dans le déploiement, l’infogérance et la sécurité d’infrastructures et réseaux critiques.</div>
#   <div>
#   	 </div>
#   <div>
#   <span class="interTitre">Défendre les systèmes industriels</span></div>
#   <div>
#   	 </div>
#   <div>
#   	Le prestataire de services managés de cybersécurité a mis en place des activités de SOC (Security Operation Center) certifiées ISO 27001. IMS Networks propose ainsi un service qui cartographie et détecte les attaques visant les systèmes industriels. Dès lors, son équipe d’experts24/7 supervise les intrusions en temps réel et assure l’intégrité de la disponibilité de l’outil de production.</div>
#   <div>
#   	 </div>
#   <div>
#   <span class="interTitre">Une Technopole comme accélérateur de réussite</span></div>
#   <div>
#   	 </div>
#   <div>
#   	Plus largement, l’agglomération sud tarnaise a également su mettre en place un environnement favorable au développement de projets innovants. Ses structures d’accélération à taille humaine, incubateur et pépinière d’entreprises, pilotées par Castres-Mazamet Technopole, séduisent de plus en plus de start-up en recherche d’un accompagnement sur-mesure.</div>
#   <div>
#   	 </div>
#   <div>
#   <a href="https://www.castres-mazamet.fr/" rel="nofollow" target="_blank">www.castres-mazamet.fr</a></div>
#   <div>
#   	 </div>
#   </p>
#   <div class="BeOpWidget" data-name="below-article"></div>
#   <div class="navDossier">
#   <a class="previousArt" href="/article/l-enit-mixe-enseignement-recherche-et-partenariats-industriels.N903309"><img alt="Article précédent" src="/images/commun/prev_slider_small.png"/></a>
#   <a class="titreCurrentArt" href="/article/publi-dossier-nouvelle-aquitaine-terre-d-innovation-industrielle.N903234">
#                               [PUBLI-DOSSIER] Nouvelle Aquitaine Terre d'innovation industrielle
#                               <span class="nbPage">10 / 11</span>
#   </a>
#   <a class="nextArt" href="/article/castres-mazamet-accompagne-les-chefs-d-entreprises-avec-hello-projets.N903229"><img alt="Article suivant" src="/images/commun/next_slider_small.png"/></a>
#   </div>
#   </div>],
#  datetime.date(2019, 11, 13),
#  'fr',
#  'Industrie du futur : Castres-Mazamet mise sur la cybersécurité - Publi-dossier',
#  'https://www.usinenouvelle.com/article/industrie-du-futur-castres-mazamet-mise-sur-la-cybersecurite.N903244',
#  "L'Usine Nouvelle",
#  'xpath_source',
#  'https://www.usinenouvelle.com/',
#  'https://www.usinenouvelle.com/mediatheque/9/6/1/000820169_image_600x315.png',
#  'Usine Nouvelle',
#  ["Nouvelle Aquitaine Terre d'innovation industrielle"]]
