# %%
import time

for i in range(3):
    # %run ./g2_crawling_test_flavien_v1.ipynb
    time.sleep(10)
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
