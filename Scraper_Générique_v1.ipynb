# %%
from bs4 import BeautifulSoup as bs
from textblob import TextBlob
import pandas as pd
import numpy as np
import datetime
import requests
import json
import re

# %%
df_scrap = pd.DataFrame(columns=['art_content','art_content_html','art_extract_datetime','art_lang','art_title','art_url','src_name','src_type','src_url','src_img','art_auth','art_tag']  )
df_scrap
# Out:
# Empty DataFrame
# Columns: [art_content, art_content_html, art_extract_datetime, art_lang, art_title, art_url, src_name, src_type, src_url, src_img, art_auth, art_tag]
# Index: []

# %%
#url="https://www.cnrtl.fr/lexicographie/ontologie"
url = "https://www.linguee.fr/anglais-francais/traduction/blob.html"

# %%
def getSoup(url):
    
    response = requests.get(url)
    print("statut de la reponse ", response.status_code)
    print('\n')
    soup = bs(response.text, 'html.parser')
    print(soup)
    
    return soup

# %%
soup = getSoup(url)
# Out:
# statut de la reponse  200
#
#
# <!DOCTYPE html>
#
# <html il_fr="" il_fr'="">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content='De très nombreux exemples de phrases traduites contenant "blob" – Dictionnaire français-anglais et moteur de recherche de traductions françaises.' name="description"/>
# <meta content="blob, Linguee, anglais, dictionnaire, traductions, français, dictionnaire anglais, moteur de recherche, traduction" name="keywords"/>
# <meta content="fr" name="language"/>
# <meta content="fr" http-equiv="content-language"/>
# <meta content="https://d1wigddrwdtsce.cloudfront.net/img5/ogimage.jpg" name="og:image"/>
# <meta content="image/jpeg" property="og:image:type">
# <meta content="1200" property="og:image:width">
# <meta content="630" property="og:image:height">
# <meta content="Linguee.fr" property="og:site_name"/>
# <meta content="blob - Traduction française – Linguee" property="title"/>
# <meta content="blob - Traduction française – Linguee" property="og:title"/>
# <meta content='De très nombreux exemples de phrases traduites contenant "blob" – Dictionnaire français-anglais et moteur de recherche de traductions françaises.' property="og:description"/>
# <meta content="index, follow" name="robots"/>
# <link href="https://www.linguee.fr/anglais-francais/traduction/blob.html" rel="canonical"/>
# <meta content="https://www.linguee.fr/anglais-francais/traduction/blob.html" property="og:url"/>
# <link href="ios-app://338225335/www.linguee.fr/anglais-francais/traduction/blob.html" media="screen and (os: ios)" rel="alternate"/>
# <link href="android-app://com.linguee.linguee/http/www.linguee.fr/anglais-francais/traduction/blob.html" media="screen and (os: android)" rel="alternate"/>
# <meta content="linguee://www.linguee.fr/anglais-francais/traduction/blob.html" property="al:ios:url"/>
# <meta content="338225335" property="al:ios:app_store_id"/>
# <meta content="Linguee" property="al:ios:app_name"/>
# <link href="https://d1wigddrwdtsce.cloudfront.net/img5/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/>
# <link href="https://d1wigddrwdtsce.cloudfront.net/img5/favicon.svg" rel="icon" sizes="any" type="image/svg+xml"/>
# <link href="https://d1wigddrwdtsce.cloudfront.net/img5/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
# <link href="https://d1wigddrwdtsce.cloudfront.net/img5/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
# <link href="/css3/sncmp.css" rel="stylesheet" type="text/css"/>
# <script src="//cdn.snigelweb.com/adconsent/adconsent.js" type="text/javascript"></script>
# <script>
#    try {
#      __cmp('setLogo', 'https://d1wigddrwdtsce.cloudfront.net/img5/dl_Linguee_Logo.svg', function(result){});
#      __cmp('setPrivacyPolicy', '/francais-anglais/page/privacy.php', function(result){});
#      __cmp('enableWelcomeTitle', null, null);
#      __cmp('enableWelcomeText', null, null);
#      __cmp('setTranslationFiles',{ path: 'https://d1wigddrwdtsce.cloudfront.net/5_db16f23c/javascript/consent_translation', locales: ['de', 'en', 'fr', 'es', 'pt', 'nl','it','pl','ru', 'zh','jp'] }, function(result){});
#
#                                     __tcfapi("disableLegitimateInterest");
#                                     __tcfapi('setPublisherPurposes', null, function(result) {}, {
#                                     purposes: [],
#                                     legIntPurposes: [],
#                                     stacks: [],
#                                     legIntStacks: [],
#                                     customPurposes: {
#                                         definition: [
#                                             {
#                                                 id: 1,
#                                                 name: "Confort",
#                                                 description: "Ces cookies permettent au site web d'offrir des fonctionnalités et une personnalisation accrues, en mémorisant par exemple les pages que vous avez visitées et en adaptant votre expérience en fonction de ces données.",
#                                                 descriptionLegal: ""
#                                             },
#                                             {
#                                                 id: 2,
#                                                 name: "Performance",
#                                                 description: "Ces cookies nous renseignent sur l'utilisation du site. Ils nous aident à améliorer nos services ainsi que le site en lui-même. Avec ces cookies, nous mesurons, par exemple, la fréquence de visite des utilisateurs et les fonctions qu'ils utilisent.",
#                                                 descriptionLegal: ""
#                                             },
#                                          ],
#                                         purposes: [1,2],
#                                         legIntPurposes: []
#                                     }});
#  } catch(error) {
#  	console.warn(error)
#  }
#  </script>
# <script>
#  document.addEventListener('cmpGUIShow', function(event){
# M.requireAsync(['DAP'], function (dap) { dap.sendEvent(dap.EVENTID_CONSENT_SHOW, dap.PAGEID_SEARCH, {}); });
#        });
#  document.addEventListener('cmpGUISubmit', function(event){
# M.requireAsync(['DAP'], function (dap) { __tcfapi('getTCData', 2, (tcData, success) => { dap.refreshUID(tcData); }, null);dap.sendEvent(dap.EVENTID_CONSENT_SUBMIT, dap.PAGEID_SEARCH, {}); });
#        });
#  document.addEventListener('cmpConsentAvailable', function(event){
# M.requireAsync(['DAP'], function (dap) { __tcfapi('getTCData', 2, (tcData, success) => { dap.refreshUID(tcData); }, null);dap.sendEvent(dap.EVENTID_CONSENT_AVAILABLE, dap.PAGEID_SEARCH, {}); });
#        });
#  </script>
# <meta content="width=device-width, initial-scale=1, user-scalable=0" name="viewport">
# <meta name="google" value="notranslate">
# <link href="https://d1wigddrwdtsce.cloudfront.net/img5/apple-touch-icon3.png" rel="apple-touch-icon"><meta content="Linguee" name="apple-mobile-web-app-title"/>
# <title>blob - Traduction française – Linguee</title>
# <style>#small_logo,#search_button,#search_button2,a.audio,a.expand_i,.source_url,.warnSign,.warnSign2{background-image:url(https://d1wigddrwdtsce.cloudfront.net/img5/sprites15.png);background-repeat:no-repeat}body,#header,#header input{font-family:Avenir Next,Roboto Condensed,Arial,sans-serif}body{background-color:#dedede;margin:0;padding:0;color:#3c3c3c;-webkit-text-size-adjust:100%}html{background-color:#f1f1f1;height:100%}#outer_div{max-width:1090px;min-width:620px;margin-left:auto;margin-right:auto;position:relative}#ip_page_wrapper,#l_page_wrapper,#ip_content_wrapper,#outer_div{min-height:100%;height:100%}img{display:block;border:0}a{color:inherit}a[href],a[onclick],a[href] b{cursor:pointer}a:link,a:visited{text-decoration:none}.bold{font-weight:bold}td{padding:0;text-align:left}th{padding:7px 0 3px 0;text-align:left;font-weight:bold;font-size:.7em;color:#333}#linguee{float:left}h1.noresults{font-weight:400;font-style:italic;font-size:18px;text-align:center;margin-top:30px}#header{position:relative;padding:0;margin-bottom:15px;height:80px}#footer{display:none}#attribution,#important_terms,#currently_searched{display:none}#social_media_toggles{display:none}#form1{margin:0}#selectionPopup{display:none}#lingueecontent{min-height:300px;margin:2px 0 150px 0;position:relative;color:#333;overflow:visible;background:white}.tooltip{display:none}.innercontent{clear:both}#maindiv{background-color:#fff;padding-bottom:80px;margin:0;position:relative;top:0;min-height:100%}#layoutmain{padding:3px 0 0 0;margin:0;vertical-align:top}.resultpage #maindiv{min-height:1200px}#reportAdForm,#footer-overlay,#cookie-hint,.dialog{display:none}#flashMp3Div audio,#audioDiv audio,#flashMp3Div,#audioDiv,#flashDiv{display:none}h1 .openTriangle{float:left;color:#888;font-size:20px;width:14px;text-align:left}@media only screen and (max-device-width :650px){h1 .openTriangle{height:1.2em}}.ad_topAndRect #header,.ad_topAndHalfpage #header{min-width:421px}.ad_topAndRect #result_container.webservice,.ad_topAndHalfpage #result_container.webservice{min-width:300px}.ad_topAndRect #outer_div,.ad_topAndHalfpage #outer_div{max-width:1230px;min-width:880px}.ad_LRectHalfpageRRectSkys #outer_div,.ad_LRectHalfpageRRectHalfpage #outer_div{max-width:1610px;min-width:1250px}.ad_leftAndRect #outer_div{max-width:1410px;min-width:1070px}.ad_leftAndRectWide #outer_div{max-width:1410px;min-width:1106px}.ad_leftAndRight #outer_div{max-width:1410px;min-width:910px}.ad_topAndRight #outer_div,.ad_translatorAndRight #outer_div,.ad_ad_underHeaderPremiumAndRight #outer_div,.ad_top #outer_div{min-width:738px}.ad_narrow #outer_div{min-width:300px}#banners_right,#banners_top,#banners_left{display:none}#mainlayout{position:relative;padding:0;min-height:100%;height:100%}.ad_top #mainlayout{padding-top:108px}.ad_topAndRight #mainlayout{padding-top:108px;padding-right:180px}.ad_topAndRect #mainlayout,.ad_topAndHalfpage #mainlayout{padding-top:108px;padding-right:320px}.ad_leftAndRect #mainlayout{padding-right:320px;padding-left:180px}.ad_LRectHalfpageRRectSkys #mainlayout,.ad_LRectHalfpageRRectHalfpage #mainlayout{padding-right:360px;padding-left:360px}.ad_leftAndRectWide #mainlayout{padding-right:356px;padding-left:180px}.ad_leftAndRight #mainlayout{padding-right:180px;padding-left:180px}.ad_translatorAndRight #mainlayout,.ad_underHeaderPremiumAndRight #mainlayout{padding-top:8px;padding-right:172px}#navi_bar_o{position:relative;height:34px;background-color:#67809a;margin-bottom:19px;border-bottom:1px solid #58728c}#navi_bar{position:relative;height:140px;overflow:hidden}#navi_bar_ul{line-height:18px;padding:0;height:35px;list-style-type:none;margin:0;position:relative;float:left;left:50%;display:block;width:auto}.ie7 #navi_bar_ul{display:block;float:left}.navi_li{font-size:14px;padding:0 10px 0 10px;margin:0;height:140px;color:#fff;vertical-align:middle;position:relative;right:50%;display:list-item;float:left}.ie7 .navi_li,.ie8 .navi_li{display:list-item;float:left}.navi_li>.i{position:rel ...
# </style>
# <style>.lQueryHeader__lingueeLogo {background-image: URL('https://d1wigddrwdtsce.cloudfront.net/img5/dl_Linguee_Logo.svg') !important;} .lMainNavbar__deeplLogoLink::before {background-image: URL('https://d1wigddrwdtsce.cloudfront.net/img5/DeepL_Logo_darkBlue_v2.svg') !important;} .dlTopBanner__content {background-image: URL('https://d1wigddrwdtsce.cloudfront.net/img5/banner/bg_orange_noise.png') !important;} .dlTopBanner__content::before {background-image: URL('https://d1wigddrwdtsce.cloudfront.net/img5/banner/bg_orange_noise.png') !important;} .dlTopBanner__content::after {background-image: URL('https://d1wigddrwdtsce.cloudfront.net/img5/banner/robot_with_girl.svg') !important;} .footer__social--twitter {background-image: URL('https://d1wigddrwdtsce.cloudfront.net/img5/icon_twitter_v2.svg') !important;} .footer__social--facebook {background-image: URL('https://d1wigddrwdtsce.cloudfront.net/img5/icon_fb_v2.svg') !important;} .footer__social--linkedin {background-image: URL('https://d1wigddrwdtsce.cloudfront.net/img5/icon_linkedin_v2.svg') !important;} </style>
# <script type="text/javascript">
# window.pageState={  interfaceLang:'FR',
#   langCodes:['FR','EN'],
#   sourceIsLang1:0,
#   mainFlag:'fr',
#   baseURL:'/francais-anglais',
# };
# var cookie='8ff9e326-9f39-6f66-8be9-8f5312ceebe5';
# var cookieLoginAuth='';
# var auxiliaryDictLang='deutsch-englisch';
# var numberQueriesSoFar=1;
# var currentYear=2021;
# var currentMonth='Jan';
# var currentDay=11;
# var currentHour=10;
# var currentMinute=19;
# var currentSecond=7;
# var hasCookies='0';
# var layout=4;
# var expertMode=0;
# var ipTestGroup=18;
# var adsInIFrames=0;
# var isStartPage=0;
# var isAboutPage=0;
# var newtestgroup='B';
# var numberCachedQueries=1;
# var timestampHead=new Date().getTime();
# var lingueeEncoding='latin-9';
# var sourceIsLang1=pageState.sourceIsLang1;;
# var langCodes=pageState.langCodes;
# var mainFlag=pageState.mainFlag;
# var baseURL=pageState.baseURL;
# var selectionBaseURL='/francais-anglais';
# var interfaceLang=pageState.interfaceLang;
# var queryFrequency=0;
# var tld='fr';
# var isLoggedIn=false;
# var statsEndpoint='prod';
# window.texts={
# 'acPressEnter': 'Appuyez sur Entrée pour chercher «&nbsp;QUERYHERE&nbsp;»'
# ,'acSearchFor': 'Rechercher &ldquo;QUERYHERE&rdquo;...'
# };
# var pressEnterText=texts['acPressEnter']; var acSearchForText=texts['acSearchFor'];
# var pastingLongStringsEnabled = false;
# var query = pageState.query = 'blob';
# var correctSpellingOfQuery = pageState.correctSpellingOfQuery = 'blob';
# pageState.casedQuery = 'blob';
# var numberPhrases = 0;
# var numberSentences = 27;
# var sourceLang = 'EN';
# var sourceFlag = 'gb';
# var targetLang = 'FR';
# pageState.userTestGroups=[];
# var keyPressField=false;var queryFocussedOnKeyPress=false;var adPlacement="";var adSuppressed=false;var isApp=!!((window.pageState&&window.pageState.appInfo)||(/\b(app|android)[\-\.]/).test(document.domain)||(/\boverride-host=[^=\s]*(app|android)[\-\.]/).test(document.cookie)||document.cookie.search("app=")>=0);var isAppF=isApp;function queryIsMobilePhone(){return typeof window.matchMedia!="undefined"&&window.matchMedia("only screen and (max-device-width : 650px)").matches}function is_touch_device(){return"ontouchstart" in window||!!(navigator.msMaxTouchPoints)}var isMobilePhone=queryIsMobilePhone();var isMobilePhoneOrTablet=isApp||isMobilePhone||(typeof window.matchMedia!="undefined"&&window.matchMedia("only screen and (max-device-width : 799px)").matches&&is_touch_device());var isMobileNarrowDevice=typeof window.matchMedia!="undefined"&&window.matchMedia("only screen and (max-device-width : 767px)").matches;var isIPhone=typeof navigator.userAgent!="undefined"&&!!navigator.userAgent.match(/[\(\/](iPhone|iPod)/);var isIPad=typeof navigator.userAgent!="undefined"&&!!navigator.userAgent.match(/[\(\/](iPad)/);var isAndroid=typeof navigator.userAgent!="undefined"&&navigator.userAgent.indexOf("Android")!=-1;var isMobileLayout=isApp||isMobilePhone;var isStartPage=window.isStartPage||false;if(window.pageState){window.pageState.isMobileLayout=isMobileLayout;window.pageState.isApp=isApp;window.pageState.isAppF=isAppF}function adWidthClass(a){if(isMobileLayout){return""}if(a==""||a=="topAndRight"){return"ad_180"}else{if(a=="topAndRect"||a=="topAndHalfPage"||a=="leftAndRight"){return"ad_355"}else{if(a=="leftAndRect"||a=="leftAndRectWide"){return"ad_530"}else{if(a=="LRectHalfpageRRectSkys"||a=="LRectHalfpageRRectHalfpage"){return"ad_705"}else{return"ad_705"}}}}}function l_page_wrapper(b,d,a){var c=(is_touch_device())?" touch_device":" mouse_device";if(isIPhone){c+=" iphone ios"}else{if(isIPad){c+=" ipad ios"}else{if(isAndroid){c+=" android"}}}document.body.className=document.body.className+c;if(b){window.pageState.isAdsEnabled=!!b&&!d;adPlacement=correctAdPlacement(b);adSuppressed=d;if(adSuppressed&&(" "+document.body.className+" ").replace(/[\t\r\n\f]/g," ").indexOf(" startpage ")>-1){adPlacement=adPlacement+"_suppressed"}if(adPlacement){document.write(unescape("%3Cdiv id='l_page_wrapper' class='ad_"+adPlacement+" "+adWidthClass(adPlacement)+"'%3E"))}}}function correctAdPlacement(b){if(isMobileLayout){return""}var a=document.documentElement.clientWidth;var c=document.documentElement.clientHeight;if(b=="topAndHalfPage"){b="topAndHalfpage"}if(b=="LRectHalfpageRRectHalfpage"){if(a<1580){b="topAndRect"}}if(b=="topAndRect"||b=="topAndHalfpage"){if(c<870){b="leftAndRect"}else{if(a<=895){b="topAndRight"}}}if(b=="topAndRect"){b="leftAndRect"}if(b=="leftAndRect"){if(a<1200){b="leftAndRight"}}if(isMobileNarrowDevice&&b=="topAndRight"){b="top"}return b}function setVisible(b,a){var c=document.getElementById(b);if(c){c.style.display=(a)?"":"none"}}function isVisible(b){if(b==document){return true}if(!b){return false}if(!b.parentNode){return false}function a(c){if(c.display=="none"){return false}if(c.visibility=="hidden"){return false}}if(b.style&&a(b.style.visibility)){return false}if(window.getComputedStyle&&a(window.getComputedStyle(b,""))){return false}if(b.currentStyle&&a(b.currentStyle)){return false}return isVisible(b.parentNode)}function isChar(a){if((a>64&&a<91)||(a>96&&a<123)||a>191||a==0){return true}}var isIE=(/MSIE/).test(navigator.userAgent);var isFF=(/Firefox/).test(navigator.userAgent);var isChrome=(/Chrome/).test(navigator.userAgent)&&(/Google\ Inc/).test(navigator.vendor);var isSafari=(/Safari/).test(navigator.userAgent)&&(/Apple\ Computer/).test(navigator.vendor);var isOpera=(/Opera/).test(navigator.userAgent);var isEdge=(/Edge/).test(navigator.userAgent);var isIENewer=(/Trident/).test(navigator.userAgent);String.prototype.trim||(String.prototype.trim=function(){return this.replace(/^\s+|\s+$/g,"")});String.prototype.startsWith||(St ...
#
# </script>
# <script>
#                 if (!window.pageState.isMobileLayout) {
#                     var __loadScriptAsync = function(url) {
#                         var node = document.getElementsByTagName('script')[0];
#                         var script = document.createElement('script');
#                         script.type = "text/javascript";
#                         script.src = url;
#                         script.async = true;
#                         node.parentNode.insertBefore(script, node);
#                     };
#
#   __loadScriptAsync('//static.h-bid.com/linguee.fr/20200317/snhb-linguee.fr.min.js');
# }
# </script>
# </link></meta></meta></meta></meta></meta></head>
# <body class="layout4 resultpage nonmobile design2019" id="body">
# <script>M.requireAsync(['DAP'], function (dap) { dap.sendPageView(dap.PAGEID_SEARCH); });</script>
# <script type="text/javascript">l_page_wrapper('LRectHalfpageRRectHalfpage',0,0);</script>
# <div id="ip_page_wrapper"><div id="ip_content_wrapper">
# <div class="tooltip" id="tooltip"> </div>
# <div id="selectionPopup">
# <ul class="selectionPopupActions">
# <li><a href="javascript:lingueeSearch()">Consulter Linguee</a></li>
# <li><a href="javascript:proposeTranslation()"> Proposer comme traduction pour "blob" </a></li>
# <li><a href="javascript:clipboardCopy()">Copier</a></li>
# </ul>
# <div class="selectionPopupFooter"></div>
# </div>
# <div class="il_FR il_FR" id="outer_div">
# <div id="mainlayout">
# <div id="banners_top">
# <div class="verticalAdText" id="banner_top">
# <div id="snhb-top_tablet_leaderboard-0"></div>
# </div>
# </div>
# <div id="snigel_ads_right" style="  top: 0;right: 0; position: absolute;text-align: center;">
# <div id="snhb-right_side_top-0" style="margin-bottom:10px;"></div>
# <div id="snhb-right_side_bottom_sticky-0"></div>
# </div>
# <div id="snigel_ads_left" style=" top: 0; left: 0; position: absolute; text-align: center;">
# <div id="snhb-left_side_top-0" style="margin-bottom:10px;"></div>
# <div id="snhb-left_side_bottom_sticky-0"></div>
# </div>
# <div id="snigel_ads_mobile" style="text-align: center;bottom: 0;left: 0;width: 100%;position: fixed;padding-bottom: 10px;z-index:255">
# <div id="snhb-bottom_mobile_leaderboard_sticky-0"></div>
# </div>
# <script type="text/javascript">
#                              var googletag = googletag || {};
#                              googletag.cmd = googletag.cmd || [];
#                              var snhb = snhb || {};
#                              snhb.queue = snhb.queue || [];
#                          </script>
# <script type="text/javascript">
#                              var brosersAndVersions = navigator.userAgent.match(/(\w+)\/([0-9.]+)/g);
#                              var browsers = {};
#                              for (var i = 0; i < brosersAndVersions.length; ++i) {
#                                  var arr = brosersAndVersions[i].split("/");
#                                  browsers[arr[0]] = parseFloat(arr[1]);
#                              }
#
#                              var offset = function(el) {
#                                  var rect = el.getBoundingClientRect(), scrollLeft = window.pageXOffset || document.documentElement.scrollLeft, scrollTop = window.pageYOffset || document.documentElement.scrollTop;
#                                  return { top: rect.top + scrollTop, left: rect.left + scrollLeft };
#                              };
#
#                              var main = window.getComputedStyle(document.getElementById('mainlayout'));
#                              var outer_div = offset(document.getElementById('outer_div'));
#                              var mainPosition = offset(document.getElementById('mainlayout'));
#                              var scrollListener = function(main, element, side) {
#                                  var stickyPos = document.getElementById(element), offsetDiv = offset(stickyPos);
#                                  stickyPos.style.width = main;
#                                  window.addEventListener('scroll', function() {
#                                      var topDistance = window.scrollY;
#                                      if ($("#body").hasClass("parallax")) { topDistance = Math.abs(offset(document.getElementById('mainlayout')).top); }
#
#                                      if (topDistance >= offsetDiv.top) {
#                                          stickyPos.style.position = 'fixed';
#                                          if ($("#body").hasClass("parallax")) {
#                                              if (browsers["Safari"] >= 601) { stickyPos.style.top = '0px';
#                                              } else { stickyPos.style.top = topDistance + 'px'; }
#                                              stickyPos.style[side] = '0px';
#                                          } else { stickyPos.style[side] = (outer_div.left + mainPosition.left) / 2 + 'px'; }
#                                      } else {
#                                          stickyPos.style.position = 'relative';
#                                          stickyPos.style.top = '0px';
#                                          stickyPos.style[side] = '0px';
#                                      }
#                                  }, true);
#                              };
#
#                              snhb.queue.push(function() {
#                                  document.getElementById('snhb-right_side_top-0').style.width = main.getPropertyValue('padding-right');
#                                  document.getElementById('snhb-left_side_top-0').style.width = main.getPropertyValue('padding-left');
#                                  googletag.cmd.push(function() {
#                                      googletag.pubads().addEventListener('slotRenderEnded', function() {
#                                          document.getElementById('snigel_ads_right').style.top = ((window.innerWidth > 767 && window.innerWidth < 896) ? 108 : 0) + 'px';
#                                          scrollListener(main.getPropertyValue('padding-left'), 'snhb-left_side_bottom_sticky-0', 'left');
#                                          scrollListener(main.getPropertyValue('padding-right'), 'snhb-right_side_bottom_sticky-0', 'right');
#                                      });
#                                  });
#                              });
#                          </script>
# <div class="mainpadding" id="maindiv">
# <link href="https://fonts.googleapis.com/css?family=Montserrat:300,400,500,600" rel="stylesheet"/>
# <nav class="lMainNavbar wide_in_main">
# <div class="lMainNavbar__left">
# <a class="lMainNavbar__deeplLogoLink" href="https://www.DeepL.com/translator">DeepL</a>
# <a class="lMainNavbar__translatorLink" href="https://www.DeepL.com/translator">Traducteur</a>
# <a class="lMainNavbar__lingueeLink is-active" href="/">Linguee</a>
# </div>
# <div class="lMainNavbar__right">
# <div class="lMainNavbar__buttonContainer">
# <div class="lMainNavbar__uiLangChooser"><button>FR</button></div>
# <div class="lMainNavbar__burgerButton"><button onclick="window.lMainNavbar.toggleBurgerMenu()">Open menu</button></div>
# </div>
# </div></nav>
# <template id="template_navPopup" style="display:none"> <div class="lNavPopup"> <div class="lNavPopup__overlay"></div> <div class="lNavPopup__window"> <button class="lNavPopup__closeButton"></button> <nav class="lNavPopup__navLinks"> <a class="lNavPopup__navLink lNavPopup__navLink--translator" href="https://www.DeepL.com/translator">Traducteur</a> <p class="lNavPopup__navLink-desc">Traduisez des textes avec la meilleure technologie de traduction automatique au monde, développée par les créateurs de Linguee.</p> <a class="lNavPopup__navLink lNavPopup__navLink--linguee" href="/">Linguee</a> <p class="lNavPopup__navLink-desc">Recherchez des traductions de mots et de phrases dans des dictionnaires bilingues, fiables et exhaustifs et parcourez des milliards de traductions en ligne.</p> <a class="lNavPopup__navLink" href="https://www.DeepL.com/blog.html">Blog</a> <a class="lNavPopup__navLink" href="https://www.DeepL.com/press.html">Informations presse</a> </nav> <div class="lNavPopup__appsSection"> <h2>Applications Linguee</h2> <a class="lNavPopup__appStoreLink appStoreLink" href="https://itunes.apple.com/de/app/id338225335?mt=8" target="_blank"><div class="AppStoreBadge appstore-logo"> </div></a> <a class="lNavPopup__appStoreLink playStoreLink" href="https://play.google.com/store/apps/details?id=com.linguee.linguee&amp;referrer=utm_source%3Dlinguee%26utm_medium%3Dunknown%26utm_campaign%3Dstart" target="_blank"><div class="PlayStoreBadge"> </div></a> </div> <script>
# 			window.$$initInstance && window.$$initInstance(function(node){
# 				function doClose(){
# 					node.parentNode.removeChild(node);
# 					node.doClose = undefined;
# 				}
# 				node.querySelector('.lNavPopup__closeButton').addEventListener('click', doClose);
# 				node.querySelector('.lNavPopup__overlay').addEventListener('click', doClose);
# 				node.doClose = doClose;
# 			});
# 			</script>
# </div>
# </div>
# </template>
# <script>
# 	window.lMainNavbar = {
# 	  toggleBurgerMenu: function(){
# 		  if (this._popupNode && this._popupNode.doClose){ this._popupNode.doClose(); this._popupNode = undefined; }
# 		  else this._popupNode = UI_Tools.createTemplateInstance('#template_navPopup', 'body');
# 		}
# 	};
# </script>
# <div class="wide_in_main l_header" id="header">
# <form accept-charset="utf-8" action="/francais-anglais/search" id="form1" method="get" name="bigform" onsubmit="return lingueeSubmitForm();">
# <div class="lQueryHeader">
# <a class="lQueryHeader__lingueeLogo" href="/">Linguee</a>
# <div class="lQueryHeader__langSelector">
# <select id="langPair" name="source">
# <option selected="selected" value="auto">[fr] français &lt;-&gt; [gb] anglais</option>
# <option value="francais">[fr] français ---&gt; [gb] anglais</option>
# <option class="dir_last" value="anglais">[gb] anglais ---&gt; [fr] français</option>
# <option value="/francais-allemand">[fr] français &lt;-&gt; [de] allemand</option>
# <option value="/francais-espagnol">[fr] français &lt;-&gt; [es] espagnol</option>
# <option value="/francais-portugais">[fr] français &lt;-&gt; [pt] portugais</option>
# <option value="/francais-italien">[fr] français &lt;-&gt; [it] italien</option>
# <option value="/francais-neerlandais">[fr] français &lt;-&gt; [nl] néerlandais</option>
# <option value="/francais-polonais">[fr] français &lt;-&gt; [pl] polonais</option>
# <option value="/francais-suedois">[fr] français &lt;-&gt; [se] suédois</option>
# <option value="/francais-danois">[fr] français &lt;-&gt; [dk] danois</option>
# <option value="/francais-finnois">[fr] français &lt;-&gt; [fi] finnois</option>
# <option value="/francais-grec">[fr] français &lt;-&gt; [gr] grec</option>
# <option value="/francais-tcheque">[fr] français &lt;-&gt; [cz] tchèque</option>
# <option value="/francais-roumain">[fr] français &lt;-&gt; [ro] roumain</option>
# <option value="/francais-hongrois">[fr] français &lt;-&gt; [hu] hongrois</option>
# <option value="/francais-slovaque">[fr] français &lt;-&gt; [sk] slovaque</option>
# <option value="/francais-bulgare">[fr] français &lt;-&gt; [bg] bulgare</option>
# <option value="/francais-slovene">[fr] français &lt;-&gt; [si] slovène</option>
# <option value="/francais-lituanien">[fr] français &lt;-&gt; [lt] lituanien</option>
# <option value="/francais-letton">[fr] français &lt;-&gt; [lv] letton</option>
# <option value="/francais-estonien">[fr] français &lt;-&gt; [ee] estonien</option>
# <option value="/francais-maltais">[fr] français &lt;-&gt; [mt] maltais</option>
# <option value="moreLanguages">Plus de langues</option>
# </select>
# </div>
# <div class="letterHelp lQueryHeader__letterHelp"><a href="javascript:addLetter('à');">à</a><a href="javascript:addLetter('â');">â</a><a href="javascript:addLetter('é');">é</a><a href="javascript:addLetter('è');">è</a><a href="javascript:addLetter('ê');">ê</a><a href="javascript:addLetter('ë');">ë</a><a href="javascript:addLetter('ï');">ï</a><a href="javascript:addLetter('î');">î</a><a href="javascript:addLetter('ô');">ô</a><a href="javascript:addLetter('ù');">ù</a><a href="javascript:addLetter('û');">û</a><a href="javascript:addLetter('ç');">ç</a><a href="javascript:addLetter('œ');">œ</a><a href="javascript:addLetter('æ');">æ</a></div>
# <script type="text/javascript">var letterHelp={gb:'àâéèêëïîôùûçœæ',de:'äöüßàâéèêëïîôùûçœæ',es:'áéíóúüñàâèêëïîôùûçœæ',pt:'áàãâéêíóõôúçèëïîùûœæ',fr:'àâéèêëïîôùûçœæ'}</script>
# <div class="lQueryHeader__input_container">
# <input autocapitalize="off" autocomplete="off" autocorrect="off" autofocus="" id="queryinput" maxlength="60" name="query" spellcheck="false" tabindex="1" type="text" value="blob"/>
# <button alt="Rechercher dans le dictionnaire français-anglais" type="submit"></button><div class="lQueryHeader__ac_container"></div></div>
# <div class="l_header__mobileLangButton" id="small_prefs"><span>FR</span><hr/><span>EN</span></div>
# </div><!--query_wrapper-->
# </form>
# </div> <!-- /header -->
# <script type="text/javascript">
# var LTexts = {button_audio: 'Écouter',button_search: 'Chercher',no_examples: 'Aucun exemple de sources externes.'}
# afterHeader()
# </script>
# <div id="lingueecontent">
# <div id="phraseeditAjaxDelay"></div>
# <div class="innercontent">
# <!-- DeepL Search Banner -->
# <div class="l_deepl_ad_container wide_in_main" style="display:none">
# <div class="l_deepl_ad__bg">
# </div>
# <div class="l_deepl_ad__content_container">
# <div class="l_deepl_ad_headercontainer">
# <div class="l_deepl_ad_header">Utilisez DeepL Traducteur pour traduire instantanément textes et documents</div>
# <div class="l_deepl_ad_header__mobile">Essayez DeepL Traducteur</div>
# </div>
# <div class="l_deepl_ad_bodycontainer">
# <div class="lmt__textarea_separator lmt__textarea_separator--left">
# <div class="lmt__textarea_separator__vertical_line"></div>
# <div class="lmt__textarea_separator__arrow"></div>
# <div class="lmt__textarea_separator__border_inner"></div>
# <div class="lmt__textarea_separator__border_outer"></div>
# <div class="lmt__textarea_separator__busy"></div>
# </div>
# <div class="l_deepl_ad__querytext lmt__textarea">blob</div>
# <div class="l_deepl_ad__copyListContainer">
# <ul>
# <li>Traduction en temps réel</li>
# <li>Meilleure qualité au monde</li>
# <li>Documents chargeables en « glisser-déposer »</li>
# </ul>
# <div class="l_deepl_ad__ctaButton" href="https://deepl.com">Essayer</div>
# </div>
# </div>
# </div>
# </div>
# <div id="dictionary">
# <h1 class="dict_headline_for_0 bothsides wide_in_main"><div class="openTriangle"> ▾</div>Dictionnaire anglais-français</h1>
# <div class="isForeignTerm" data-source-lang="EN"><div class="exact"><div class="lemma featured" wt="101"><div><h2 class="line lemma_desc" lid="EN:blob6820"><span class="tag_lemma"><a class="dictLink" href="/anglais-francais/traduction/blob.html" rel="nofollow">blob</a> <a class="audio" id="EN_US/ee/ee26908bf9629eeb4b37dac350f4754a-101" onclick='playSound(this,"EN_US/ee/ee26908bf9629eeb4b37dac350f4754a-101","anglais américain","EN_UK/ee/ee26908bf9629eeb4b37dac350f4754a-101","anglais britannique");'></a> <span class="tag_wordtype">nom</span></span><span class="dash">—</span></h2><div class="lemma_content"><div class="meaninggroup sortablemg" gid="0"><div class="translation_lines"><div class="translation sortablemg featured"><h3 class="translation_desc"><span bid="10007272810" class="tag_trans" lid="FR:goutte10913"><a class="dictLink featured" href="/francais-anglais/traduction/goutte.html" id="dictEntry10007272810">goutte</a> <span class="tag_type" title="nom, féminin">f</span> <a class="audio" id="FR/08/083afbe0160d88657a63f7fadff48541-107" onclick='playSound(this,"FR/08/083afbe0160d88657a63f7fadff48541-107","français");'></a><a class="expand_i"></a></span><!--tag_trans--></h3><!--translation_desc--><!-- editorial isFeatured 1 inType 0 allowFeatured 1 available: 1 -->
# <div class="example_lines"><div class="example line" sid="280241"><span class="tag_e"><span class="tag_s">The artist put a blob of paint on the canvas.</span> <span class="dash">—</span> <span class="tag_t">L'artiste a mis une goutte de peinture sur la toile. </span><span class="tag_e_end"></span></span></div></div></div>
# <div class="translation sortablemg featured"><h3 class="translation_desc"><span bid="10007272669" class="tag_trans" lid="FR:forme#floue33699"><a class="dictLink featured" href="/francais-anglais/traduction/forme+floue.html" id="dictEntry10007272669">forme floue</a> <span class="tag_type" title="nom, féminin">f</span></span><!--tag_trans--></h3><!--translation_desc--><!-- editorial isFeatured 1 inType 0 allowFeatured 1 available: 1 -->
# <div class="example_lines"><div class="example line" sid="279882"><span class="tag_e"><span class="tag_s">Without my glasses, people are just blobs.</span> <span class="dash">—</span> <span class="tag_t">Sans mes lunettes, les gens ne sont que des formes floues.</span><span class="tag_e_end"></span></span></div></div></div>
# </div><!--translation_lines-->
# </div><!--meaninggroup-->
# </div><!--lemma_content--></div></div><!--lemma-->
# </div><!--exact--><div class="copyrightLineOuter"><div class="copyrightLine">© Dictionnaire Linguee, 2020</div></div>
# </div></div><!--dictionary-->
# <div class="webservice" id="result_container"><h1 class="folding wide_in_main"><div class="openTriangle">▾</div>Sources externes (non révisées)
# </h1>
# <div>
# <table cellspacing="0" class="result_table" id="result_table">
# <tbody class="examples">
# <tr class="row_first" id="row_0_4736769280_0">
# <td class="sentence left"><div class="wrap">
# A<b class="b4"> </b><b class="b5">blob</b><b class="b4"> </b><b class="b3">o</b><b class="b2">f</b><b class="b1"> p</b>aint is placed in the centre of the base plate close to the black <span class="placeholder_end2"> [...]</span>
# <div class="shortened_end2">/ white division.</div>
# <div class="source_url_spacer">labomat.eu</div>
# <div class="source_url"><a href="http://www.labomat.eu/document/docGB/02DA_Pfund_B.pdf" rel="noopener noreferrer" target="_blank">labomat.eu</a></div><div class="behindLinkDiv"></div>
# </div></td>
# <td class="sentence right2"><div class="wrap">
# On place <b class="b1">un</b><b class="b2">e goutte d</b><b class="b1">e </b>peinture au centre de la plaque de basen près de la séparation <span class="placeholder_end2"> [...]</span>
# <div class="shortened_end2">noir/blanc.</div>
# <div class="source_url_spacer">labomat.eu</div>
# <div class="source_url"><a href="http://www.labomat.eu/document/docFR/02DF_Pfund_B.pdf" rel="noopener noreferrer" target="_blank">labomat.eu</a></div><div class="behindLinkDiv"></div>
# </div></td>
# </tr>
# <tr class="" id="row_0_8847093024_0">
# <td class="sentence left"><div class="wrap">
# One can also store the XML source file as any o<b class="b1">th</b><b class="b2">e</b><b class="b3">r</b><b class="b4"> </b><b class="b5">BLOB</b><b class="b4"> </b><b class="b3">d</b><b class="b2">a</b><b class="b1">ta</b>, within the DBMS or in a flat file. <div class="source_url_spacer">paradox.riff.org</div>
# <div class="source_url"><a href="http://paradox.riff.org/en/310_Stockage_XML.php" rel="noopener noreferrer" target="_blank">paradox.riff.org</a></div><div class="behindLinkDiv"></div>
# </div></td>
# <td class="sentence right2"><div class="wrap">
# Il est aussi possible de conserver le document XML comme un champ BLOB, ou comme un fichier. <div class="source_url_spacer">paradox.riff.org</div>
# <div class="source_url"><a href="http://paradox.riff.org/fr/310_Stockage_XML.php" rel="noopener noreferrer" target="_blank">paradox.riff.org</a></div><div class="behindLinkDiv"></div>
# </div></td>
# </tr>
# <tr class="" id="row_0_6225848354_0">
# <td class="sentence left"><div class="wrap">
# At any rate, even though it looks innocent, I suppose like a li<b class="b1">tt</b><b class="b2">l</b><b class="b3">e</b><b class="b4"> </b><b class="b5">blob</b><b class="b4">,</b><b class="b3"> </b><b class="b2">t</b><b class="b1">hi</b>s is a human being after 30 days. <div class="source_url_spacer">www2.parl.gc.ca</div>
# <div class="source_url"><a href="http://www2.parl.gc.ca/HousePublications/Publication.aspx?DocId=1040902&amp;Language=E&amp;Mode=1&amp;Parl=37&amp;Ses=1" rel="noopener noreferrer" target="_blank">www2.parl.gc.ca</a></div><div class="behindLinkDiv"></div>
# </div></td>
# <td class="sentence right2"><div class="wrap">
# De toute façon, même si cela peut sembler très innocent, probablement comme une petite tache, c'est un être humain après 30 jours. <div class="source_url_spacer">www2.parl.gc.ca</div>
# <div class="source_url"><a href="http://www2.parl.gc.ca/HousePublications/Publication.aspx?DocId=1040902&amp;Language=F&amp;Mode=1&amp;Parl=37&amp;Ses=1" rel="noopener noreferrer" target="_blank">www2.parl.gc.ca</a></div><div class="behindLinkDiv"></div>
# </div></td>
# </tr>
# <tr class="" id="row_0_9665156324_0">
# <td class="sentence left"><div class="wrap">
# But the goal of this project is not to eliminate Catholic media by merging them into a form<b class="b1">le</b><b class="b2">s</b><b class="b3">s</b><b class="b4"> </b><b class="b5">blob</b>. <div class="source_url_spacer">inquisition.ca</div>
# <div class="source_url"><a href="http://inquisition.ca/en/serm/corps_mediatique.htm" rel="noopener noreferrer" target="_blank">inquisition.ca</a></div><div class="behindLinkDiv"></div>
# </div></td>
# <td class="sentence right2"><div class="wrap">
# Mais ce projet ne vise pas du tout à éliminer les médias catholiques en les fusionnant dans un magma informe. <div class="source_url_spacer">inquisition.ca</div>
# <div class="source_url"><a href="http://inquisition.ca/fr/serm/corps_mediatique.htm" rel="noopener noreferrer" target="_blank">inquisition.ca</a></div><div class="behindLinkDiv"></div>
# </div></td>
# </tr>
# <tr class="" id="row_0_1532226701_0">
# <td class="sentence left"><div class="wrap">
# The retu<b class="b1">rn</b><b class="b2">e</b><b class="b3">d</b><b class="b4"> </b><b class="b5">blob</b><b class="b4"> </b><b class="b3">i</b><b class="b2">s</b><b class="b1"> c</b>oncatenated <span class="placeholder_end2"> [...]</span>
# <div class="shortened_end2">with the host-supplied nonce, then further encrypted with the host-supplied RSA key, and </div>
# <span class="placeholder_end"> [...]</span>
# <div class="shortened_end">finally sent to the host over HTTPS.</div>
# <div class="source_url_spacer">secure.logmein.com</div>
# <div class="source_url"><a href="https://secure.logmein.com/UK/products/central/security.aspx" rel="noopener noreferrer" target="_blank">secure.logmein.com</a></div><div class="behindLinkDiv"></div>
# </div></td>
# <td class="sentence right2"><div class="wrap">
# Le <b class="b1">bl</b><b class="b2">ob renvoyé es</b><b class="b1">t </b>concaténé à <span class="placeholder_end2"> [...]</span>
# <div class="shortened_end2">la valeur de circonstance fournie par l'hôte, chiffré à nouveau avec la clé RSA fournie </div>
# <span class="placeholder_end"> [...]</span>
# <div class="shortened_end">par l'hôte, puis envoyé à l'hôte par HTTPS.</div>
# <div class="source_url_spacer">secure.logmein.com</div>
# <div class="source_url"><a href="https://secure.logmein.com/fr/products/central/security.aspx" rel="noopener noreferrer" target="_blank">secure.logmein.com</a></div><div class="behindLinkDiv"></div>
# </div></td>
# </tr>
# <tr class="" id="row_0_1114686900_0">
# <td class="sentence left"><div class="wrap">
# <div class="shortened_begin2">Turner went on to explain that the plaintiffs were seeking protection for the belief that "God created</div>
# <span class="placeholder_begin2">[...] </span>
#  man as man, not <b class="b1">as</b><b class="b2"> </b><b class="b3">a</b><b class="b4"> </b><b class="b5">blob</b><b class="b4">"</b>. <div class="source_url_spacer">creationwiki.org</div>
# <div class="source_url"><a href="http://creationwiki.org/History_of_creationism" rel="noopener noreferrer" target="_blank">creationwiki.org</a></div><div class="behindLinkDiv"></div>
# </div></td>
# <td class="sentence right2"><div class="wrap">
# <div class="shortened_begin2">Turner a tenu à expliquer que les poursuivants cherchaient la protection pour la croyance que « Dieu a créé l'homme comme</div>
# <span class="placeholder_begin2">[...] </span>
#  l'homme,<b class="b1"> p</b><b class="b2">as co</b><b class="b3">mme</b><b class="b4"> un </b><b class="b3">pât</b><b class="b2">é"</b>. <div class="source_url_spacer">creationwiki.org</div>
# <div class="source_url"><a href="http://creationwiki.org/fr/Histoire_de_cr%C3%A9ationnisme" rel="noopener noreferrer" target="_blank">creationwiki.org</a></div><div class="behindLinkDiv"></div>
# </div></td>
# </tr>
# <tr class="" id="row_0_7939726786_0">
# <td class="sentence left"><div class="wrap">
# Most often, it is about repairing slits and tears, stains<b class="b1"> a</b><b class="b2">n</b><b class="b3">d</b><b class="b4"> </b><b class="b5">blob</b><b class="b4"> </b><b class="b3">a</b><b class="b2">n</b><b class="b1">d </b>stripes. <div class="source_url_spacer">myphotorescue.com</div>
# <div class="source_url"><a href="http://www.myphotorescue.com/" rel="noopener noreferrer" target="_blank">myphotorescue.com</a></div><div class="behindLinkDiv"></div>
# </div></td>
# <td class="sentence right2"><div class="wrap">
# Le plus souvent il s'agit de réparer des déchirures, des taches e<b class="b1">t </b><b class="b2">des</b><b class="b1"> r</b>ayures. <div class="source_url_spacer">myphotorescue.com</div>
# <div class="source_url"><a href="http://www.myphotorescue.com/lang-fr/" rel="noopener noreferrer" target="_blank">myphotorescue.com</a></div><div class="behindLinkDiv"></div>
# </div></td>
# </tr>
# <tr class="" id="row_0_8675002796_0">
# <td class="sentence left"><div class="wrap">
# If you double-click <b class="b1">on</b><b class="b2"> </b><b class="b3">a</b><b class="b4"> </b><b class="b5">blob</b><b class="b4">,</b><b class="b3"> </b><b class="b2">i</b><b class="b1">t </b>will move to the note nearest to it in the chromatic scale. <div class="source_url_spacer">assets.celemony.com</div>
# <div class="source_url"><a href="http://assets.celemony.com/manuals/pdf/MelodyneEditor/Manual_Melodyne_editor_1.2_English.pdf" rel="noopener noreferrer" target="_blank">assets.celemony.com</a></div><div class="behindLinkDiv"></div>
# </div></td>
# <td class="sentence right2"><div class="wrap">
# Si vous double-cliquez s<b class="b1">ur</b><b class="b2"> une </b><b class="b1">go</b>utte, elle se cale sur la note la plus proche dans la gamme chromatique. <div class="source_url_spacer">assets.celemony.com</div>
# <div class="source_url"><a href="http://assets.celemony.com/manuals/pdf/MelodyneEditor/Manual_Melodyne_editor_1.2_French.pdf" rel="noopener noreferrer" target="_blank">assets.celemony.com</a></div><div class="behindLinkDiv"></div>
# </div></td>
# </tr>
# <tr class="" id="row_0_9672944580_0">
# <td class="sentence left"><div class="wrap">
# It makes creating and editing MySQL database objects easy and fast, and allows you to run SQL scripts, manage users and their privileges, build SQL queries visually, extract, print and search metadata, export data to 17 available file formats and import them, view and <b class="b1">ed</b><b class="b2">i</b><b class="b3">t</b><b class="b4"> </b><b class="b5">BLOB</b><b class="b4"> </b><b class="b3">f</b><b class="b2">i</b><b class="b1">el</b>ds, and much more. <div class="source_url_spacer">download2.sqlmanager.net</div>
# <div class="source_url"><a href="http://download2.sqlmanager.net/download/datasheets/mysql/manager/en/mymanager.pdf" rel="noopener noreferrer" target="_blank">download2.sqlmanager.net</a></div><div class="behindLinkDiv"></div>
# </div></td>
# <td class="sentence right2"><div class="wrap">
# Le programme permet de créer et de modifier rapidement des objets de bases de données MySQL, d'exécuter les scripts SQL, de gérer les utilisateurs et leurs privilèges, de construire visuellement les requêtes SQL, d'extraire, d'imprimer et de rechercher les métadonnées, d'exporter et d'importer les données vers les dix-sept formats les plus populaires, d'afficher et de modifi<b class="b1">er</b><b class="b2"> les </b><b class="b1">ch</b>amps BLOB etc. <div class="source_url_spacer">download2.sqlmanager.net</div>
# <div class="source_url"><a href="http://download2.sqlmanager.net/download/datasheets/mysql/manager/fr/mymanager.pdf" rel="noopener noreferrer" target="_blank">download2.sqlmanager.net</a></div><div class="behindLinkDiv"></div>
# </div></td>
# </tr>
# <tr class="" id="row_0_9130141051_0">
# <td class="sentence left"><div class="wrap">
# The resulting RSA-encry<b class="b1">pt</b><b class="b2">e</b><b class="b3">d</b><b class="b4"> </b><b class="b5">blob</b><b class="b4"> </b><b class="b3">i</b><b class="b2">s</b><b class="b1"> p</b>assed to a LogMeIn webservice over HTTPS, where <span class="placeholder_end2"> [...]</span>
# <div class="shortened_end2">it is further encrypted (using AES-256-CBC) </div>
# <span class="placeholder_end"> [...]</span>
# <div class="shortened_end">with a secret unique to your LogMeIn account.</div>
# <div class="source_url_spacer">secure.logmein.com</div>
# <div class="source_url"><a href="https://secure.logmein.com/UK/products/central/security.aspx" rel="noopener noreferrer" target="_blank">secure.logmein.com</a></div><div class="behindLinkDiv"></div>
# </div></td>
# <td class="sentence right2"><div class="wrap">
# Le blob chiffré <b class="b1">pa</b><b class="b2">r RSA e</b><b class="b1">st</b> ensuite transmis au service Web LogMeIn par HTTPS, où il est à nouveau <span class="placeholder_end2"> [...]</span>
# <div class="shortened_end2">chiffré (par AES-256-CBC) </div>
# <span class="placeholder_end"> [...]</span>
# <div class="shortened_end">avec une clé secrète unique associée à votre compte LogMeIn.</div>
# <div class="source_url_spacer">secure.logmein.com</div>
# <div class="source_url"><a href="https://secure.logmein.com/fr/products/central/security.aspx" rel="noopener noreferrer" target="_blank">secure.logmein.com</a></div><div class="behindLinkDiv"></div>
# </div></td>
# </tr>
# <tr class="" id="row_0_6359877354_0">
# <td class="sentence left"><div class="wrap">
# Yes, tattooing is expensive but you are better off saving your money and getting a beautifully done tattoo than spending little money and be stuck with a flower tattoo that looks li<b class="b1">ke</b><b class="b2"> </b><b class="b3">a</b><b class="b4"> </b><b class="b5">blob</b>. <div class="source_url_spacer">eohu.ca</div>
# <div class="source_url"><a href="http://eohu.ca/_files/resources/resource57.pdf" rel="noopener noreferrer" target="_blank">eohu.ca</a></div><div class="behindLinkDiv"></div>
# </div></td>
# <td class="sentence right2"><div class="wrap">
# Un tatouage c'est cher, mais il vaut mieux économiser ton argent et te faire faire un beau tatouage que de dépenser juste un peu d'argent et de te retrouver avec un tatouage d'une fleur qui ressemble à une tache. <div class="source_url_spacer">eohu.ca</div>
# <div class="source_url"><a href="http://eohu.ca/_files/resources/resource311.pdf" rel="noopener noreferrer" target="_blank">eohu.ca</a></div><div class="behindLinkDiv"></div>
# </div></td>
# </tr>
# <tr class="" id="row_0_3914281362_0">
# <td class="sentence left"><div class="wrap">
# Use a marshmallo<b class="b1">w </b><b class="b2">o</b><b class="b3">r</b><b class="b4"> </b><b class="b5">blob</b><b class="b4"> </b><b class="b3">o</b><b class="b2">f</b><b class="b1"> c</b>lay to attach <span class="placeholder_end2"> [...]</span>
# <div class="shortened_end2">three straws together.</div>
# <div class="source_url_spacer">asc-csa.gc.ca</div>
# ...
# </div></td>
# </tr>
# <tr class="" id="row_0_84027564_0">
# <td class="sentence left"><div class="wrap">
# <div class="shortened_begin2">Indeed, even with no explosive charge at</div>
# <span class="placeholder_begin2">[...] </span>
#  all, or wi<b class="b1">th</b><b class="b2"> </b><b class="b3">a</b><b class="b4"> </b><b class="b5">blob</b><b class="b4"> </b><b class="b3">o</b><b class="b2">f</b><b class="b1"> c</b>oncrete inside <span class="placeholder_end2"> [...]</span>
# <div class="shortened_end2">its warhead, no one would like to see a </div>
# <span class="placeholder_end"> [...]</span>
# <div class="shortened_end">ballistic missile hurtling down at 7km per second toward their apartment block, as residents of a few cities in the Middle East are all too well aware.</div>
# <div class="source_url_spacer">unidir.org</div>
# <div class="source_url"><a href="http://unidir.org/pdf/articles/pdf-art2430.pdf" rel="noopener noreferrer" target="_blank">unidir.org</a></div><div class="behindLinkDiv"></div>
# </div></td>
# <td class="sentence right2"><div class="wrap">
# <div class="shortened_begin2">Un missile</div>
# <span class="placeholder_begin2">[...] </span>
#  balistique<b class="b1">, </b><b class="b2">même</b><b class="b3"> dépourvu </b><b class="b2">de t</b><b class="b1">ou</b>te charge <span class="placeholder_end2"> [...]</span>
# <div class="shortened_end2">explosive, reste redoutable lorsqu'il fond à 7km à la seconde sur une </div>
# <span class="placeholder_end"> [...]</span>
# <div class="shortened_end">zone urbaine, comme les habitants de plusieurs villes du Moyen-Orient en ont fait l'expérience.</div>
# <div class="source_url_spacer">unidir.org</div>
# <div class="source_url"><a href="http://unidir.org/pdf/articles/pdf-art2443.pdf" rel="noopener noreferrer" target="_blank">unidir.org</a></div><div class="behindLinkDiv"></div>
# </div></td>
# </tr>
# <tr class="" id="row_0_3270050967_0">
# <td class="sentence left"><div class="wrap">
# hash the document or subtree stored <b class="b1">as</b><b class="b2"> </b><b class="b3">a</b><b class="b4"> </b><b class="b5">BLOB</b><b class="b4">,</b><b class="b3"> </b><b class="b2">t</b><b class="b1">o </b>a separate column, at the storage stage, then when querying compare hash results, referably indexed, then double check the absence of collisions by comparing the data being searched with just the data returned <span class="placeholder_end2"> [...]</span>
# <div class="shortened_end2">by this first test</div>
# <div class="source_url_spacer">paradox.riff.org</div>
# <div class="source_url"><a href="http://paradox.riff.org/en/322_Restituer_XML_2.php" rel="noopener noreferrer" target="_blank">paradox.riff.org</a></div><div class="behindLinkDiv"></div>
# </div></td>
# <td class="sentence right2"><div class="wrap">
# hâcher le document ou sous-arbre stocké en natif, dans une colonne lors du stockage, et comparer le résultat du hâchage, de préférence indexé, puis vérifier l'absence de collision en comparant les enregistrements à hash correspondant avec la donnée recherchée <div class="source_url_spacer">paradox.riff.org</div>
# <div class="source_url"><a href="http://paradox.riff.org/fr/322_Restituer_XML_2.php" rel="noopener noreferrer" target="_blank">paradox.riff.org</a></div><div class="behindLinkDiv"></div>
# </div></td>
# </tr>
# <tr class="" id="row_0_6354748020_0">
# <td class="sentence left"><div class="wrap">
# A<b class="b4"> </b><b class="b5">blob</b><b class="b4"> </b><b class="b3">o</b><b class="b2">f</b><b class="b1"> s</b>older from the J5 brass <span class="placeholder_end2"> [...]</span>
# <div class="shortened_end2">connector was found in a thermal cavity in the glass surface beneath the J5 terminal </div>
# <span class="placeholder_end"> [...]</span>
# <div class="shortened_end">block area with two parallel cracks, each about 35 inches across the length of the windshield, emanating from the cavity.</div>
# <div class="source_url_spacer">tsb-bst.gc.ca</div>
# <div class="source_url"><a href="http://www.tsb-bst.gc.ca/eng/rapports-reports/aviation/2002/a02c0227/a02c0227.asp" rel="noopener noreferrer" target="_blank">tsb-bst.gc.ca</a></div><div class="behindLinkDiv"></div>
# </div></td>
# <td class="sentence right2"><div class="wrap">
# U<b class="b3">n</b><b class="b4">e goutte d</b><b class="b3">e s</b><b class="b2">oudur</b><b class="b1">e </b>en provenance <span class="placeholder_end2"> [...]</span>
# <div class="shortened_end2">du connecteur en laiton J5 a été trouvée dans une cavité thermique à la surface du verre, </div>
# <span class="placeholder_end"> [...]</span>
# <div class="shortened_end">sous le bornier J5 ainsi que deux criques parallèles d'environ 35 pouces dans le sens de la longueur du pare-brise, à partir de la cavité.</div>
# <div class="source_url_spacer">tsb-bst.gc.ca</div>
# <div class="source_url"><a href="http://www.tsb-bst.gc.ca/fra/rapports-reports/aviation/2002/a02c0227/a02c0227.asp" rel="noopener noreferrer" target="_blank">tsb-bst.gc.ca</a></div><div class="behindLinkDiv"></div>
# </div></td>
# </tr>
# <tr class="" id="row_0_2816276160_0">
# <td class="sentence left"><div class="wrap">
# You can now move<b class="b1"> t</b><b class="b2">h</b><b class="b3">e</b><b class="b4"> </b><b class="b5">blob</b><b class="b4">(</b><b class="b3">s</b><b class="b2">)</b><b class="b1"> w</b>ithout dragging the adja<b class="b1">ce</b><b class="b2">n</b><b class="b3">t</b><b class="b4"> </b><b class="b5">blobs</b><b class="b4"> </b><b class="b3">a</b><b class="b2">t</b><b class="b1"> t</b>he same time. <div class="source_url_spacer">assets.celemony.com</div>
# <div class="source_url"><a href="http://assets.celemony.com/manuals/pdf/MelodyneStudio/Manual.MelodyneStudio.3.2.English.pdf" rel="noopener noreferrer" target="_blank">assets.celemony.com</a></div><div class="behindLinkDiv"></div>
# </div></td>
# <td class="sentence right2"><div class="wrap">
# Vous pouvez à présent dé<b class="b1">pl</b><b class="b2">acer </b><b class="b3">la </b><b class="b4">sélection</b><b class="b3"> sa</b><b class="b2">ns af</b><b class="b1">fe</b>cter le<b class="b1">s </b><b class="b2">blob</b><b class="b1">(s</b>) adjacents. <div class="source_url_spacer">assets.celemony.com</div>
# <div class="source_url"><a href="http://assets.celemony.com/manuals/pdf/Manual.MelodyneCre8Studio.3.2.French.pdf" rel="noopener noreferrer" target="_blank">assets.celemony.com</a></div><div class="behindLinkDiv"></div>
# </div></td>
# </tr>
# <tr class="" id="row_0_8255508504_0">
# <td class="sentence left warn"><div class="wrap">
# <span class="warnSign tooltip_help" title="Il se peut que cette traduction soit inexacte."></span><span class="warnSign2 tooltip_help" title="Il se peut que cette traduction soit inexacte."></span><b class="b5">Blob</b><b class="b4"> </b><b class="b3">l</b><b class="b2">o</b><b class="b1">ca</b>tor tool supports the detection of part with irregularity, shape which could not be detected by a trained image (such as cookies, food, etc )etc) <div class="source_url_spacer">fanucrobotics.lu</div>
# <div class="source_url"><a href="http://www.fanucrobotics.lu/~/media/Global/Files/Downloads/Datasheets/EN/iRVision_EN.ashx" rel="noopener noreferrer" target="_blank">fanucrobotics.lu</a></div><div class="behindLinkDiv"></div>
# </div></td>
# <td class="sentence right2 warn"><div class="wrap">
# <span class="warnSign tooltip_help" title="Il se peut que cette traduction soit inexacte."></span><span class="warnSign2 tooltip_help" title="Il se peut que cette traduction soit inexacte."></span>L'outil Blob Locator permet la détection d'une pièce avec des irrégularités, qui n'auraient pas pu être détectées avec une image préenregistrée (ex. biscuits, nourriture, etc.) <div class="source_url_spacer">fanucrobotics.lu</div>
# <div class="source_url"><a href="http://www.fanucrobotics.lu/~/media/Global/Files/Downloads/Datasheets/FR/iRVision_FR.ashx" rel="noopener noreferrer" target="_blank">fanucrobotics.lu</a></div><div class="behindLinkDiv"></div>
# </div></td>
# </tr>
# <tr class="" id="row_0_8884649618_0">
# <td class="sentence left warn"><div class="wrap">
# <span class="warnSign tooltip_help" title="Il se peut que cette traduction soit inexacte."></span><div class="shortened_begin2">Web link to the full text of the aid measure:</div>
# <span class="warnSign2 tooltip_help" title="Il se peut que cette traduction soit inexacte."></span><span class="placeholder_begin2">[...] </span>
#  http://cdl.niedersachse<b class="b1">n.</b><b class="b2">d</b><b class="b3">e</b><b class="b4">/</b><b class="b5">blob</b><b class="b4">/</b><b class="b3">i</b><b class="b2">m</b><b class="b1">ag</b>       es/C44357889_L20.pdf <div class="source_url_spacer">eur-lex.europa.eu</div>
# <div class="source_url"><a href="http://eur-lex.europa.eu/LexUriServ/LexUriServ.do?uri=OJ:C:2009:292:0017:0022:EN:PDF" rel="noopener noreferrer" target="_blank">eur-lex.europa.eu</a></div><div class="behindLinkDiv"></div>
# </div></td>
# <td class="sentence right2 warn"><div class="wrap">
# <span class="warnSign tooltip_help" title="Il se peut que cette traduction soit inexacte."></span><div class="shortened_begin2">Lien internet vers le texte intégral de la mesure d'aide:</div>
# <span class="warnSign2 tooltip_help" title="Il se peut que cette traduction soit inexacte."></span><span class="placeholder_begin2">[...] </span>
#  http://cdl.nieders<b class="b1">ac</b><b class="b2">hsen</b><b class="b3">.de/</b><b class="b4">blob</b><b class="b3">/ima</b><b class="b2">ges/</b><b class="b1">C4</b>       4357889_L20.pdf <div class="source_url_spacer">eur-lex.europa.eu</div>
# <div class="source_url"><a href="http://eur-lex.europa.eu/LexUriServ/LexUriServ.do?uri=OJ:C:2009:292:0017:0022:FR:PDF" rel="noopener noreferrer" target="_blank">eur-lex.europa.eu</a></div><div class="behindLinkDiv"></div>
# </div></td>
# </tr>
# </tbody>
# </table> <!-- /result_table -->
# </div> <!-- /result_div -->
# </div>
# <!-- /result_container -->
# </div><!--innercontent-->
# </div><!--lingueecontent-->
# <div class="footer" id="footer">
# <div id="attribution">
# </div>
# <div id="currently_searched">Requêtes en cours :
# <a href="/francais-anglais/traduction/g%C3%AEte.html">gîte</a>, <a href="/anglais-francais/traduction/media+outlet.html">media outlet</a>, <a href="/francais-anglais/traduction/adaptation.html">adaptation</a>, <a href="/anglais-francais/traduction/epitome.html">epitome</a>, <a href="/francais-anglais/traduction/je+viens+d%27apprendre.html">je viens d'apprendre</a>, <a href="/anglais-francais/traduction/borne.html">borne</a>, <a href="/francais-anglais/traduction/vivement.html">vivement</a>, <a href="/anglais-francais/traduction/easy+access.html">easy access</a>, <a href="/francais-anglais/traduction/boxeur.html">boxeur</a>, <a href="/anglais-francais/traduction/wound+healing.html">wound healing</a>, <a href="/francais-anglais/traduction/sup%C3%A9rette.html">supérette</a>, <a href="/anglais-francais/traduction/lenient.html">lenient</a>, <a href="/francais-anglais/traduction/violon.html">violon</a>, <a href="/anglais-francais/traduction/no+point.html">no point</a>, <a href="/francais-anglais/traduction/de+ton+c%C3%B4t%C3%A9.html">de ton côté</a></div>
# <div id="important_terms">Requête la plus fréquente dans le dictionnaire français :
#  <a href="/french-english/topfrench/1-200.html">1-200</a>, <a href="/french-english/topfrench/201-1000.html">-1k</a>, <a href="/french-english/topfrench/1001-2000.html">-2k</a>, <a href="/french-english/topfrench/2001-3000.html">-3k</a>, <a href="/french-english/topfrench/3001-4000.html">-4k</a>, <a href="/french-english/topfrench/4001-5000.html">-5k</a>, <a href="/french-english/topfrench/5001-7000.html">-7k</a>, <a href="/french-english/topfrench/7001-10000.html">-10k</a>
# , <a href="/french-english/topfrench/10001-20000.html">-20k</a>, <a href="/french-english/topfrench/20001-40000.html">-40k</a>, <a href="/french-english/topfrench/40001-100000.html">-100k</a>, <a href="/french-english/topfrench/100001-200000.html">-200k</a>, <a href="/french-english/topfrench/200001-500000.html">-500k</a>, <a href="/french-english/topfrench/500001-2200000.html">-1000k</a><br/>
# Requête la plus fréquente dans le dictionnaire anglais :
#  <a href="/english-french/topenglish/1-200.html">1-200</a>, <a href="/english-french/topenglish/201-1000.html">-1k</a>, <a href="/english-french/topenglish/1001-2000.html">-2k</a>, <a href="/english-french/topenglish/2001-3000.html">-3k</a>, <a href="/english-french/topenglish/3001-4000.html">-4k</a>, <a href="/english-french/topenglish/4001-5000.html">-5k</a>, <a href="/english-french/topenglish/5001-7000.html">-7k</a>, <a href="/english-french/topenglish/7001-10000.html">-10k</a>
# , <a href="/english-french/topenglish/10001-20000.html">-20k</a>, <a href="/english-french/topenglish/20001-40000.html">-40k</a>, <a href="/english-french/topenglish/40001-100000.html">-100k</a>, <a href="/english-french/topenglish/100001-200000.html">-200k</a>, <a href="/english-french/topenglish/200001-500000.html">-500k</a>, <a href="/english-french/topenglish/500001-2200000.html">-1000k</a><br/>
# </div>
# <div class="footer__inner"><nav class="footer__nav" id="footerNav"><a href="https://www.linguee.com/english-french/translation/blob.html" onclick="differentDomain(this)"><span>Linguee</span> in English</a>
# <a href="/francais-anglais/page/login.php" rel="nofollow">Connexion</a>
# <a href="/francais-anglais/page/imprint.php" rel="nofollow">Mentions légales</a>
# <a href="/francais-anglais/page/termsAndConditions.php" rel="nofollow">CGU</a>
# <a href="/francais-anglais/page/privacy.php" rel="nofollow">Déclaration de confidentialité</a></nav><div class="footer__socials"><a class="footer__social footer__social--twitter" href="https://twitter.com/DeepLcom" rel="noopener" target="_blank" title="Twitter"></a><a class="footer__social footer__social--facebook" href="https://www.facebook.com/DeepLcom/" rel="noopener" target="_blank"></a><a class="footer__social footer__social--linkedin" href="https://www.linkedin.com/company/linkedin-com-company-deepl/" rel="noopener" target="_blank"></a></div></div></div> <!-- /footer -->
# </div><!--maindiv--></div><!--mainlayout-->
# <div class="dialog" id="voteDownReasonDiv">
# <a class="button_close" onclick="forgetVoteDown()"></a>
# <b>Veuillez choisir une raison pour justifier votre évaluation de la traduction :</b>
# <ul><li id="vdBadExample"><a onclick="vdBadExample()">Cet exemple ne correspond à la traduction ci-dessus.</a></li>
# <li id="vdWrongBoldWords"><a onclick="vdWrongBoldWords()">Les mots surlignés ne correspondent pas.</a></li>
# <li id="vdDoesNotFitForQuery"><a onclick="vdDoesNotFitForQuery()">Ce résultat ne correspond pas à ma recherche.</a></li>
# <li id="vdShouldNotBeCombined"><a onclick="vdShouldNotBeCombined()">Cet exemple ne correspond pas à l'entrée en orange.</a></li>
# <li id="vdBadTranslation"><a onclick="vdBadTranslation()">La traduction est fausse ou de mauvaise qualité.</a></li>
# </ul>
# </div>
# <div class="dialog" id="voteThankYouDiv">
# <a class="button_close" onclick='jQuery("#voteThankYouDiv").fadeOut("fast")'></a>
# Merci d'avoir donné votre avis sur cette traduction !<br/> Vous contribuez ainsi à l'amélioration de notre service.
# </div>
# <link href="https://d1wigddrwdtsce.cloudfront.net/5_db16f23c/css3/style4-late.min.css.g" rel="stylesheet" type="text/css"/><script src="https://d1wigddrwdtsce.cloudfront.net/5_db16f23c/javascript/linguee4-all-late.min.js.g" type="text/javascript"></script>
# <script type="text/javascript">callDocumentReady();</script>
# <script type="text/javascript">
#   abpFormat='rectangle';
#   //if (document.documentElement.clientWidth*document.documentElement.clientHeight*0.15>=600*300) {
#   //  abpFormat='halfpage';
#   //}
# </script>
# <script type="text/javascript">
# if (isIE || isEdge || isIENewer) { window.performance=null; }
# </script>
# <script type="text/javascript">
# </script>
# </div></div></div>
# <script type="text/javascript">l_page_wrapper_close();</script>
# <div id="flashMp3Div"></div>
# <img border="0" height="1" src="/francais-anglais/white_pixel.gif?number=897991844" width="1"/>
# </body></html>
# <!-- 2021-Jan-11 10:19:07 -->

# %%
def get_content(url):
    
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
    list_balises = ['h1', 'h2', 'h3', 'h4', 'h5', 'h6', 'b', 'strong', 'i', 'em', 'pre', 'mark', 'small', 'del', 's', 'ins', 'u', 'sub', 'sup', 'dfn', 'p']
    if soup.find('article') is not None:
        if 'p' in [tag.name for tag in soup.find('article').contents]:
            content_html = soup.find('article')
            content = '\n'.join(tag.text for tag in content_html.contents if tag.name in list_balises).replace('\xa0', '')
        else:
            list_div = list()
            for el in soup.find_all('div'):
                if el.find('p') and not el.find('div'):
                    list_div.append(el)
            index_max = np.argmax([len(block.find_all('p')) for block in list_div])
            content_html = list_div[index_max]
            content = '\n'.join(tag.text for tag in content_html.contents if tag.name in list_balises).replace('\xa0', '')
    else:
        list_div = list()
        for el in soup.find_all('div'):
            if el.find('p') and not el.find('div'):
                list_div.append(el)
        index_max = np.argmax([len(block.find_all('p')) for block in list_div])
        content_html = list_div[index_max]
        content = '\n'.join(tag.text for tag in content_html.contents if tag.name in list_balises).replace('\xa0', '')
    return content_html, content

# %%
def getDate(soup):
    
    """ 
        Extracting the date of publishing / updating of the article
    """
        
    if soup.find('meta', property='article:modified_time'):
        date = soup.find('meta', property='article:modified_time').get('content')
        art_published_datetime = datetime.datetime.strptime(date, '%Y-%m-%dT%H:%M:%S%z').date()
        
    elif soup.find('meta', property='article:published_time'):
        date = soup.fond('meta', property='article:published_time').get('content')
        art_published_datetime = datetime.datetime.strptime(date, '%Y-%m-%dT%H:%M:%S%z').date()
        
    elif soup.find('time', class_='datetime'):
        date = soup.find('time', class_='datetime').text
        art_published_datetime = datetime.datetime.strptime(date, '%Y-%m-%dT%H:%M:%S%z').date()

    else :
        art_published_datetime = datetime.date.today()
        
    return art_published_datetime

# %%
def getLang(soup, content):
    
    """ 
        Retrieval of the article language
    """
    
    blob = TextBlob(str(content)) #Art content without html
    
    return blob.detect_language()

# %%
getLang(soup, content)
# Out:
# 'fr'

# %%
def getTitle(soup):
    
    """ 
        Retrieval of the article title
    """
    
    if soup.find('meta', property = "og:title"):
        art_title = soup.find('meta', property = "og:title").get('content')
        
    elif soup.find('title'):
        art_title = soup.find('title').get_text()
        
    else :
        art_title = "no_data"

    return art_title

# %%
def getUrl(soup, url):
    
    """ 
        Retrieval of the article url
    """
    
    if soup.find('meta', property = "og:url"):
        art_url = soup.find('meta', property = "og:url").get('content')
        
    elif soup.find('link', rel = 'canonical'):
        art_url = soup.find('link', rel = 'canonical').get('href')
        
    else :
        art_url = url
        
    return art_url

# %%
def getSourceUrl(soup):
    
    """ 
        Article's source url
    """
    for val in re.finditer("(\w)+://[^/]+/", url):
        return val.group(0)

# %%
def getSourceName(soup, url):
    
    """ 
        Extracting article's source name
    """
        
    if soup.find('meta', property="og:site_name"):
        src_name = soup.find('meta', property="og:site_name").get('content')
    else :
        try :
            site = url.split("://")

            if site[0] == "https" or site[0] == "http":
                name_site = site[1]
            else:
                name_site = site[0]

            tab = name_site.split("/")
            name_site = tab[0]


            TLD = ["fr.","www.","www2.",".org",".fr",".eu",".net",".com"]

            for i in TLD:
                name_site = name_site.replace(i, "")
            if name_site[-1] =='.' :
                return name_site[:-1]
            else :
                return (name_site)
        except :
            return url
        
    return src_name

# %%
def getSourceType(soup):
    
    """ 
        Extracting article's source type
    """
    
    src_type = "xpath_source"
    
    return src_type

# %%
def getImg(soup):
    
    """ 
        Extracting article's image
    """
    if soup.find('meta', property = "og:image"):
        src_img = soup.find('meta', property = "og:image").get('content')
        
    else :
        src_img = "no_data"
        
    return src_img

# %%
def getArtAuth(soup):
    
    """ 
        Extracting article's author
    """
    if soup.find('meta', attrs={'name':"twitter:data1"}) :
        art_auth = soup.find('meta', attrs={'name':"twitter:data1"}).get('content')
        
    elif soup.find('div', class_ = "td-post-author-name") :
        art_auth = find('div', class_ = "td-post-author-name").text
        
    elif soup.find("a", {"class": "nomAuteur"}):
        art_auth = soup.find("a", {"class": "nomAuteur"}).get('content')
        
    else :
        art_auth = "no_data"
    
    return art_auth

# %%
def getTag(soup):
    
    ##keywords or tags
    """
        Extracting article's tags if they exist
    """
    if soup.find('meta', attrs={'name':"keywords"}):
        art_tag = soup.find('meta', attrs={'name':"keywords"}).get('content')
        
    elif soup.find_all("a", {"rel": "category tag"}) :
        art_tag = [el.get_text() for el in soup.find_all("a", {"rel": "category tag"})]
        
    else:
        art_tag = "no_data"
        
    return art_tag

# %%
def scrapPage(soup):
    
    """ 
        Function combining the previous ones and stocking the list of results in a dataframe line
    """
    
    art_content, art_content_html = getContent(soup)
    
    art_extract_datetime = getDate(soup)
    
    art_lang = getLang(soup, art_content)
    
    art_title = getTitle(soup)
    
    art_url = getUrl(soup, url)
    
    src_name = getSourceName(soup, url)
    
    src_type = "xpath_source"
    
    src_url = getSourceUrl(soup)
    
    src_img = getImg(soup) 
    
    art_auth = getArtAuth(soup)
    
    art_tag = getTag(soup)
    
    return art_content, art_content_html, art_extract_datetime, art_lang, art_title, art_url, src_name, src_type, src_url, src_img, art_auth, art_tag

# %%
df_scrap.loc[1]=scrapPage(soup)

# %%
df_scrap
# Out:
#                                          art_content  \
# 1  \n\nLe World Wide Web [ˌwɝld waɪd ˈwɛb][a] (li...
#
#                                     art_content_html art_extract_datetime  \
# 1  <div class="mw-parser-output"><div class="band...           2021-01-11
#
#   art_lang                   art_title  \
# 1       fr  World Wide Web — Wikipédia
#
#                                         art_url       src_name      src_type  \
# 1  https://fr.wikipedia.org/wiki/World_Wide_Web  geeksforgeeks  xpath_source
#
#                           src_url  \
# 1  https://www.geeksforgeeks.org/
#
#                                              src_img art_auth  art_tag
# 1  https://upload.wikimedia.org/wikipedia/commons...  no_data  no_data
